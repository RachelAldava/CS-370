# %% [markdown]
# # Module Five Assignment: Cartpole Problem
# Review the code in this notebook and in the score_logger.py file in the *scores* folder (directory). Once you have reviewed the code, return to this notebook and select **Cell** and then **Run All** from the menu bar to run this code. The code takes several minutes to run.

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.95  
LEARNING_RATE = 0.001  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.995  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()
# Out:
# Using TensorFlow backend.

# %%
cartpole()
# Out:
# Run: 1, exploration: 1.0, score: 14
# Scores: (min: 14, avg: 14, max: 14)
#
# Run: 2, exploration: 0.960693043575437, score: 14
# Scores: (min: 14, avg: 14, max: 14)
#
# Run: 3, exploration: 0.8778091417340573, score: 19
# Scores: (min: 14, avg: 15.666666666666666, max: 19)
#
# Run: 4, exploration: 0.7590483508202912, score: 30
# Scores: (min: 14, avg: 19.25, max: 30)
#
# Run: 5, exploration: 0.7183288830986236, score: 12
# Scores: (min: 12, avg: 17.8, max: 30)
#
# Run: 6, exploration: 0.6596532430440636, score: 18
# Scores: (min: 12, avg: 17.833333333333332, max: 30)
#
# Run: 7, exploration: 0.5937455908197752, score: 22
# Scores: (min: 12, avg: 18.428571428571427, max: 30)
#
# Run: 8, exploration: 0.5344229416520513, score: 22
# Scores: (min: 12, avg: 18.875, max: 30)
#
# Run: 9, exploration: 0.5032248303978422, score: 13
# Scores: (min: 12, avg: 18.22222222222222, max: 30)
#
# Run: 10, exploration: 0.4858739637363176, score: 8
# Scores: (min: 8, avg: 17.2, max: 30)
#
# Run: 11, exploration: 0.46677573701590436, score: 9
# Scores: (min: 8, avg: 16.454545454545453, max: 30)
#
# Run: 12, exploration: 0.4417353564707963, score: 12
# Scores: (min: 8, avg: 16.083333333333332, max: 30)
#
# Run: 13, exploration: 0.42013897252428334, score: 11
# Scores: (min: 8, avg: 15.692307692307692, max: 30)
#
# Run: 14, exploration: 0.3976004408064698, score: 12
# Scores: (min: 8, avg: 15.428571428571429, max: 30)
#
# Run: 15, exploration: 0.38389143477919885, score: 8
# Scores: (min: 8, avg: 14.933333333333334, max: 30)
#
# Run: 16, exploration: 0.36512303261753626, score: 11
# Scores: (min: 8, avg: 14.6875, max: 30)
#
# Run: 17, exploration: 0.3472722151889232, score: 11
# Scores: (min: 8, avg: 14.470588235294118, max: 30)
#
# Run: 18, exploration: 0.3253644408394192, score: 14
# Scores: (min: 8, avg: 14.444444444444445, max: 30)
#
# Run: 19, exploration: 0.3079101286968243, score: 12
# Scores: (min: 8, avg: 14.31578947368421, max: 30)
#
# Run: 20, exploration: 0.29580711868545667, score: 9
# Scores: (min: 8, avg: 14.05, max: 30)
#
# Run: 21, exploration: 0.2757603055760701, score: 15
# Scores: (min: 8, avg: 14.095238095238095, max: 30)
#
# Run: 22, exploration: 0.25966219297210513, score: 13
# Scores: (min: 8, avg: 14.045454545454545, max: 30)
#
# Run: 23, exploration: 0.24696734223472733, score: 11
# Scores: (min: 8, avg: 13.91304347826087, max: 30)
#
# Run: 24, exploration: 0.23255008201124722, score: 13
# Scores: (min: 8, avg: 13.875, max: 30)
#
# Run: 25, exploration: 0.22229219984074702, score: 10
# Scores: (min: 8, avg: 13.72, max: 30)
#
# Run: 26, exploration: 0.21355457002808648, score: 9
# Scores: (min: 8, avg: 13.538461538461538, max: 30)
#
# Run: 27, exploration: 0.2041345879004775, score: 10
# Scores: (min: 8, avg: 13.407407407407407, max: 30)
#
# Run: 28, exploration: 0.1912566947289212, score: 14
# Scores: (min: 8, avg: 13.428571428571429, max: 30)
#
# Run: 29, exploration: 0.17829525136613786, score: 15
# Scores: (min: 8, avg: 13.482758620689655, max: 30)
#
# Run: 30, exploration: 0.1712870076899825, score: 9
# Scores: (min: 8, avg: 13.333333333333334, max: 30)
#
# Run: 31, exploration: 0.16455423674261854, score: 9
# Scores: (min: 8, avg: 13.193548387096774, max: 30)
#
# Run: 32, exploration: 0.1572956799768517, score: 10
# Scores: (min: 8, avg: 13.09375, max: 30)
#
# Run: 33, exploration: 0.15111286553822956, score: 9
# Scores: (min: 8, avg: 12.969696969696969, max: 30)
#
# Run: 34, exploration: 0.14444721332374086, score: 10
# Scores: (min: 8, avg: 12.882352941176471, max: 30)
#
# Run: 35, exploration: 0.13669828187021155, score: 12
# Scores: (min: 8, avg: 12.857142857142858, max: 30)
#
# Run: 36, exploration: 0.1313250884614265, score: 9
# Scores: (min: 8, avg: 12.75, max: 30)
#
# Run: 37, exploration: 0.1242800989098765, score: 12
# Scores: (min: 8, avg: 12.72972972972973, max: 30)
#
# Run: 38, exploration: 0.11939502647758558, score: 9
# Scores: (min: 8, avg: 12.631578947368421, max: 30)
#
# Run: 39, exploration: 0.11299003011401039, score: 12
# Scores: (min: 8, avg: 12.615384615384615, max: 30)
#
# Run: 40, exploration: 0.10800599224428936, score: 10
# Scores: (min: 8, avg: 12.55, max: 30)
#
# Run: 41, exploration: 0.1032418023864836, score: 10
# Scores: (min: 8, avg: 12.487804878048781, max: 30)
#
# Run: 42, exploration: 0.09819432413732986, score: 11
# Scores: (min: 8, avg: 12.452380952380953, max: 30)
#
# Run: 43, exploration: 0.09339361644125409, score: 11
# Scores: (min: 8, avg: 12.418604651162791, max: 30)
#
# Run: 44, exploration: 0.0888276147181114, score: 11
# Scores: (min: 8, avg: 12.386363636363637, max: 30)
#
# Run: 45, exploration: 0.08533607153708872, score: 9
# Scores: (min: 8, avg: 12.311111111111112, max: 30)
#
# Run: 46, exploration: 0.08157186144027828, score: 10
# Scores: (min: 8, avg: 12.26086956521739, max: 30)
#
# Run: 47, exploration: 0.07836551983717477, score: 9
# Scores: (min: 8, avg: 12.191489361702128, max: 30)
#
# Run: 48, exploration: 0.0745342397963533, score: 11
# Scores: (min: 8, avg: 12.166666666666666, max: 30)
#
# Run: 49, exploration: 0.0712465030521374, score: 10
# Scores: (min: 8, avg: 12.122448979591837, max: 30)
#
# Run: 50, exploration: 0.06810378976195819, score: 10
# Scores: (min: 8, avg: 12.08, max: 30)
#
# Run: 51, exploration: 0.06542683706543727, score: 9
# Scores: (min: 8, avg: 12.019607843137255, max: 30)
#
# Run: 52, exploration: 0.06285510723190912, score: 9
# Scores: (min: 8, avg: 11.961538461538462, max: 30)
#
# Run: 53, exploration: 0.06038446427088321, score: 9
# Scores: (min: 8, avg: 11.90566037735849, max: 30)
#
# Run: 54, exploration: 0.058010934765067, score: 9
# Scores: (min: 8, avg: 11.851851851851851, max: 30)
#
# Run: 55, exploration: 0.0554520479727078, score: 10
# Scores: (min: 8, avg: 11.818181818181818, max: 30)
#
# Run: 56, exploration: 0.052477299559006776, score: 12
# Scores: (min: 8, avg: 11.821428571428571, max: 30)
#
# Run: 57, exploration: 0.05041457663196215, score: 9
# Scores: (min: 8, avg: 11.771929824561404, max: 30)
#
# Run: 58, exploration: 0.048432933065126825, score: 9
# Scores: (min: 8, avg: 11.724137931034482, max: 30)
#
# Run: 59, exploration: 0.04652918187562211, score: 9
# Scores: (min: 8, avg: 11.677966101694915, max: 30)
#
# Run: 60, exploration: 0.04470026135116646, score: 9
# Scores: (min: 8, avg: 11.633333333333333, max: 30)
#
# Run: 61, exploration: 0.04272851397543923, score: 10
# Scores: (min: 8, avg: 11.60655737704918, max: 30)
#
# Run: 62, exploration: 0.04063952250178857, score: 11
# Scores: (min: 8, avg: 11.596774193548388, max: 30)
#
# Run: 63, exploration: 0.03923829805195549, score: 8
# Scores: (min: 8, avg: 11.53968253968254, max: 30)
#
# Run: 64, exploration: 0.0378853869148274, score: 8
# Scores: (min: 8, avg: 11.484375, max: 30)
#
# Run: 65, exploration: 0.036396227662238566, score: 9
# Scores: (min: 8, avg: 11.446153846153846, max: 30)
#
# Run: 66, exploration: 0.03514130927386981, score: 8
# Scores: (min: 8, avg: 11.393939393939394, max: 30)
#
# Run: 67, exploration: 0.03359121130473201, score: 10
# Scores: (min: 8, avg: 11.373134328358208, max: 30)
#
# Run: 68, exploration: 0.03227084302572862, score: 9
# Scores: (min: 8, avg: 11.338235294117647, max: 30)
#
# Run: 69, exploration: 0.031158165231288826, score: 8
# Scores: (min: 8, avg: 11.289855072463768, max: 30)
#
# Run: 70, exploration: 0.029933432588273214, score: 9
# Scores: (min: 8, avg: 11.257142857142858, max: 30)
#
# Run: 71, exploration: 0.02861305625559891, score: 10
# Scores: (min: 8, avg: 11.23943661971831, max: 30)
#
# Run: 72, exploration: 0.027626496583102015, score: 8
# Scores: (min: 8, avg: 11.194444444444445, max: 30)
#
# Run: 73, exploration: 0.02654058308574668, score: 9
# Scores: (min: 8, avg: 11.164383561643836, max: 30)
#
# Run: 74, exploration: 0.02562548094765099, score: 8
# Scores: (min: 8, avg: 11.121621621621621, max: 30)
#
# Run: 75, exploration: 0.02449513017825978, score: 10
# Scores: (min: 8, avg: 11.106666666666667, max: 30)
#
# Run: 76, exploration: 0.023414639657910272, score: 10
# Scores: (min: 8, avg: 11.092105263157896, max: 30)
#
# Run: 77, exploration: 0.022494281437179946, score: 9
# Scores: (min: 8, avg: 11.064935064935066, max: 30)
#
# Run: 78, exploration: 0.021610099696926857, score: 9
# Scores: (min: 8, avg: 11.038461538461538, max: 30)
#
# Run: 79, exploration: 0.020760672449809284, score: 9
# Scores: (min: 8, avg: 11.012658227848101, max: 30)
#
# Run: 80, exploration: 0.019944633602480003, score: 9
# Scores: (min: 8, avg: 10.9875, max: 30)
#
# Run: 81, exploration: 0.019160670758563442, score: 9
# Scores: (min: 8, avg: 10.962962962962964, max: 30)
# Run: 82, exploration: 0.01831548549245123, score: 10
# Scores: (min: 8, avg: 10.951219512195122, max: 30)
#
# Run: 83, exploration: 0.017595559502304726, score: 9
# Scores: (min: 8, avg: 10.927710843373495, max: 30)
#
# Run: 84, exploration: 0.016903931611681827, score: 9
# Scores: (min: 8, avg: 10.904761904761905, max: 30)
#
# Run: 85, exploration: 0.01615829206087557, score: 10
# Scores: (min: 8, avg: 10.894117647058824, max: 30)
#
# Run: 86, exploration: 0.015523158778943369, score: 9
# Scores: (min: 8, avg: 10.872093023255815, max: 30)
#
# Run: 87, exploration: 0.014838425699981627, score: 10
# Scores: (min: 8, avg: 10.862068965517242, max: 30)
#
# Run: 88, exploration: 0.014255172347583332, score: 9
# Scores: (min: 8, avg: 10.840909090909092, max: 30)
#
# Run: 89, exploration: 0.013626370684745774, score: 10
# Scores: (min: 8, avg: 10.831460674157304, max: 30)
#
# Run: 90, exploration: 0.01302530572838545, score: 10
# Scores: (min: 8, avg: 10.822222222222223, max: 30)
#
# Run: 91, exploration: 0.012513320603703188, score: 9
# Scores: (min: 8, avg: 10.802197802197803, max: 30)
#
# Run: 92, exploration: 0.01202146005600684, score: 9
# Scores: (min: 8, avg: 10.782608695652174, max: 30)
#
# Run: 93, exploration: 0.011491188384178622, score: 10
# Scores: (min: 8, avg: 10.774193548387096, max: 30)
#
# Run: 94, exploration: 0.010874738754866477, score: 12
# Scores: (min: 8, avg: 10.787234042553191, max: 30)
#
# Run: 95, exploration: 0.010447285872500434, score: 9
# Scores: (min: 8, avg: 10.76842105263158, max: 30)
#
# Run: 96, exploration: 0.010036634861955105, score: 9
# Scores: (min: 8, avg: 10.75, max: 30)
#
# Run: 97, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.731958762886597, max: 30)
#
# Run: 98, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.724489795918368, max: 30)
#
# Run: 99, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.707070707070708, max: 30)
#
# Run: 100, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.69, max: 30)
#
# Run: 101, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 10.66, max: 30)
#
# Run: 102, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.61, max: 30)
#
# Run: 103, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.52, max: 30)
#
# Run: 104, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.31, max: 22)
#
# Run: 105, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.28, max: 22)
#
# Run: 106, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 10.28, max: 22)
#
# Run: 107, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.15, max: 22)
#
# Run: 108, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 10.07, max: 18)
#
# Run: 109, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 10.06, max: 18)
#
# Run: 110, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 10.19, max: 21)
#
# Run: 111, exploration: 0.01, score: 75
# Scores: (min: 8, avg: 10.85, max: 75)
#
# Run: 112, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 10.96, max: 75)
#
# Run: 113, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 11, max: 75)
#
# Run: 114, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 11, max: 75)
#
# Run: 115, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 11.04, max: 75)
#
# Run: 116, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 11.08, max: 75)
#
# Run: 117, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 11.14, max: 75)
#
# Run: 118, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 11.17, max: 75)
#
# Run: 119, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.15, max: 75)
#
# Run: 120, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 11.18, max: 75)
#
# Run: 121, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 11.23, max: 75)
#
# Run: 122, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 11.3, max: 75)
#
# Run: 123, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 11.37, max: 75)
#
# Run: 124, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 11.39, max: 75)
#
# Run: 125, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 11.42, max: 75)
#
# Run: 126, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.42, max: 75)
#
# Run: 127, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.42, max: 75)
#
# Run: 128, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.38, max: 75)
#
# Run: 129, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11.34, max: 75)
#
# Run: 130, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11.36, max: 75)
#
# Run: 131, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11.38, max: 75)
#
# Run: 132, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 11.4, max: 75)
#
# Run: 133, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 11.47, max: 75)
#
# Run: 134, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 11.53, max: 75)
#
# Run: 135, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 11.61, max: 75)
#
# Run: 136, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 11.78, max: 75)
#
# Run: 137, exploration: 0.01, score: 45
# Scores: (min: 8, avg: 12.11, max: 75)
#
# Run: 138, exploration: 0.01, score: 60
# Scores: (min: 8, avg: 12.62, max: 75)
#
# Run: 139, exploration: 0.01, score: 40
# Scores: (min: 8, avg: 12.9, max: 75)
#
# Run: 140, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 13.09, max: 75)
#
# Run: 141, exploration: 0.01, score: 71
# Scores: (min: 8, avg: 13.7, max: 75)
#
# Run: 142, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 13.88, max: 75)
#
# Run: 143, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 13.94, max: 75)
#
# Run: 144, exploration: 0.01, score: 43
# Scores: (min: 8, avg: 14.26, max: 75)
#
# Run: 145, exploration: 0.01, score: 49
# Scores: (min: 8, avg: 14.66, max: 75)
#
# Run: 146, exploration: 0.01, score: 57
# Scores: (min: 8, avg: 15.13, max: 75)
#
# Run: 147, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 15.27, max: 75)
#
# Run: 148, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 15.44, max: 75)
#
# Run: 149, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 15.55, max: 75)
#
# Run: 150, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 15.75, max: 75)
#
# Run: 151, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 15.95, max: 75)
#
# Run: 152, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 16.03, max: 75)
#
# Run: 153, exploration: 0.01, score: 33
# Scores: (min: 8, avg: 16.27, max: 75)
#
# Run: 154, exploration: 0.01, score: 42
# Scores: (min: 8, avg: 16.6, max: 75)
#
# Run: 155, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 16.84, max: 75)
#
# Run: 156, exploration: 0.01, score: 77
# Scores: (min: 8, avg: 17.49, max: 77)
#
# Run: 157, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 17.67, max: 77)
#
# Run: 158, exploration: 0.01, score: 51
# Scores: (min: 8, avg: 18.09, max: 77)
#
# Run: 159, exploration: 0.01, score: 40
# Scores: (min: 8, avg: 18.4, max: 77)
#
# Run: 160, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 18.6, max: 77)
#
# Run: 161, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 18.8, max: 77)
#
# Run: 162, exploration: 0.01, score: 57
# Scores: (min: 8, avg: 19.26, max: 77)
#
# Run: 163, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 19.52, max: 77)
#
# Run: 164, exploration: 0.01, score: 33
# Scores: (min: 8, avg: 19.77, max: 77)
#
# Run: 165, exploration: 0.01, score: 41
# Scores: (min: 8, avg: 20.09, max: 77)
#
# Run: 166, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 20.32, max: 77)
#
# Run: 167, exploration: 0.01, score: 54
# Scores: (min: 8, avg: 20.76, max: 77)
#
# Run: 168, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 20.99, max: 77)
#
# Run: 169, exploration: 0.01, score: 56
# Scores: (min: 8, avg: 21.47, max: 77)
#
# Run: 170, exploration: 0.01, score: 70
# Scores: (min: 8, avg: 22.08, max: 77)
#
# Run: 171, exploration: 0.01, score: 73
# Scores: (min: 8, avg: 22.71, max: 77)
#
# Run: 172, exploration: 0.01, score: 60
# Scores: (min: 8, avg: 23.23, max: 77)
#
# Run: 173, exploration: 0.01, score: 70
# Scores: (min: 8, avg: 23.84, max: 77)
#
# Run: 174, exploration: 0.01, score: 65
# Scores: (min: 9, avg: 24.41, max: 77)
#
# Run: 175, exploration: 0.01, score: 78
# Scores: (min: 9, avg: 25.09, max: 78)
#
# Run: 176, exploration: 0.01, score: 67
# Scores: (min: 9, avg: 25.66, max: 78)
#
# Run: 177, exploration: 0.01, score: 76
# Scores: (min: 9, avg: 26.33, max: 78)
#
# Run: 178, exploration: 0.01, score: 106
# Scores: (min: 9, avg: 27.3, max: 106)
#
# Run: 179, exploration: 0.01, score: 98
# Scores: (min: 9, avg: 28.19, max: 106)
#
# Run: 180, exploration: 0.01, score: 122
# Scores: (min: 9, avg: 29.32, max: 122)
#
# Run: 181, exploration: 0.01, score: 104
# Scores: (min: 9, avg: 30.27, max: 122)
# Run: 182, exploration: 0.01, score: 116
# Scores: (min: 9, avg: 31.33, max: 122)
#
# Run: 183, exploration: 0.01, score: 110
# Scores: (min: 9, avg: 32.34, max: 122)
#
# Run: 184, exploration: 0.01, score: 107
# Scores: (min: 9, avg: 33.32, max: 122)
#
# Run: 185, exploration: 0.01, score: 130
# Scores: (min: 9, avg: 34.52, max: 130)
#
# Run: 186, exploration: 0.01, score: 108
# Scores: (min: 9, avg: 35.51, max: 130)
#
# Run: 187, exploration: 0.01, score: 127
# Scores: (min: 9, avg: 36.68, max: 130)
#
# Run: 188, exploration: 0.01, score: 115
# Scores: (min: 9, avg: 37.74, max: 130)
#
# Run: 189, exploration: 0.01, score: 119
# Scores: (min: 9, avg: 38.83, max: 130)
#
# Run: 190, exploration: 0.01, score: 110
# Scores: (min: 9, avg: 39.83, max: 130)
#
# Run: 191, exploration: 0.01, score: 122
# Scores: (min: 9, avg: 40.96, max: 130)
#
# Run: 192, exploration: 0.01, score: 110
# Scores: (min: 9, avg: 41.97, max: 130)
#
# Run: 193, exploration: 0.01, score: 131
# Scores: (min: 9, avg: 43.18, max: 131)
#
# Run: 194, exploration: 0.01, score: 135
# Scores: (min: 9, avg: 44.41, max: 135)
#
# Run: 195, exploration: 0.01, score: 125
# Scores: (min: 9, avg: 45.57, max: 135)
#
# Run: 196, exploration: 0.01, score: 147
# Scores: (min: 9, avg: 46.95, max: 147)
#
# Run: 197, exploration: 0.01, score: 130
# Scores: (min: 9, avg: 48.16, max: 147)
#
# Run: 198, exploration: 0.01, score: 111
# Scores: (min: 9, avg: 49.17, max: 147)
#
# Run: 199, exploration: 0.01, score: 117
# Scores: (min: 9, avg: 50.25, max: 147)
#
# Run: 200, exploration: 0.01, score: 117
# Scores: (min: 9, avg: 51.33, max: 147)
#
# Run: 201, exploration: 0.01, score: 117
# Scores: (min: 9, avg: 52.39, max: 147)
#
# Run: 202, exploration: 0.01, score: 119
# Scores: (min: 9, avg: 53.49, max: 147)
#
# Run: 203, exploration: 0.01, score: 123
# Scores: (min: 9, avg: 54.62, max: 147)
#
# Run: 204, exploration: 0.01, score: 118
# Scores: (min: 9, avg: 55.71, max: 147)
#
# Run: 205, exploration: 0.01, score: 139
# Scores: (min: 9, avg: 57.01, max: 147)
#
# Run: 206, exploration: 0.01, score: 122
# Scores: (min: 9, avg: 58.05, max: 147)
#
# Run: 207, exploration: 0.01, score: 135
# Scores: (min: 9, avg: 59.31, max: 147)
#
# Run: 208, exploration: 0.01, score: 122
# Scores: (min: 9, avg: 60.39, max: 147)
#
# Run: 209, exploration: 0.01, score: 130
# Scores: (min: 9, avg: 61.57, max: 147)
#
# Run: 210, exploration: 0.01, score: 127
# Scores: (min: 9, avg: 62.63, max: 147)
#
# Run: 211, exploration: 0.01, score: 116
# Scores: (min: 9, avg: 63.04, max: 147)
#
# Run: 212, exploration: 0.01, score: 113
# Scores: (min: 9, avg: 63.94, max: 147)
#
# Run: 213, exploration: 0.01, score: 118
# Scores: (min: 9, avg: 64.97, max: 147)
#
# Run: 214, exploration: 0.01, score: 133
# Scores: (min: 9, avg: 66.18, max: 147)
#
# Run: 215, exploration: 0.01, score: 133
# Scores: (min: 9, avg: 67.39, max: 147)
#
# Run: 216, exploration: 0.01, score: 126
# Scores: (min: 9, avg: 68.5, max: 147)
#
# Run: 217, exploration: 0.01, score: 143
# Scores: (min: 9, avg: 69.76, max: 147)
#
# Run: 218, exploration: 0.01, score: 148
# Scores: (min: 9, avg: 71.07, max: 148)
#
# Run: 219, exploration: 0.01, score: 113
# Scores: (min: 9, avg: 72.1, max: 148)
#
# Run: 220, exploration: 0.01, score: 122
# Scores: (min: 9, avg: 73.2, max: 148)
#
# Run: 221, exploration: 0.01, score: 129
# Scores: (min: 9, avg: 74.29, max: 148)
#
# Run: 222, exploration: 0.01, score: 121
# Scores: (min: 9, avg: 75.3, max: 148)
#
# Run: 223, exploration: 0.01, score: 115
# Scores: (min: 9, avg: 76.27, max: 148)
#
# Run: 224, exploration: 0.01, score: 132
# Scores: (min: 9, avg: 77.44, max: 148)
#
# Run: 225, exploration: 0.01, score: 118
# Scores: (min: 9, avg: 78.49, max: 148)
#
# Run: 226, exploration: 0.01, score: 117
# Scores: (min: 10, avg: 79.57, max: 148)
#
# Run: 227, exploration: 0.01, score: 130
# Scores: (min: 10, avg: 80.77, max: 148)
#
# Run: 228, exploration: 0.01, score: 111
# Scores: (min: 11, avg: 81.78, max: 148)
#
# Run: 229, exploration: 0.01, score: 137
# Scores: (min: 11, avg: 83.04, max: 148)
#
# Run: 230, exploration: 0.01, score: 106
# Scores: (min: 11, avg: 83.99, max: 148)
#
# Run: 231, exploration: 0.01, score: 96
# Scores: (min: 12, avg: 84.84, max: 148)
#
# Run: 232, exploration: 0.01, score: 118
# Scores: (min: 16, avg: 85.9, max: 148)
#
# Run: 233, exploration: 0.01, score: 140
# Scores: (min: 16, avg: 87.14, max: 148)
#
# Run: 234, exploration: 0.01, score: 112
# Scores: (min: 17, avg: 88.1, max: 148)
#
# Run: 235, exploration: 0.01, score: 127
# Scores: (min: 17, avg: 89.17, max: 148)
#
# Run: 236, exploration: 0.01, score: 116
# Scores: (min: 17, avg: 90.07, max: 148)
#
# Run: 237, exploration: 0.01, score: 113
# Scores: (min: 17, avg: 90.75, max: 148)
#
# Run: 238, exploration: 0.01, score: 130
# Scores: (min: 17, avg: 91.45, max: 148)
#
# Run: 239, exploration: 0.01, score: 118
# Scores: (min: 17, avg: 92.23, max: 148)
#
# Run: 240, exploration: 0.01, score: 118
# Scores: (min: 17, avg: 93.12, max: 148)
#
# Run: 241, exploration: 0.01, score: 113
# Scores: (min: 17, avg: 93.54, max: 148)
#
# Run: 242, exploration: 0.01, score: 120
# Scores: (min: 17, avg: 94.45, max: 148)
#
# Run: 243, exploration: 0.01, score: 121
# Scores: (min: 17, avg: 95.49, max: 148)
#
# Run: 244, exploration: 0.01, score: 132
# Scores: (min: 17, avg: 96.38, max: 148)
#
# Run: 245, exploration: 0.01, score: 125
# Scores: (min: 17, avg: 97.14, max: 148)
#
# Run: 246, exploration: 0.01, score: 121
# Scores: (min: 17, avg: 97.78, max: 148)
#
# Run: 247, exploration: 0.01, score: 125
# Scores: (min: 17, avg: 98.8, max: 148)
#
# Run: 248, exploration: 0.01, score: 121
# Scores: (min: 17, avg: 99.73, max: 148)
#
# Run: 249, exploration: 0.01, score: 122
# Scores: (min: 17, avg: 100.74, max: 148)
#
# Run: 250, exploration: 0.01, score: 130
# Scores: (min: 17, avg: 101.74, max: 148)
#
# Run: 251, exploration: 0.01, score: 112
# Scores: (min: 17, avg: 102.57, max: 148)
#
# Run: 252, exploration: 0.01, score: 123
# Scores: (min: 27, avg: 103.63, max: 148)
#
# Run: 253, exploration: 0.01, score: 129
# Scores: (min: 27, avg: 104.59, max: 148)
#
# Run: 254, exploration: 0.01, score: 128
# Scores: (min: 27, avg: 105.45, max: 148)
#
# Run: 255, exploration: 0.01, score: 130
# Scores: (min: 27, avg: 106.41, max: 148)
#
# Run: 256, exploration: 0.01, score: 140
# Scores: (min: 27, avg: 107.04, max: 148)
#
# Run: 257, exploration: 0.01, score: 118
# Scores: (min: 29, avg: 107.95, max: 148)
#
# Run: 258, exploration: 0.01, score: 134
# Scores: (min: 29, avg: 108.78, max: 148)
#
# Run: 259, exploration: 0.01, score: 120
# Scores: (min: 29, avg: 109.58, max: 148)
#
# Run: 260, exploration: 0.01, score: 126
# Scores: (min: 30, avg: 110.55, max: 148)
#
# Run: 261, exploration: 0.01, score: 126
# Scores: (min: 31, avg: 111.51, max: 148)
#
# Run: 262, exploration: 0.01, score: 133
# Scores: (min: 31, avg: 112.27, max: 148)
#
# Run: 263, exploration: 0.01, score: 130
# Scores: (min: 31, avg: 113.23, max: 148)
#
# Run: 264, exploration: 0.01, score: 156
# Scores: (min: 31, avg: 114.46, max: 156)
#
# Run: 265, exploration: 0.01, score: 138
# Scores: (min: 31, avg: 115.43, max: 156)
#
# Run: 266, exploration: 0.01, score: 136
# Scores: (min: 32, avg: 116.48, max: 156)
#
# Run: 267, exploration: 0.01, score: 128
# Scores: (min: 32, avg: 117.22, max: 156)
#
# Run: 268, exploration: 0.01, score: 125
# Scores: (min: 56, avg: 118.15, max: 156)
#
# Run: 269, exploration: 0.01, score: 120
# Scores: (min: 60, avg: 118.79, max: 156)
#
# Run: 270, exploration: 0.01, score: 141
# Scores: (min: 60, avg: 119.5, max: 156)
#
# Run: 271, exploration: 0.01, score: 103
# Scores: (min: 60, avg: 119.8, max: 156)
#
# Run: 272, exploration: 0.01, score: 140
# Scores: (min: 65, avg: 120.6, max: 156)
#
# Run: 273, exploration: 0.01, score: 126
# Scores: (min: 65, avg: 121.16, max: 156)
#
# Run: 274, exploration: 0.01, score: 125
# Scores: (min: 67, avg: 121.76, max: 156)
#
# Run: 275, exploration: 0.01, score: 127
# Scores: (min: 67, avg: 122.25, max: 156)
#
# Run: 276, exploration: 0.01, score: 155
# Scores: (min: 76, avg: 123.13, max: 156)
#
# Run: 277, exploration: 0.01, score: 140
# Scores: (min: 96, avg: 123.77, max: 156)
#
# Run: 278, exploration: 0.01, score: 149
# Scores: (min: 96, avg: 124.2, max: 156)
#
# Run: 279, exploration: 0.01, score: 116
# Scores: (min: 96, avg: 124.38, max: 156)
#
# Run: 280, exploration: 0.01, score: 141
# Scores: (min: 96, avg: 124.57, max: 156)
#
# Run: 281, exploration: 0.01, score: 117
# Scores: (min: 96, avg: 124.7, max: 156)
#
# Run: 282, exploration: 0.01, score: 145
# Scores: (min: 96, avg: 124.99, max: 156)
#
# Run: 283, exploration: 0.01, score: 124
# Scores: (min: 96, avg: 125.13, max: 156)
# Run: 284, exploration: 0.01, score: 129
# Scores: (min: 96, avg: 125.35, max: 156)
#
# Run: 285, exploration: 0.01, score: 125
# Scores: (min: 96, avg: 125.3, max: 156)
#
# Run: 286, exploration: 0.01, score: 120
# Scores: (min: 96, avg: 125.42, max: 156)
#
# Run: 287, exploration: 0.01, score: 134
# Scores: (min: 96, avg: 125.49, max: 156)
#
# Run: 288, exploration: 0.01, score: 118
# Scores: (min: 96, avg: 125.52, max: 156)
#
# Run: 289, exploration: 0.01, score: 116
# Scores: (min: 96, avg: 125.49, max: 156)
#
# Run: 290, exploration: 0.01, score: 141
# Scores: (min: 96, avg: 125.8, max: 156)
#
# Run: 291, exploration: 0.01, score: 125
# Scores: (min: 96, avg: 125.83, max: 156)
#
# Run: 292, exploration: 0.01, score: 142
# Scores: (min: 96, avg: 126.15, max: 156)
#
# Run: 293, exploration: 0.01, score: 140
# Scores: (min: 96, avg: 126.24, max: 156)
#
# Run: 294, exploration: 0.01, score: 116
# Scores: (min: 96, avg: 126.05, max: 156)
#
# Run: 295, exploration: 0.01, score: 134
# Scores: (min: 96, avg: 126.14, max: 156)
#
# Run: 296, exploration: 0.01, score: 135
# Scores: (min: 96, avg: 126.02, max: 156)
#
# Run: 297, exploration: 0.01, score: 139
# Scores: (min: 96, avg: 126.11, max: 156)
#
# Run: 298, exploration: 0.01, score: 136
# Scores: (min: 96, avg: 126.36, max: 156)
#
# Run: 299, exploration: 0.01, score: 122
# Scores: (min: 96, avg: 126.41, max: 156)
#
# Run: 300, exploration: 0.01, score: 118
# Scores: (min: 96, avg: 126.42, max: 156)
#
# Run: 301, exploration: 0.01, score: 127
# Scores: (min: 96, avg: 126.52, max: 156)
#
# Run: 302, exploration: 0.01, score: 124
# Scores: (min: 96, avg: 126.57, max: 156)
#
# Run: 303, exploration: 0.01, score: 144
# Scores: (min: 96, avg: 126.78, max: 156)
#
# Run: 304, exploration: 0.01, score: 138
# Scores: (min: 96, avg: 126.98, max: 156)
#
# Run: 305, exploration: 0.01, score: 154
# Scores: (min: 96, avg: 127.13, max: 156)
#
# Run: 306, exploration: 0.01, score: 126
# Scores: (min: 96, avg: 127.17, max: 156)
#
# Run: 307, exploration: 0.01, score: 145
# Scores: (min: 96, avg: 127.27, max: 156)
#
# Run: 308, exploration: 0.01, score: 118
# Scores: (min: 96, avg: 127.23, max: 156)
#
# Run: 309, exploration: 0.01, score: 140
# Scores: (min: 96, avg: 127.33, max: 156)
#
# Run: 310, exploration: 0.01, score: 126
# Scores: (min: 96, avg: 127.32, max: 156)
#
# Run: 311, exploration: 0.01, score: 122
# Scores: (min: 96, avg: 127.38, max: 156)
#
# Run: 312, exploration: 0.01, score: 122
# Scores: (min: 96, avg: 127.47, max: 156)
#
# Run: 313, exploration: 0.01, score: 127
# Scores: (min: 96, avg: 127.56, max: 156)
#
# Run: 314, exploration: 0.01, score: 134
# Scores: (min: 96, avg: 127.57, max: 156)
#
# Run: 315, exploration: 0.01, score: 115
# Scores: (min: 96, avg: 127.39, max: 156)
#
# Run: 316, exploration: 0.01, score: 105
# Scores: (min: 96, avg: 127.18, max: 156)
#
# Run: 317, exploration: 0.01, score: 149
# Scores: (min: 96, avg: 127.24, max: 156)
#
# Run: 318, exploration: 0.01, score: 122
# Scores: (min: 96, avg: 126.98, max: 156)
#
# Run: 319, exploration: 0.01, score: 112
# Scores: (min: 96, avg: 126.97, max: 156)
#
# Run: 320, exploration: 0.01, score: 151
# Scores: (min: 96, avg: 127.26, max: 156)
#
# Run: 321, exploration: 0.01, score: 127
# Scores: (min: 96, avg: 127.24, max: 156)
#
# Run: 322, exploration: 0.01, score: 129
# Scores: (min: 96, avg: 127.32, max: 156)
#
# Run: 323, exploration: 0.01, score: 147
# Scores: (min: 96, avg: 127.64, max: 156)
#
# Run: 324, exploration: 0.01, score: 140
# Scores: (min: 96, avg: 127.72, max: 156)
#
# Run: 325, exploration: 0.01, score: 121
# Scores: (min: 96, avg: 127.75, max: 156)
#
# Run: 326, exploration: 0.01, score: 132
# Scores: (min: 96, avg: 127.9, max: 156)
#
# Run: 327, exploration: 0.01, score: 119
# Scores: (min: 96, avg: 127.79, max: 156)
#
# Run: 328, exploration: 0.01, score: 124
# Scores: (min: 96, avg: 127.92, max: 156)
#
# Run: 329, exploration: 0.01, score: 116
# Scores: (min: 96, avg: 127.71, max: 156)
#
# Run: 330, exploration: 0.01, score: 107
# Scores: (min: 96, avg: 127.72, max: 156)
#
# Run: 331, exploration: 0.01, score: 92
# Scores: (min: 92, avg: 127.68, max: 156)
#
# Run: 332, exploration: 0.01, score: 116
# Scores: (min: 92, avg: 127.66, max: 156)
#
# Run: 333, exploration: 0.01, score: 124
# Scores: (min: 92, avg: 127.5, max: 156)
#
# Run: 334, exploration: 0.01, score: 120
# Scores: (min: 92, avg: 127.58, max: 156)
#
# Run: 335, exploration: 0.01, score: 129
# Scores: (min: 92, avg: 127.6, max: 156)
#
# Run: 336, exploration: 0.01, score: 113
# Scores: (min: 92, avg: 127.57, max: 156)
#
# Run: 337, exploration: 0.01, score: 132
# Scores: (min: 92, avg: 127.76, max: 156)
#
# Run: 338, exploration: 0.01, score: 87
# Scores: (min: 87, avg: 127.33, max: 156)
#
# Run: 339, exploration: 0.01, score: 123
# Scores: (min: 87, avg: 127.38, max: 156)
#
# Run: 340, exploration: 0.01, score: 112
# Scores: (min: 87, avg: 127.32, max: 156)
#
# Run: 341, exploration: 0.01, score: 80
# Scores: (min: 80, avg: 126.99, max: 156)
#
# Run: 342, exploration: 0.01, score: 113
# Scores: (min: 80, avg: 126.92, max: 156)
#
# Run: 343, exploration: 0.01, score: 136
# Scores: (min: 80, avg: 127.07, max: 156)
#
# Run: 344, exploration: 0.01, score: 131
# Scores: (min: 80, avg: 127.06, max: 156)
#
# Run: 345, exploration: 0.01, score: 105
# Scores: (min: 80, avg: 126.86, max: 156)
#
# Run: 346, exploration: 0.01, score: 108
# Scores: (min: 80, avg: 126.73, max: 156)
#
# Run: 347, exploration: 0.01, score: 95
# Scores: (min: 80, avg: 126.43, max: 156)
#
# Run: 348, exploration: 0.01, score: 98
# Scores: (min: 80, avg: 126.2, max: 156)
#
# Run: 349, exploration: 0.01, score: 130
# Scores: (min: 80, avg: 126.28, max: 156)
#
# Run: 350, exploration: 0.01, score: 123
# Scores: (min: 80, avg: 126.21, max: 156)
#
# Run: 351, exploration: 0.01, score: 130
# Scores: (min: 80, avg: 126.39, max: 156)
#
# Run: 352, exploration: 0.01, score: 114
# Scores: (min: 80, avg: 126.3, max: 156)
#
# Run: 353, exploration: 0.01, score: 121
# Scores: (min: 80, avg: 126.22, max: 156)
#
# Run: 354, exploration: 0.01, score: 148
# Scores: (min: 80, avg: 126.42, max: 156)
#
# Run: 355, exploration: 0.01, score: 118
# Scores: (min: 80, avg: 126.3, max: 156)
#
# Run: 356, exploration: 0.01, score: 113
# Scores: (min: 80, avg: 126.03, max: 156)
#
# Run: 357, exploration: 0.01, score: 89
# Scores: (min: 80, avg: 125.74, max: 156)
#
# Run: 358, exploration: 0.01, score: 126
# Scores: (min: 80, avg: 125.66, max: 156)
#
# Run: 359, exploration: 0.01, score: 156
# Scores: (min: 80, avg: 126.02, max: 156)
#
# Run: 360, exploration: 0.01, score: 111
# Scores: (min: 80, avg: 125.87, max: 156)
#
# Run: 361, exploration: 0.01, score: 98
# Scores: (min: 80, avg: 125.59, max: 156)
#
# Run: 362, exploration: 0.01, score: 143
# Scores: (min: 80, avg: 125.69, max: 156)
#
# Run: 363, exploration: 0.01, score: 132
# Scores: (min: 80, avg: 125.71, max: 156)
#
# Run: 364, exploration: 0.01, score: 140
# Scores: (min: 80, avg: 125.55, max: 156)
#
# Run: 365, exploration: 0.01, score: 125
# Scores: (min: 80, avg: 125.42, max: 156)
#
# Run: 366, exploration: 0.01, score: 132
# Scores: (min: 80, avg: 125.38, max: 156)
#
# Run: 367, exploration: 0.01, score: 45
# Scores: (min: 45, avg: 124.55, max: 156)
#
# Run: 368, exploration: 0.01, score: 138
# Scores: (min: 45, avg: 124.68, max: 156)
#
# Run: 369, exploration: 0.01, score: 144
# Scores: (min: 45, avg: 124.92, max: 156)
#
# Run: 370, exploration: 0.01, score: 105
# Scores: (min: 45, avg: 124.56, max: 156)
#
# Run: 371, exploration: 0.01, score: 138
# Scores: (min: 45, avg: 124.91, max: 156)
#
# Run: 372, exploration: 0.01, score: 132
# Scores: (min: 45, avg: 124.83, max: 156)
#
# Run: 373, exploration: 0.01, score: 146
# Scores: (min: 45, avg: 125.03, max: 156)
#
# Run: 374, exploration: 0.01, score: 139
# Scores: (min: 45, avg: 125.17, max: 156)
#
# Run: 375, exploration: 0.01, score: 150
# Scores: (min: 45, avg: 125.4, max: 156)
#
# Run: 376, exploration: 0.01, score: 131
# Scores: (min: 45, avg: 125.16, max: 156)
#
# Run: 377, exploration: 0.01, score: 126
# Scores: (min: 45, avg: 125.02, max: 156)
#
# Run: 378, exploration: 0.01, score: 125
# Scores: (min: 45, avg: 124.78, max: 156)
#
# Run: 379, exploration: 0.01, score: 127
# Scores: (min: 45, avg: 124.89, max: 156)
#
# Run: 380, exploration: 0.01, score: 129
# Scores: (min: 45, avg: 124.77, max: 156)
#
# Run: 381, exploration: 0.01, score: 134
# Scores: (min: 45, avg: 124.94, max: 156)
#
# Run: 382, exploration: 0.01, score: 141
# Scores: (min: 45, avg: 124.9, max: 156)
#
# Run: 383, exploration: 0.01, score: 104
# Scores: (min: 45, avg: 124.7, max: 156)
#
# Run: 384, exploration: 0.01, score: 131
# Scores: (min: 45, avg: 124.72, max: 156)
# Run: 385, exploration: 0.01, score: 132
# Scores: (min: 45, avg: 124.79, max: 156)
#
# Run: 386, exploration: 0.01, score: 136
# Scores: (min: 45, avg: 124.95, max: 156)
#
# Run: 387, exploration: 0.01, score: 146
# Scores: (min: 45, avg: 125.07, max: 156)
#
# Run: 388, exploration: 0.01, score: 37
# Scores: (min: 37, avg: 124.26, max: 156)
#
# Run: 389, exploration: 0.01, score: 129
# Scores: (min: 37, avg: 124.39, max: 156)
#
# Run: 390, exploration: 0.01, score: 125
# Scores: (min: 37, avg: 124.23, max: 156)
#
# Run: 391, exploration: 0.01, score: 90
# Scores: (min: 37, avg: 123.88, max: 156)
#
# Run: 392, exploration: 0.01, score: 92
# Scores: (min: 37, avg: 123.38, max: 156)
#
# Run: 393, exploration: 0.01, score: 133
# Scores: (min: 37, avg: 123.31, max: 156)
#
# Run: 394, exploration: 0.01, score: 110
# Scores: (min: 37, avg: 123.25, max: 156)
#
# Run: 395, exploration: 0.01, score: 159
# Scores: (min: 37, avg: 123.5, max: 159)
#
# Run: 396, exploration: 0.01, score: 117
# Scores: (min: 37, avg: 123.32, max: 159)
#
# Run: 397, exploration: 0.01, score: 145
# Scores: (min: 37, avg: 123.38, max: 159)
#
# Run: 398, exploration: 0.01, score: 139
# Scores: (min: 37, avg: 123.41, max: 159)
#
# Run: 399, exploration: 0.01, score: 112
# Scores: (min: 37, avg: 123.31, max: 159)
#
# Run: 400, exploration: 0.01, score: 127
# Scores: (min: 37, avg: 123.4, max: 159)
#
# Run: 401, exploration: 0.01, score: 137
# Scores: (min: 37, avg: 123.5, max: 159)
#
# Run: 402, exploration: 0.01, score: 124
# Scores: (min: 37, avg: 123.5, max: 159)
#
# Run: 403, exploration: 0.01, score: 125
# Scores: (min: 37, avg: 123.31, max: 159)
#
# Run: 404, exploration: 0.01, score: 135
# Scores: (min: 37, avg: 123.28, max: 159)
#
# Run: 405, exploration: 0.01, score: 129
# Scores: (min: 37, avg: 123.03, max: 159)
#
# Run: 406, exploration: 0.01, score: 144
# Scores: (min: 37, avg: 123.21, max: 159)
#
# Run: 407, exploration: 0.01, score: 169
# Scores: (min: 37, avg: 123.45, max: 169)
#
# Run: 408, exploration: 0.01, score: 193
# Scores: (min: 37, avg: 124.2, max: 193)
#
# Run: 409, exploration: 0.01, score: 127
# Scores: (min: 37, avg: 124.07, max: 193)
#
# Run: 410, exploration: 0.01, score: 12
# Scores: (min: 12, avg: 122.93, max: 193)
#
# Run: 411, exploration: 0.01, score: 124
# Scores: (min: 12, avg: 122.95, max: 193)
#
# Run: 412, exploration: 0.01, score: 135
# Scores: (min: 12, avg: 123.08, max: 193)
#
# Run: 413, exploration: 0.01, score: 113
# Scores: (min: 12, avg: 122.94, max: 193)
#
# Run: 414, exploration: 0.01, score: 134
# Scores: (min: 12, avg: 122.94, max: 193)
#
# Run: 415, exploration: 0.01, score: 160
# Scores: (min: 12, avg: 123.39, max: 193)
#
# Run: 416, exploration: 0.01, score: 138
# Scores: (min: 12, avg: 123.72, max: 193)
#
# Run: 417, exploration: 0.01, score: 151
# Scores: (min: 12, avg: 123.74, max: 193)
#
# Run: 418, exploration: 0.01, score: 127
# Scores: (min: 12, avg: 123.79, max: 193)
#
# Run: 419, exploration: 0.01, score: 127
# Scores: (min: 12, avg: 123.94, max: 193)
#
# Run: 420, exploration: 0.01, score: 135
# Scores: (min: 12, avg: 123.78, max: 193)
#
# Run: 421, exploration: 0.01, score: 118
# Scores: (min: 12, avg: 123.69, max: 193)
#
# Run: 422, exploration: 0.01, score: 124
# Scores: (min: 12, avg: 123.64, max: 193)
#
# Run: 423, exploration: 0.01, score: 117
# Scores: (min: 12, avg: 123.34, max: 193)
#
# Run: 424, exploration: 0.01, score: 146
# Scores: (min: 12, avg: 123.4, max: 193)
#
# Run: 425, exploration: 0.01, score: 127
# Scores: (min: 12, avg: 123.46, max: 193)
#
# Run: 426, exploration: 0.01, score: 116
# Scores: (min: 12, avg: 123.3, max: 193)
#
# Run: 427, exploration: 0.01, score: 160
# Scores: (min: 12, avg: 123.71, max: 193)
#
# Run: 428, exploration: 0.01, score: 130
# Scores: (min: 12, avg: 123.77, max: 193)
#
# Run: 429, exploration: 0.01, score: 143
# Scores: (min: 12, avg: 124.04, max: 193)
#
# Run: 430, exploration: 0.01, score: 163
# Scores: (min: 12, avg: 124.6, max: 193)
#
# Run: 431, exploration: 0.01, score: 104
# Scores: (min: 12, avg: 124.72, max: 193)
#
# Run: 432, exploration: 0.01, score: 135
# Scores: (min: 12, avg: 124.91, max: 193)
#
# Run: 433, exploration: 0.01, score: 121
# Scores: (min: 12, avg: 124.88, max: 193)
#
# Run: 434, exploration: 0.01, score: 133
# Scores: (min: 12, avg: 125.01, max: 193)
#
# Run: 435, exploration: 0.01, score: 163
# Scores: (min: 12, avg: 125.35, max: 193)
#
# Run: 436, exploration: 0.01, score: 150
# Scores: (min: 12, avg: 125.72, max: 193)
#
# Run: 437, exploration: 0.01, score: 145
# Scores: (min: 12, avg: 125.85, max: 193)
#
# Run: 438, exploration: 0.01, score: 158
# Scores: (min: 12, avg: 126.56, max: 193)
#
# Run: 439, exploration: 0.01, score: 150
# Scores: (min: 12, avg: 126.83, max: 193)
#
# Run: 440, exploration: 0.01, score: 187
# Scores: (min: 12, avg: 127.58, max: 193)
#
# Run: 441, exploration: 0.01, score: 144
# Scores: (min: 12, avg: 128.22, max: 193)
#
# Run: 442, exploration: 0.01, score: 123
# Scores: (min: 12, avg: 128.32, max: 193)
#
# Run: 443, exploration: 0.01, score: 108
# Scores: (min: 12, avg: 128.04, max: 193)
#
# Run: 444, exploration: 0.01, score: 153
# Scores: (min: 12, avg: 128.26, max: 193)
#
# Run: 445, exploration: 0.01, score: 122
# Scores: (min: 12, avg: 128.43, max: 193)
#
# Run: 446, exploration: 0.01, score: 134
# Scores: (min: 12, avg: 128.69, max: 193)
#
# Run: 447, exploration: 0.01, score: 131
# Scores: (min: 12, avg: 129.05, max: 193)
#
# Run: 448, exploration: 0.01, score: 137
# Scores: (min: 12, avg: 129.44, max: 193)
#
# Run: 449, exploration: 0.01, score: 163
# Scores: (min: 12, avg: 129.77, max: 193)
#
# Run: 450, exploration: 0.01, score: 133
# Scores: (min: 12, avg: 129.87, max: 193)
#
# Run: 451, exploration: 0.01, score: 142
# Scores: (min: 12, avg: 129.99, max: 193)
#
# Run: 452, exploration: 0.01, score: 115
# Scores: (min: 12, avg: 130, max: 193)
#
# Run: 453, exploration: 0.01, score: 133
# Scores: (min: 12, avg: 130.12, max: 193)
#
# Run: 454, exploration: 0.01, score: 141
# Scores: (min: 12, avg: 130.05, max: 193)
#
# Run: 455, exploration: 0.01, score: 118
# Scores: (min: 12, avg: 130.05, max: 193)
#
# Run: 456, exploration: 0.01, score: 124
# Scores: (min: 12, avg: 130.16, max: 193)
#
# Run: 457, exploration: 0.01, score: 122
# Scores: (min: 12, avg: 130.49, max: 193)
#
# Run: 458, exploration: 0.01, score: 121
# Scores: (min: 12, avg: 130.44, max: 193)
#
# Run: 459, exploration: 0.01, score: 103
# Scores: (min: 12, avg: 129.91, max: 193)
#
# Run: 460, exploration: 0.01, score: 142
# Scores: (min: 12, avg: 130.22, max: 193)
#
# Run: 461, exploration: 0.01, score: 116
# Scores: (min: 12, avg: 130.4, max: 193)
#
# Run: 462, exploration: 0.01, score: 118
# Scores: (min: 12, avg: 130.15, max: 193)
#
# Run: 463, exploration: 0.01, score: 132
# Scores: (min: 12, avg: 130.15, max: 193)
#
# Run: 464, exploration: 0.01, score: 128
# Scores: (min: 12, avg: 130.03, max: 193)
#
# Run: 465, exploration: 0.01, score: 138
# Scores: (min: 12, avg: 130.16, max: 193)
#
# Run: 466, exploration: 0.01, score: 78
# Scores: (min: 12, avg: 129.62, max: 193)
#
# Run: 467, exploration: 0.01, score: 148
# Scores: (min: 12, avg: 130.65, max: 193)
#
# Run: 468, exploration: 0.01, score: 145
# Scores: (min: 12, avg: 130.72, max: 193)
#
# Run: 469, exploration: 0.01, score: 158
# Scores: (min: 12, avg: 130.86, max: 193)
#
# Run: 470, exploration: 0.01, score: 124
# Scores: (min: 12, avg: 131.05, max: 193)
#
# Run: 471, exploration: 0.01, score: 131
# Scores: (min: 12, avg: 130.98, max: 193)
#
# Run: 472, exploration: 0.01, score: 142
# Scores: (min: 12, avg: 131.08, max: 193)
#
# Run: 473, exploration: 0.01, score: 139
# Scores: (min: 12, avg: 131.01, max: 193)
#
# Run: 474, exploration: 0.01, score: 80
# Scores: (min: 12, avg: 130.42, max: 193)
#
# Run: 475, exploration: 0.01, score: 134
# Scores: (min: 12, avg: 130.26, max: 193)
#
# Run: 476, exploration: 0.01, score: 151
# Scores: (min: 12, avg: 130.46, max: 193)
#
# Run: 477, exploration: 0.01, score: 147
# Scores: (min: 12, avg: 130.67, max: 193)
#
# Run: 478, exploration: 0.01, score: 166
# Scores: (min: 12, avg: 131.08, max: 193)
#
# Run: 479, exploration: 0.01, score: 187
# Scores: (min: 12, avg: 131.68, max: 193)
#
# Run: 480, exploration: 0.01, score: 142
# Scores: (min: 12, avg: 131.81, max: 193)
#
# Run: 481, exploration: 0.01, score: 139
# Scores: (min: 12, avg: 131.86, max: 193)
#
# Run: 482, exploration: 0.01, score: 131
# Scores: (min: 12, avg: 131.76, max: 193)
#
# Run: 483, exploration: 0.01, score: 130
# Scores: (min: 12, avg: 132.02, max: 193)
#
# Run: 484, exploration: 0.01, score: 111
# Scores: (min: 12, avg: 131.82, max: 193)
#
# Run: 485, exploration: 0.01, score: 138
# Scores: (min: 12, avg: 131.88, max: 193)
# Run: 486, exploration: 0.01, score: 150
# Scores: (min: 12, avg: 132.02, max: 193)
#
# Run: 487, exploration: 0.01, score: 128
# Scores: (min: 12, avg: 131.84, max: 193)
#
# Run: 488, exploration: 0.01, score: 124
# Scores: (min: 12, avg: 132.71, max: 193)
#
# Run: 489, exploration: 0.01, score: 60
# Scores: (min: 12, avg: 132.02, max: 193)
#
# Run: 490, exploration: 0.01, score: 132
# Scores: (min: 12, avg: 132.09, max: 193)
#
# Run: 491, exploration: 0.01, score: 132
# Scores: (min: 12, avg: 132.51, max: 193)
#
# Run: 492, exploration: 0.01, score: 143
# Scores: (min: 12, avg: 133.02, max: 193)
#
# Run: 493, exploration: 0.01, score: 123
# Scores: (min: 12, avg: 132.92, max: 193)
#
# Run: 494, exploration: 0.01, score: 128
# Scores: (min: 12, avg: 133.1, max: 193)
#
# Run: 495, exploration: 0.01, score: 169
# Scores: (min: 12, avg: 133.2, max: 193)
#
# Run: 496, exploration: 0.01, score: 139
# Scores: (min: 12, avg: 133.42, max: 193)
#
# Run: 497, exploration: 0.01, score: 185
# Scores: (min: 12, avg: 133.82, max: 193)
#
# Run: 498, exploration: 0.01, score: 166
# Scores: (min: 12, avg: 134.09, max: 193)
#
# Run: 499, exploration: 0.01, score: 142
# Scores: (min: 12, avg: 134.39, max: 193)
#
# Run: 500, exploration: 0.01, score: 142
# Scores: (min: 12, avg: 134.54, max: 193)
#
# Run: 501, exploration: 0.01, score: 108
# Scores: (min: 12, avg: 134.25, max: 193)
#
# Run: 502, exploration: 0.01, score: 120
# Scores: (min: 12, avg: 134.21, max: 193)
#
# Run: 503, exploration: 0.01, score: 145
# Scores: (min: 12, avg: 134.41, max: 193)
#
# Run: 504, exploration: 0.01, score: 134
# Scores: (min: 12, avg: 134.4, max: 193)
#
# Run: 505, exploration: 0.01, score: 133
# Scores: (min: 12, avg: 134.44, max: 193)
#
# Run: 506, exploration: 0.01, score: 154
# Scores: (min: 12, avg: 134.54, max: 193)
#
# Run: 507, exploration: 0.01, score: 131
# Scores: (min: 12, avg: 134.16, max: 193)
#
# Run: 508, exploration: 0.01, score: 112
# Scores: (min: 12, avg: 133.35, max: 187)
#
# Run: 509, exploration: 0.01, score: 52
# Scores: (min: 12, avg: 132.6, max: 187)
#
# Run: 510, exploration: 0.01, score: 113
# Scores: (min: 52, avg: 133.61, max: 187)
#
# Run: 511, exploration: 0.01, score: 132
# Scores: (min: 52, avg: 133.69, max: 187)
#
# Run: 512, exploration: 0.01, score: 135
# Scores: (min: 52, avg: 133.69, max: 187)
#
# Run: 513, exploration: 0.01, score: 141
# Scores: (min: 52, avg: 133.97, max: 187)
#
# Run: 514, exploration: 0.01, score: 167
# Scores: (min: 52, avg: 134.3, max: 187)
#
# Run: 515, exploration: 0.01, score: 149
# Scores: (min: 52, avg: 134.19, max: 187)
#
# Run: 516, exploration: 0.01, score: 164
# Scores: (min: 52, avg: 134.45, max: 187)
#
# Run: 517, exploration: 0.01, score: 124
# Scores: (min: 52, avg: 134.18, max: 187)
#
# Run: 518, exploration: 0.01, score: 121
# Scores: (min: 52, avg: 134.12, max: 187)
#
# Run: 519, exploration: 0.01, score: 133
# Scores: (min: 52, avg: 134.18, max: 187)
#
# Run: 520, exploration: 0.01, score: 112
# Scores: (min: 52, avg: 133.95, max: 187)
#
# Run: 521, exploration: 0.01, score: 90
# Scores: (min: 52, avg: 133.67, max: 187)
#
# Run: 522, exploration: 0.01, score: 131
# Scores: (min: 52, avg: 133.74, max: 187)
#
# Run: 523, exploration: 0.01, score: 120
# Scores: (min: 52, avg: 133.77, max: 187)
#
# Run: 524, exploration: 0.01, score: 147
# Scores: (min: 52, avg: 133.78, max: 187)
#
# Run: 525, exploration: 0.01, score: 186
# Scores: (min: 52, avg: 134.37, max: 187)
#
# Run: 526, exploration: 0.01, score: 151
# Scores: (min: 52, avg: 134.72, max: 187)
#
# Run: 527, exploration: 0.01, score: 146
# Scores: (min: 52, avg: 134.58, max: 187)
#
# Run: 528, exploration: 0.01, score: 148
# Scores: (min: 52, avg: 134.76, max: 187)
#
# Run: 529, exploration: 0.01, score: 130
# Scores: (min: 52, avg: 134.63, max: 187)
#
# Run: 530, exploration: 0.01, score: 171
# Scores: (min: 52, avg: 134.71, max: 187)
#
# Run: 531, exploration: 0.01, score: 139
# Scores: (min: 52, avg: 135.06, max: 187)
#
# Run: 532, exploration: 0.01, score: 182
# Scores: (min: 52, avg: 135.53, max: 187)
#
# Run: 533, exploration: 0.01, score: 132
# Scores: (min: 52, avg: 135.64, max: 187)
#
# Run: 534, exploration: 0.01, score: 131
# Scores: (min: 52, avg: 135.62, max: 187)
#
# Run: 535, exploration: 0.01, score: 140
# Scores: (min: 52, avg: 135.39, max: 187)
#
# Run: 536, exploration: 0.01, score: 138
# Scores: (min: 52, avg: 135.27, max: 187)
#
# Run: 537, exploration: 0.01, score: 146
# Scores: (min: 52, avg: 135.28, max: 187)
#
# Run: 538, exploration: 0.01, score: 144
# Scores: (min: 52, avg: 135.14, max: 187)
#
# Run: 539, exploration: 0.01, score: 147
# Scores: (min: 52, avg: 135.11, max: 187)
#
# Run: 540, exploration: 0.01, score: 130
# Scores: (min: 52, avg: 134.54, max: 187)
#
# Run: 541, exploration: 0.01, score: 227
# Scores: (min: 52, avg: 135.37, max: 227)
#
# Run: 542, exploration: 0.01, score: 150
# Scores: (min: 52, avg: 135.64, max: 227)
#
# Run: 543, exploration: 0.01, score: 128
# Scores: (min: 52, avg: 135.84, max: 227)
#
# Run: 544, exploration: 0.01, score: 123
# Scores: (min: 52, avg: 135.54, max: 227)
#
# Run: 545, exploration: 0.01, score: 128
# Scores: (min: 52, avg: 135.6, max: 227)
#
# Run: 546, exploration: 0.01, score: 133
# Scores: (min: 52, avg: 135.59, max: 227)
#
# Run: 547, exploration: 0.01, score: 148
# Scores: (min: 52, avg: 135.76, max: 227)
#
# Run: 548, exploration: 0.01, score: 210
# Scores: (min: 52, avg: 136.49, max: 227)
#
# Run: 549, exploration: 0.01, score: 136
# Scores: (min: 52, avg: 136.22, max: 227)
#
# Run: 550, exploration: 0.01, score: 150
# Scores: (min: 52, avg: 136.39, max: 227)
#
# Run: 551, exploration: 0.01, score: 141
# Scores: (min: 52, avg: 136.38, max: 227)
#
# Run: 552, exploration: 0.01, score: 170
# Scores: (min: 52, avg: 136.93, max: 227)
#
# Run: 553, exploration: 0.01, score: 138
# Scores: (min: 52, avg: 136.98, max: 227)
#
# Run: 554, exploration: 0.01, score: 131
# Scores: (min: 52, avg: 136.88, max: 227)
#
# Run: 555, exploration: 0.01, score: 147
# Scores: (min: 52, avg: 137.17, max: 227)
#
# Run: 556, exploration: 0.01, score: 165
# Scores: (min: 52, avg: 137.58, max: 227)
#
# Run: 557, exploration: 0.01, score: 157
# Scores: (min: 52, avg: 137.93, max: 227)
#
# Run: 558, exploration: 0.01, score: 124
# Scores: (min: 52, avg: 137.96, max: 227)
#
# Run: 559, exploration: 0.01, score: 142
# Scores: (min: 52, avg: 138.35, max: 227)
#
# Run: 560, exploration: 0.01, score: 148
# Scores: (min: 52, avg: 138.41, max: 227)
#
# Run: 561, exploration: 0.01, score: 154
# Scores: (min: 52, avg: 138.79, max: 227)
#
# Run: 562, exploration: 0.01, score: 141
# Scores: (min: 52, avg: 139.02, max: 227)
#
# Run: 563, exploration: 0.01, score: 130
# Scores: (min: 52, avg: 139, max: 227)
#
# Run: 564, exploration: 0.01, score: 183
# Scores: (min: 52, avg: 139.55, max: 227)
#
# Run: 565, exploration: 0.01, score: 173
# Scores: (min: 52, avg: 139.9, max: 227)
#
# Run: 566, exploration: 0.01, score: 143
# Scores: (min: 52, avg: 140.55, max: 227)
#
# Run: 567, exploration: 0.01, score: 90
# Scores: (min: 52, avg: 139.97, max: 227)
#
# Run: 568, exploration: 0.01, score: 213
# Scores: (min: 52, avg: 140.65, max: 227)
#
# ...
# Scores: (min: 57, avg: 151.83, max: 438)
#
# Run: 644, exploration: 0.01, score: 33
# Scores: (min: 33, avg: 150.93, max: 438)
#
# Run: 645, exploration: 0.01, score: 239
# Scores: (min: 33, avg: 152.04, max: 438)
#
# Run: 646, exploration: 0.01, score: 201
# Scores: (min: 33, avg: 152.72, max: 438)
#
# Run: 647, exploration: 0.01, score: 170
# Scores: (min: 33, avg: 152.94, max: 438)
#
# Run: 648, exploration: 0.01, score: 137
# Scores: (min: 33, avg: 152.21, max: 438)
#
# Run: 649, exploration: 0.01, score: 137
# Scores: (min: 33, avg: 152.22, max: 438)
#
# Run: 650, exploration: 0.01, score: 109
# Scores: (min: 33, avg: 151.81, max: 438)
#
# Run: 651, exploration: 0.01, score: 212
# Scores: (min: 33, avg: 152.52, max: 438)
#
# Run: 652, exploration: 0.01, score: 379
# Scores: (min: 33, avg: 154.61, max: 438)
#
# Run: 653, exploration: 0.01, score: 211
# Scores: (min: 33, avg: 155.34, max: 438)
#
# Run: 654, exploration: 0.01, score: 93
# Scores: (min: 33, avg: 154.96, max: 438)
#
# Run: 655, exploration: 0.01, score: 136
# Scores: (min: 33, avg: 154.85, max: 438)
#
# Run: 656, exploration: 0.01, score: 147
# Scores: (min: 33, avg: 154.67, max: 438)
#
# Run: 657, exploration: 0.01, score: 107
# Scores: (min: 33, avg: 154.17, max: 438)
#
# Run: 658, exploration: 0.01, score: 305
# Scores: (min: 33, avg: 155.98, max: 438)
#
# Run: 659, exploration: 0.01, score: 134
# Scores: (min: 33, avg: 155.9, max: 438)
#
# Run: 660, exploration: 0.01, score: 137
# Scores: (min: 33, avg: 155.79, max: 438)
#
# Run: 661, exploration: 0.01, score: 160
# Scores: (min: 33, avg: 155.85, max: 438)
#
# Run: 662, exploration: 0.01, score: 108
# Scores: (min: 33, avg: 155.52, max: 438)
#
# Run: 663, exploration: 0.01, score: 389
# Scores: (min: 33, avg: 158.11, max: 438)
#
# Run: 664, exploration: 0.01, score: 134
# Scores: (min: 33, avg: 157.62, max: 438)
#
# Run: 665, exploration: 0.01, score: 101
# Scores: (min: 33, avg: 156.9, max: 438)
#
# Run: 666, exploration: 0.01, score: 218
# Scores: (min: 33, avg: 157.65, max: 438)
#
# Run: 667, exploration: 0.01, score: 149
# Scores: (min: 33, avg: 158.24, max: 438)
#
# Run: 668, exploration: 0.01, score: 111
# Scores: (min: 33, avg: 157.22, max: 438)
#
# Run: 669, exploration: 0.01, score: 16
# Scores: (min: 16, avg: 156.34, max: 438)
#
# Run: 670, exploration: 0.01, score: 15
# Scores: (min: 15, avg: 155.11, max: 438)
#
# Run: 671, exploration: 0.01, score: 16
# Scores: (min: 15, avg: 153.62, max: 438)
#
# Run: 672, exploration: 0.01, score: 21
# Scores: (min: 15, avg: 152.3, max: 438)
#
# Run: 673, exploration: 0.01, score: 93
# Scores: (min: 15, avg: 151.98, max: 438)
#
# Run: 674, exploration: 0.01, score: 92
# Scores: (min: 15, avg: 151.33, max: 438)
#
# Run: 675, exploration: 0.01, score: 125
# Scores: (min: 15, avg: 151.09, max: 438)
#
# Run: 676, exploration: 0.01, score: 270
# Scores: (min: 15, avg: 152.37, max: 438)
#
# Run: 677, exploration: 0.01, score: 42
# Scores: (min: 15, avg: 151.35, max: 438)
#
# Run: 678, exploration: 0.01, score: 110
# Scores: (min: 15, avg: 150.95, max: 438)
#
# Run: 679, exploration: 0.01, score: 180
# Scores: (min: 15, avg: 151.49, max: 438)
#
# Run: 680, exploration: 0.01, score: 206
# Scores: (min: 15, avg: 151.35, max: 438)
#
# Run: 681, exploration: 0.01, score: 500
# Scores: (min: 15, avg: 155.03, max: 500)
#
# Run: 682, exploration: 0.01, score: 153
# Scores: (min: 15, avg: 155.17, max: 500)
#
# Run: 683, exploration: 0.01, score: 425
# Scores: (min: 15, avg: 157.95, max: 500)
#
# Run: 684, exploration: 0.01, score: 201
# Scores: (min: 15, avg: 158.37, max: 500)
#
# Run: 685, exploration: 0.01, score: 64
# Scores: (min: 15, avg: 157.53, max: 500)
#
# Run: 686, exploration: 0.01, score: 157
# Scores: (min: 15, avg: 157.86, max: 500)
#
# Run: 687, exploration: 0.01, score: 371
# Scores: (min: 15, avg: 160.46, max: 500)
# Run: 688, exploration: 0.01, score: 198
# Scores: (min: 15, avg: 161.01, max: 500)
#
# Run: 689, exploration: 0.01, score: 100
# Scores: (min: 15, avg: 160.7, max: 500)
#
# Run: 690, exploration: 0.01, score: 134
# Scores: (min: 15, avg: 160.8, max: 500)
#
# Run: 691, exploration: 0.01, score: 187
# Scores: (min: 15, avg: 161.39, max: 500)
#
# Run: 692, exploration: 0.01, score: 100
# Scores: (min: 15, avg: 161.06, max: 500)
#
# Run: 693, exploration: 0.01, score: 370
# Scores: (min: 15, avg: 163.31, max: 500)
#
# Run: 694, exploration: 0.01, score: 111
# Scores: (min: 15, avg: 163.14, max: 500)
#
# Run: 695, exploration: 0.01, score: 145
# Scores: (min: 15, avg: 163.18, max: 500)
#
# Run: 696, exploration: 0.01, score: 258
# Scores: (min: 15, avg: 163.65, max: 500)
#
# Run: 697, exploration: 0.01, score: 302
# Scores: (min: 15, avg: 166.1, max: 500)
#
# Run: 698, exploration: 0.01, score: 225
# Scores: (min: 15, avg: 166.66, max: 500)
#
# Run: 699, exploration: 0.01, score: 128
# Scores: (min: 15, avg: 166.56, max: 500)
#
# Run: 700, exploration: 0.01, score: 77
# Scores: (min: 15, avg: 165.17, max: 500)
#
# Run: 701, exploration: 0.01, score: 123
# Scores: (min: 15, avg: 164.87, max: 500)
#
# Run: 702, exploration: 0.01, score: 160
# Scores: (min: 15, avg: 165.05, max: 500)
#
# Run: 703, exploration: 0.01, score: 106
# Scores: (min: 15, avg: 164.95, max: 500)
#
# Run: 704, exploration: 0.01, score: 107
# Scores: (min: 15, avg: 164.8, max: 500)
#
# Run: 705, exploration: 0.01, score: 113
# Scores: (min: 15, avg: 164.61, max: 500)
#
# Run: 706, exploration: 0.01, score: 135
# Scores: (min: 15, avg: 164.41, max: 500)
#
# Run: 707, exploration: 0.01, score: 278
# Scores: (min: 15, avg: 165.85, max: 500)
#
# Run: 708, exploration: 0.01, score: 109
# Scores: (min: 15, avg: 165.09, max: 500)
#
# Run: 709, exploration: 0.01, score: 194
# Scores: (min: 15, avg: 165.67, max: 500)
#
# Run: 710, exploration: 0.01, score: 119
# Scores: (min: 15, avg: 165.89, max: 500)
#
# Run: 711, exploration: 0.01, score: 98
# Scores: (min: 15, avg: 165.13, max: 500)
#
# Run: 712, exploration: 0.01, score: 104
# Scores: (min: 15, avg: 164.83, max: 500)
#
# Run: 713, exploration: 0.01, score: 12
# Scores: (min: 12, avg: 163.73, max: 500)
#
# Run: 714, exploration: 0.01, score: 21
# Scores: (min: 12, avg: 162.52, max: 500)
#
# Run: 715, exploration: 0.01, score: 17
# Scores: (min: 12, avg: 161.08, max: 500)
#
# Run: 716, exploration: 0.01, score: 16
# Scores: (min: 12, avg: 160.22, max: 500)
#
# Run: 717, exploration: 0.01, score: 17
# Scores: (min: 12, avg: 156.01, max: 500)
#
# Run: 718, exploration: 0.01, score: 20
# Scores: (min: 12, avg: 154.95, max: 500)
#
# Run: 719, exploration: 0.01, score: 21
# Scores: (min: 12, avg: 154.24, max: 500)
#
# Run: 720, exploration: 0.01, score: 18
# Scores: (min: 12, avg: 153.22, max: 500)
#
# Run: 721, exploration: 0.01, score: 112
# Scores: (min: 12, avg: 153.07, max: 500)
#
# Run: 722, exploration: 0.01, score: 187
# Scores: (min: 12, avg: 153.91, max: 500)
#
# Run: 723, exploration: 0.01, score: 13
# Scores: (min: 12, avg: 152.66, max: 500)
#
# Run: 724, exploration: 0.01, score: 20
# Scores: (min: 12, avg: 151.08, max: 500)
#
# Run: 725, exploration: 0.01, score: 93
# Scores: (min: 12, avg: 150.21, max: 500)
#
# Run: 726, exploration: 0.01, score: 155
# Scores: (min: 12, avg: 150.83, max: 500)
#
# Run: 727, exploration: 0.01, score: 249
# Scores: (min: 12, avg: 151.57, max: 500)
#
# Run: 728, exploration: 0.01, score: 12
# Scores: (min: 12, avg: 150.37, max: 500)
#
# Run: 729, exploration: 0.01, score: 92
# Scores: (min: 12, avg: 148.91, max: 500)
#
# Run: 730, exploration: 0.01, score: 10
# Scores: (min: 10, avg: 147.73, max: 500)
#
# Run: 731, exploration: 0.01, score: 33
# Scores: (min: 10, avg: 146.77, max: 500)
#
# Run: 732, exploration: 0.01, score: 162
# Scores: (min: 10, avg: 147.31, max: 500)
#
# Run: 733, exploration: 0.01, score: 138
# Scores: (min: 10, avg: 147.11, max: 500)
#
# Run: 734, exploration: 0.01, score: 255
# Scores: (min: 10, avg: 147.38, max: 500)
#
# Run: 735, exploration: 0.01, score: 72
# Scores: (min: 10, avg: 144.77, max: 500)
#
# Run: 736, exploration: 0.01, score: 141
# Scores: (min: 10, avg: 144.71, max: 500)
#
# Run: 737, exploration: 0.01, score: 192
# Scores: (min: 10, avg: 145.35, max: 500)
#
# Run: 738, exploration: 0.01, score: 100
# Scores: (min: 10, avg: 144.99, max: 500)
#
# Run: 739, exploration: 0.01, score: 235
# Scores: (min: 10, avg: 145.52, max: 500)
#
# Run: 740, exploration: 0.01, score: 262
# Scores: (min: 10, avg: 146.76, max: 500)
#
# Run: 741, exploration: 0.01, score: 227
# Scores: (min: 10, avg: 146.2, max: 500)
#
# Run: 742, exploration: 0.01, score: 500
# Scores: (min: 10, avg: 148.27, max: 500)
#
# Run: 743, exploration: 0.01, score: 162
# Scores: (min: 10, avg: 148.59, max: 500)
#
# Run: 744, exploration: 0.01, score: 353
# Scores: (min: 10, avg: 151.79, max: 500)
#
# Run: 745, exploration: 0.01, score: 128
# Scores: (min: 10, avg: 150.68, max: 500)
#
# Run: 746, exploration: 0.01, score: 177
# Scores: (min: 10, avg: 150.44, max: 500)
#
# Run: 747, exploration: 0.01, score: 150
# Scores: (min: 10, avg: 150.24, max: 500)
#
# Run: 748, exploration: 0.01, score: 177
# Scores: (min: 10, avg: 150.64, max: 500)
#
# Run: 749, exploration: 0.01, score: 174
# Scores: (min: 10, avg: 151.01, max: 500)
#
# Run: 750, exploration: 0.01, score: 124
# Scores: (min: 10, avg: 151.16, max: 500)
#
# Run: 751, exploration: 0.01, score: 228
# Scores: (min: 10, avg: 151.32, max: 500)
#
# Run: 752, exploration: 0.01, score: 193
# Scores: (min: 10, avg: 149.46, max: 500)
#
# Run: 753, exploration: 0.01, score: 168
# Scores: (min: 10, avg: 149.03, max: 500)
#
# Run: 754, exploration: 0.01, score: 416
# Scores: (min: 10, avg: 152.26, max: 500)
#
# Run: 755, exploration: 0.01, score: 122
# Scores: (min: 10, avg: 152.12, max: 500)
#
# Run: 756, exploration: 0.01, score: 120
# Scores: (min: 10, avg: 151.85, max: 500)
#
# Run: 757, exploration: 0.01, score: 500
# Scores: (min: 10, avg: 155.78, max: 500)
#
# Run: 758, exploration: 0.01, score: 109
# Scores: (min: 10, avg: 153.82, max: 500)
#
# Run: 759, exploration: 0.01, score: 138
# Scores: (min: 10, avg: 153.86, max: 500)
#
# Run: 760, exploration: 0.01, score: 149
# Scores: (min: 10, avg: 153.98, max: 500)
#
# Run: 761, exploration: 0.01, score: 148
# Scores: (min: 10, avg: 153.86, max: 500)
#
# Run: 762, exploration: 0.01, score: 312
# Scores: (min: 10, avg: 155.9, max: 500)
#
# Run: 763, exploration: 0.01, score: 154
# Scores: (min: 10, avg: 153.55, max: 500)
#
# Run: 764, exploration: 0.01, score: 199
# Scores: (min: 10, avg: 154.2, max: 500)
#
# Run: 765, exploration: 0.01, score: 198
# Scores: (min: 10, avg: 155.17, max: 500)
#
# Run: 766, exploration: 0.01, score: 358
# Scores: (min: 10, avg: 156.57, max: 500)
#
# Run: 767, exploration: 0.01, score: 235
# Scores: (min: 10, avg: 157.43, max: 500)
#
# Run: 768, exploration: 0.01, score: 207
# Scores: (min: 10, avg: 158.39, max: 500)
#
# Run: 769, exploration: 0.01, score: 25
# Scores: (min: 10, avg: 158.48, max: 500)
#
# Run: 770, exploration: 0.01, score: 17
# Scores: (min: 10, avg: 158.5, max: 500)
#
# Run: 771, exploration: 0.01, score: 11
# Scores: (min: 10, avg: 158.45, max: 500)
#
# Run: 772, exploration: 0.01, score: 109
# Scores: (min: 10, avg: 159.33, max: 500)
#
# Run: 773, exploration: 0.01, score: 108
# Scores: (min: 10, avg: 159.48, max: 500)
#
# Run: 774, exploration: 0.01, score: 75
# Scores: (min: 10, avg: 159.31, max: 500)
#
# Run: 775, exploration: 0.01, score: 287
# Scores: (min: 10, avg: 160.93, max: 500)
#
# Run: 776, exploration: 0.01, score: 51
# Scores: (min: 10, avg: 158.74, max: 500)
#
# Run: 777, exploration: 0.01, score: 98
# Scores: (min: 10, avg: 159.3, max: 500)
#
# Run: 778, exploration: 0.01, score: 208
# Scores: (min: 10, avg: 160.28, max: 500)
#
# Run: 779, exploration: 0.01, score: 168
# Scores: (min: 10, avg: 160.16, max: 500)
#
# Run: 780, exploration: 0.01, score: 130
# Scores: (min: 10, avg: 159.4, max: 500)
#
# Run: 781, exploration: 0.01, score: 121
# Scores: (min: 10, avg: 155.61, max: 500)
#
# Run: 782, exploration: 0.01, score: 128
# Scores: (min: 10, avg: 155.36, max: 500)
#
# Run: 783, exploration: 0.01, score: 160
# Scores: (min: 10, avg: 152.71, max: 500)
#
# Run: 784, exploration: 0.01, score: 215
# Scores: (min: 10, avg: 152.85, max: 500)
#
# Run: 785, exploration: 0.01, score: 136
# Scores: (min: 10, avg: 153.57, max: 500)
#
# Run: 786, exploration: 0.01, score: 500
# Scores: (min: 10, avg: 157, max: 500)
#
# Run: 787, exploration: 0.01, score: 172
# Scores: (min: 10, avg: 155.01, max: 500)
#
# Run: 788, exploration: 0.01, score: 371
# Scores: (min: 10, avg: 156.74, max: 500)
# Run: 789, exploration: 0.01, score: 197
# Scores: (min: 10, avg: 157.71, max: 500)
#
# Run: 790, exploration: 0.01, score: 500
# Scores: (min: 10, avg: 161.37, max: 500)
#
# Run: 791, exploration: 0.01, score: 108
# Scores: (min: 10, avg: 160.58, max: 500)
#
# Run: 792, exploration: 0.01, score: 440
# Scores: (min: 10, avg: 163.98, max: 500)
#
# Run: 793, exploration: 0.01, score: 171
# Scores: (min: 10, avg: 161.99, max: 500)
#
# Run: 794, exploration: 0.01, score: 201
# Scores: (min: 10, avg: 162.89, max: 500)
#
# Run: 795, exploration: 0.01, score: 130
# Scores: (min: 10, avg: 162.74, max: 500)
#
# Run: 796, exploration: 0.01, score: 490
# Scores: (min: 10, avg: 165.06, max: 500)
#
# Run: 797, exploration: 0.01, score: 137
# Scores: (min: 10, avg: 163.41, max: 500)
#
# Run: 798, exploration: 0.01, score: 145
# Scores: (min: 10, avg: 162.61, max: 500)
#
# Run: 799, exploration: 0.01, score: 107
# Scores: (min: 10, avg: 162.4, max: 500)
#
# Run: 800, exploration: 0.01, score: 226
# Scores: (min: 10, avg: 163.89, max: 500)
#
# Run: 801, exploration: 0.01, score: 162
# Scores: (min: 10, avg: 164.28, max: 500)
#
# Run: 802, exploration: 0.01, score: 273
# Scores: (min: 10, avg: 165.41, max: 500)
#
# Run: 803, exploration: 0.01, score: 142
# Scores: (min: 10, avg: 165.77, max: 500)
#
# Run: 804, exploration: 0.01, score: 500
# Scores: (min: 10, avg: 169.7, max: 500)
#
# Run: 805, exploration: 0.01, score: 77
# Scores: (min: 10, avg: 169.34, max: 500)
#
# Run: 806, exploration: 0.01, score: 193
# Scores: (min: 10, avg: 169.92, max: 500)
#
# Run: 807, exploration: 0.01, score: 102
# Scores: (min: 10, avg: 168.16, max: 500)
#
# Run: 808, exploration: 0.01, score: 500
# Scores: (min: 10, avg: 172.07, max: 500)
#
# Run: 809, exploration: 0.01, score: 148
# Scores: (min: 10, avg: 171.61, max: 500)
#
# Run: 810, exploration: 0.01, score: 207
# Scores: (min: 10, avg: 172.49, max: 500)
#
# Run: 811, exploration: 0.01, score: 112
# Scores: (min: 10, avg: 172.63, max: 500)
#
# Run: 812, exploration: 0.01, score: 124
# Scores: (min: 10, avg: 172.83, max: 500)
#
# Run: 813, exploration: 0.01, score: 345
# Scores: (min: 10, avg: 176.16, max: 500)
#
# Run: 814, exploration: 0.01, score: 148
# Scores: (min: 10, avg: 177.43, max: 500)
#
# Run: 815, exploration: 0.01, score: 174
# Scores: (min: 10, avg: 179, max: 500)
#
# Run: 816, exploration: 0.01, score: 342
# Scores: (min: 10, avg: 182.26, max: 500)
#
# Run: 817, exploration: 0.01, score: 228
# Scores: (min: 10, avg: 184.37, max: 500)
#
# Run: 818, exploration: 0.01, score: 203
# Scores: (min: 10, avg: 186.2, max: 500)
#
# Run: 819, exploration: 0.01, score: 171
# Scores: (min: 10, avg: 187.7, max: 500)
#
# Run: 820, exploration: 0.01, score: 156
# Scores: (min: 10, avg: 189.08, max: 500)
#
# Run: 821, exploration: 0.01, score: 129
# Scores: (min: 10, avg: 189.25, max: 500)
#
# Run: 822, exploration: 0.01, score: 119
# Scores: (min: 10, avg: 188.57, max: 500)
#
# Run: 823, exploration: 0.01, score: 195
# Scores: (min: 10, avg: 190.39, max: 500)
#
# Run: 824, exploration: 0.01, score: 212
# Scores: (min: 10, avg: 192.31, max: 500)
#
# Run: 825, exploration: 0.01, score: 327
# Scores: (min: 10, avg: 194.65, max: 500)
#
# Run: 826, exploration: 0.01, score: 192
# Scores: (min: 10, avg: 195.02, max: 500)
#
# Solved in 726 runs, 826 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-1-bea6327a4fd8> in cartpole()
#      84             if terminal:
#      85                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 86                 score_logger.add_score(step, run)
#      87                 break
#      88             dqn_solver.experience_replay()
#
# U:\Cartpole\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %% [markdown]
# Note: If the code is running properly, you should begin to see output appearing above this code block. It will take several minutes, so it is recommended that you let this code run in the background while completing other work. When the code has finished, it will print output saying, "Solved in _ runs, _ total runs."
#
# You may see an error about not having an exit command. This error does not affect the program's functionality and results from the steps taken to convert the code from Python 2.x to Python 3. Please disregard this error.

# %% [markdown]
# # Value Modification to Explore Effects on Algorithm Performance
#
#
# If the objective is to explore how each value influences the performance, we should be able to return to a baseline setting easily.

# %%
# These are values used in the starter code. We will return to these while exploring behavior.
def reset_to_baseline_settings():
    GAMMA = 0.95  
    LEARNING_RATE = 0.001  

    MEMORY_SIZE = 1000000  
    BATCH_SIZE = 20  

    EXPLORATION_MAX = 1.0  
    EXPLORATION_MIN = 0.01  
    EXPLORATION_DECAY = 0.995

# %% [markdown]
# I propose that we do not need to attempt to solve the problem fully at this stage; it may take a long time to reach a stable mean score of 195. We can explore behavior at an earlier stage and extrapolate. Here, am slightly modifying the print statements and adding the option to end early.

# %%
def cartpole(max_run):  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                if (run >= max_run):
                    return
                if (run % 10 == 0):
                    print("####################")
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step), end=' | ')  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()

# %% [markdown]
# First, increase discount factor, or gamma, by .01

# %%
# Note: the baseline average at run# 250 was 101.74
reset_to_baseline_settings()
GAMMA = 0.96 
cartpole(250)
# Out:
# Run: 1, exploration: 1.0, score: 16 | Scores: (min: 16, avg: 16, max: 16)
#
# Run: 2, exploration: 0.9558895783575597, score: 13 | Scores: (min: 13, avg: 14.5, max: 16)
#
# Run: 3, exploration: 0.7744209942832988, score: 43 | Scores: (min: 13, avg: 24, max: 43)
#
# Run: 4, exploration: 0.6866430931872001, score: 25 | Scores: (min: 13, avg: 24.25, max: 43)
#
# Run: 5, exploration: 0.6274028820538087, score: 19 | Scores: (min: 13, avg: 23.2, max: 43)
#
# Run: 6, exploration: 0.3420891339682016, score: 122 | Scores: (min: 13, avg: 39.666666666666664, max: 122)
#
# Run: 7, exploration: 0.192217783647157, score: 116 | Scores: (min: 13, avg: 50.57142857142857, max: 122)
#
# Run: 8, exploration: 0.1580861105294992, score: 40 | Scores: (min: 13, avg: 49.25, max: 122)
#
# Run: 9, exploration: 0.11299003011401039, score: 68 | Scores: (min: 13, avg: 51.333333333333336, max: 122)
#
# ####################
# Run: 10, exploration: 0.10068643904747315, score: 24 | Scores: (min: 13, avg: 48.6, max: 122)
#
# Run: 11, exploration: 0.09292664835904782, score: 17 | Scores: (min: 13, avg: 45.72727272727273, max: 122)
#
# Run: 12, exploration: 0.08239373898667031, score: 25 | Scores: (min: 13, avg: 44, max: 122)
#
# Run: 13, exploration: 0.07232597730414898, score: 27 | Scores: (min: 13, avg: 42.69230769230769, max: 122)
#
# Run: 14, exploration: 0.05517478773284426, score: 55 | Scores: (min: 13, avg: 43.57142857142857, max: 122)
#
# Run: 15, exploration: 0.036033175291307735, score: 86 | Scores: (min: 13, avg: 46.4, max: 122)
#
# Run: 16, exploration: 0.024991218342344988, score: 74 | Scores: (min: 13, avg: 48.125, max: 122)
#
# Run: 17, exploration: 0.017595559502304726, score: 71 | Scores: (min: 13, avg: 49.470588235294116, max: 122)
#
# Run: 18, exploration: 0.01208186940302195, score: 76 | Scores: (min: 13, avg: 50.94444444444444, max: 122)
#
# Run: 19, exploration: 0.01, score: 164 | Scores: (min: 13, avg: 56.89473684210526, max: 164)
#
# ####################
# Run: 20, exploration: 0.01, score: 417 | Scores: (min: 13, avg: 74.9, max: 417)
#
# Run: 21, exploration: 0.01, score: 196 | Scores: (min: 13, avg: 80.66666666666667, max: 417)
#
# Run: 22, exploration: 0.01, score: 147 | Scores: (min: 13, avg: 83.68181818181819, max: 417)
#
# Run: 23, exploration: 0.01, score: 136 | Scores: (min: 13, avg: 85.95652173913044, max: 417)
#
# Run: 24, exploration: 0.01, score: 173 | Scores: (min: 13, avg: 89.58333333333333, max: 417)
#
# Run: 25, exploration: 0.01, score: 141 | Scores: (min: 13, avg: 91.64, max: 417)
#
# Run: 26, exploration: 0.01, score: 137 | Scores: (min: 13, avg: 93.38461538461539, max: 417)
#
# Run: 27, exploration: 0.01, score: 139 | Scores: (min: 13, avg: 95.07407407407408, max: 417)
#
# Run: 28, exploration: 0.01, score: 140 | Scores: (min: 13, avg: 96.67857142857143, max: 417)
#
# Run: 29, exploration: 0.01, score: 170 | Scores: (min: 13, avg: 99.20689655172414, max: 417)
#
# ####################
# Run: 30, exploration: 0.01, score: 114 | Scores: (min: 13, avg: 99.7, max: 417)
#
# Run: 31, exploration: 0.01, score: 138 | Scores: (min: 13, avg: 100.93548387096774, max: 417)
#
# Run: 32, exploration: 0.01, score: 42 | Scores: (min: 13, avg: 99.09375, max: 417)
#
# Run: 33, exploration: 0.01, score: 211 | Scores: (min: 13, avg: 102.48484848484848, max: 417)
#
# Run: 34, exploration: 0.01, score: 140 | Scores: (min: 13, avg: 103.58823529411765, max: 417)
#
# Run: 35, exploration: 0.01, score: 114 | Scores: (min: 13, avg: 103.88571428571429, max: 417)
#
# Run: 36, exploration: 0.01, score: 113 | Scores: (min: 13, avg: 104.13888888888889, max: 417)
#
# Run: 37, exploration: 0.01, score: 185 | Scores: (min: 13, avg: 106.32432432432432, max: 417)
#
# Run: 38, exploration: 0.01, score: 178 | Scores: (min: 13, avg: 108.21052631578948, max: 417)
#
# Run: 39, exploration: 0.01, score: 156 | Scores: (min: 13, avg: 109.43589743589743, max: 417)
#
# ####################
# Run: 40, exploration: 0.01, score: 167 | Scores: (min: 13, avg: 110.875, max: 417)
#
# Run: 41, exploration: 0.01, score: 132 | Scores: (min: 13, avg: 111.39024390243902, max: 417)
#
# Run: 42, exploration: 0.01, score: 179 | Scores: (min: 13, avg: 113, max: 417)
#
# Run: 43, exploration: 0.01, score: 11 | Scores: (min: 11, avg: 110.62790697674419, max: 417)
#
# Run: 44, exploration: 0.01, score: 10 | Scores: (min: 10, avg: 108.3409090909091, max: 417)
#
# Run: 45, exploration: 0.01, score: 8 | Scores: (min: 8, avg: 106.11111111111111, max: 417)
#
# Run: 46, exploration: 0.01, score: 10 | Scores: (min: 8, avg: 104.02173913043478, max: 417)
#
# Run: 47, exploration: 0.01, score: 10 | Scores: (min: 8, avg: 102.02127659574468, max: 417)
#
# Run: 48, exploration: 0.01, score: 10 | Scores: (min: 8, avg: 100.10416666666667, max: 417)
#
# Run: 49, exploration: 0.01, score: 10 | Scores: (min: 8, avg: 98.26530612244898, max: 417)
#
# ####################
# Run: 50, exploration: 0.01, score: 9 | Scores: (min: 8, avg: 96.48, max: 417)
#
# Run: 51, exploration: 0.01, score: 9 | Scores: (min: 8, avg: 94.76470588235294, max: 417)
#
# Run: 52, exploration: 0.01, score: 9 | Scores: (min: 8, avg: 93.11538461538461, max: 417)
#
# Run: 53, exploration: 0.01, score: 9 | Scores: (min: 8, avg: 91.52830188679245, max: 417)
#
# Run: 54, exploration: 0.01, score: 10 | Scores: (min: 8, avg: 90.01851851851852, max: 417)
#
# Run: 55, exploration: 0.01, score: 9 | Scores: (min: 8, avg: 88.54545454545455, max: 417)
#
# Run: 56, exploration: 0.01, score: 10 | Scores: (min: 8, avg: 87.14285714285714, max: 417)
#
# Run: 57, exploration: 0.01, score: 10 | Scores: (min: 8, avg: 85.78947368421052, max: 417)
#
# Run: 58, exploration: 0.01, score: 10 | Scores: (min: 8, avg: 84.48275862068965, max: 417)
#
# Run: 59, exploration: 0.01, score: 10 | Scores: (min: 8, avg: 83.22033898305085, max: 417)
#
# ####################
# Run: 60, exploration: 0.01, score: 8 | Scores: (min: 8, avg: 81.96666666666667, max: 417)
#
# Run: 61, exploration: 0.01, score: 8 | Scores: (min: 8, avg: 80.75409836065573, max: 417)
#
# Run: 62, exploration: 0.01, score: 9 | Scores: (min: 8, avg: 79.59677419354838, max: 417)
#
# Run: 63, exploration: 0.01, score: 9 | Scores: (min: 8, avg: 78.47619047619048, max: 417)
#
# Run: 64, exploration: 0.01, score: 8 | Scores: (min: 8, avg: 77.375, max: 417)
#
# Run: 65, exploration: 0.01, score: 9 | Scores: (min: 8, avg: 76.32307692307693, max: 417)
#
# Run: 66, exploration: 0.01, score: 9 | Scores: (min: 8, avg: 75.3030303030303, max: 417)
#
# Run: 67, exploration: 0.01, score: 10 | Scores: (min: 8, avg: 74.32835820895522, max: 417)
#
# Run: 68, exploration: 0.01, score: 9 | Scores: (min: 8, avg: 73.36764705882354, max: 417)
#
# Run: 69, exploration: 0.01, score: 10 | Scores: (min: 8, avg: 72.44927536231884, max: 417)
#
# ####################
# Run: 70, exploration: 0.01, score: 9 | Scores: (min: 8, avg: 71.54285714285714, max: 417)
#
# Run: 71, exploration: 0.01, score: 9 | Scores: (min: 8, avg: 70.66197183098592, max: 417)
#
# Run: 72, exploration: 0.01, score: 9 | Scores: (min: 8, avg: 69.80555555555556, max: 417)
#
# Run: 73, exploration: 0.01, score: 10 | Scores: (min: 8, avg: 68.98630136986301, max: 417)
#
# Run: 74, exploration: 0.01, score: 10 | Scores: (min: 8, avg: 68.1891891891892, max: 417)
#
# Run: 75, exploration: 0.01, score: 10 | Scores: (min: 8, avg: 67.41333333333333, max: 417)
#
# Run: 76, exploration: 0.01, score: 10 | Scores: (min: 8, avg: 66.65789473684211, max: 417)
#
# Run: 77, exploration: 0.01, score: 27 | Scores: (min: 8, avg: 66.14285714285714, max: 417)
#
# Run: 78, exploration: 0.01, score: 11 | Scores: (min: 8, avg: 65.43589743589743, max: 417)
#
# Run: 79, exploration: 0.01, score: 10 | Scores: (min: 8, avg: 64.73417721518987, max: 417)
#
# ####################
# Run: 80, exploration: 0.01, score: 10 | Scores: (min: 8, avg: 64.05, max: 417)
#
# Run: 81, exploration: 0.01, score: 9 | Scores: (min: 8, avg: 63.370370370370374, max: 417)
#
# Run: 82, exploration: 0.01, score: 11 | Scores: (min: 8, avg: 62.73170731707317, max: 417)
#
# Run: 83, exploration: 0.01, score: 141 | Scores: (min: 8, avg: 63.674698795180724, max: 417)
#
# Run: 84, exploration: 0.01, score: 295 | Scores: (min: 8, avg: 66.42857142857143, max: 417)
#
# Run: 85, exploration: 0.01, score: 174 | Scores: (min: 8, avg: 67.69411764705882, max: 417)
#
# Run: 86, exploration: 0.01, score: 151 | Scores: (min: 8, avg: 68.66279069767442, max: 417)
#
# Run: 87, exploration: 0.01, score: 161 | Scores: (min: 8, avg: 69.72413793103448, max: 417)
# Run: 88, exploration: 0.01, score: 194 | Scores: (min: 8, avg: 71.13636363636364, max: 417)
#
# Run: 89, exploration: 0.01, score: 34 | Scores: (min: 8, avg: 70.71910112359551, max: 417)
#
# ####################
# Run: 90, exploration: 0.01, score: 267 | Scores: (min: 8, avg: 72.9, max: 417)
#
# Run: 91, exploration: 0.01, score: 158 | Scores: (min: 8, avg: 73.83516483516483, max: 417)
#
# Run: 92, exploration: 0.01, score: 160 | Scores: (min: 8, avg: 74.77173913043478, max: 417)
#
# Run: 93, exploration: 0.01, score: 184 | Scores: (min: 8, avg: 75.94623655913979, max: 417)
#
# Run: 94, exploration: 0.01, score: 189 | Scores: (min: 8, avg: 77.14893617021276, max: 417)
#
# Run: 95, exploration: 0.01, score: 181 | Scores: (min: 8, avg: 78.2421052631579, max: 417)
#
# Run: 96, exploration: 0.01, score: 164 | Scores: (min: 8, avg: 79.13541666666667, max: 417)
#
# Run: 97, exploration: 0.01, score: 169 | Scores: (min: 8, avg: 80.0618556701031, max: 417)
#
# Run: 98, exploration: 0.01, score: 180 | Scores: (min: 8, avg: 81.08163265306122, max: 417)
#
# Run: 99, exploration: 0.01, score: 160 | Scores: (min: 8, avg: 81.87878787878788, max: 417)
#
# ####################
# Run: 100, exploration: 0.01, score: 167 | Scores: (min: 8, avg: 82.73, max: 417)
#
# Run: 101, exploration: 0.01, score: 160 | Scores: (min: 8, avg: 84.17, max: 417)
#
# Run: 102, exploration: 0.01, score: 168 | Scores: (min: 8, avg: 85.72, max: 417)
#
# Run: 103, exploration: 0.01, score: 163 | Scores: (min: 8, avg: 86.92, max: 417)
#
# Run: 104, exploration: 0.01, score: 165 | Scores: (min: 8, avg: 88.32, max: 417)
#
# Run: 105, exploration: 0.01, score: 220 | Scores: (min: 8, avg: 90.33, max: 417)
#
# Run: 106, exploration: 0.01, score: 203 | Scores: (min: 8, avg: 91.14, max: 417)
#
# Run: 107, exploration: 0.01, score: 167 | Scores: (min: 8, avg: 91.65, max: 417)
#
# Run: 108, exploration: 0.01, score: 213 | Scores: (min: 8, avg: 93.38, max: 417)
#
# Run: 109, exploration: 0.01, score: 219 | Scores: (min: 8, avg: 94.89, max: 417)
#
# ####################
# Run: 110, exploration: 0.01, score: 186 | Scores: (min: 8, avg: 96.51, max: 417)
#
# Run: 111, exploration: 0.01, score: 180 | Scores: (min: 8, avg: 98.14, max: 417)
#
# Run: 112, exploration: 0.01, score: 239 | Scores: (min: 8, avg: 100.28, max: 417)
#
# Run: 113, exploration: 0.01, score: 208 | Scores: (min: 8, avg: 102.09, max: 417)
#
# Run: 114, exploration: 0.01, score: 175 | Scores: (min: 8, avg: 103.29, max: 417)
#
# Run: 115, exploration: 0.01, score: 164 | Scores: (min: 8, avg: 104.07, max: 417)
#
# Run: 116, exploration: 0.01, score: 282 | Scores: (min: 8, avg: 106.15, max: 417)
#
# Run: 117, exploration: 0.01, score: 231 | Scores: (min: 8, avg: 107.75, max: 417)
#
# Run: 118, exploration: 0.01, score: 183 | Scores: (min: 8, avg: 108.82, max: 417)
#
# Run: 119, exploration: 0.01, score: 165 | Scores: (min: 8, avg: 108.83, max: 417)
#
# ####################
# Run: 120, exploration: 0.01, score: 169 | Scores: (min: 8, avg: 106.35, max: 295)
#
# Run: 121, exploration: 0.01, score: 219 | Scores: (min: 8, avg: 106.58, max: 295)
#
# Run: 122, exploration: 0.01, score: 211 | Scores: (min: 8, avg: 107.22, max: 295)
#
# Run: 123, exploration: 0.01, score: 215 | Scores: (min: 8, avg: 108.01, max: 295)
#
# Run: 124, exploration: 0.01, score: 220 | Scores: (min: 8, avg: 108.48, max: 295)
#
# Run: 125, exploration: 0.01, score: 193 | Scores: (min: 8, avg: 109, max: 295)
#
# Run: 126, exploration: 0.01, score: 227 | Scores: (min: 8, avg: 109.9, max: 295)
#
# Run: 127, exploration: 0.01, score: 146 | Scores: (min: 8, avg: 109.97, max: 295)
#
# Run: 128, exploration: 0.01, score: 125 | Scores: (min: 8, avg: 109.82, max: 295)
#
# Run: 129, exploration: 0.01, score: 220 | Scores: (min: 8, avg: 110.32, max: 295)
#
# ####################
# Run: 130, exploration: 0.01, score: 213 | Scores: (min: 8, avg: 111.31, max: 295)
#
# Run: 131, exploration: 0.01, score: 227 | Scores: (min: 8, avg: 112.2, max: 295)
#
# Run: 132, exploration: 0.01, score: 279 | Scores: (min: 8, avg: 114.57, max: 295)
#
# Run: 133, exploration: 0.01, score: 278 | Scores: (min: 8, avg: 115.24, max: 295)
#
# Run: 134, exploration: 0.01, score: 344 | Scores: (min: 8, avg: 117.28, max: 344)
#
# Run: 135, exploration: 0.01, score: 227 | Scores: (min: 8, avg: 118.41, max: 344)
#
# Run: 136, exploration: 0.01, score: 286 | Scores: (min: 8, avg: 120.14, max: 344)
#
# Run: 137, exploration: 0.01, score: 60 | Scores: (min: 8, avg: 118.89, max: 344)
#
# Run: 138, exploration: 0.01, score: 16 | Scores: (min: 8, avg: 117.27, max: 344)
#
# Run: 139, exploration: 0.01, score: 15 | Scores: (min: 8, avg: 115.86, max: 344)
#
# ####################
# Run: 140, exploration: 0.01, score: 9 | Scores: (min: 8, avg: 114.28, max: 344)
#
# Run: 141, exploration: 0.01, score: 9 | Scores: (min: 8, avg: 113.05, max: 344)
#
# Run: 142, exploration: 0.01, score: 10 | Scores: (min: 8, avg: 111.36, max: 344)
#
# Run: 143, exploration: 0.01, score: 9 | Scores: (min: 8, avg: 111.34, max: 344)
#
# Run: 144, exploration: 0.01, score: 9 | Scores: (min: 8, avg: 111.33, max: 344)
#
# Run: 145, exploration: 0.01, score: 10 | Scores: (min: 8, avg: 111.35, max: 344)
#
# Run: 146, exploration: 0.01, score: 8 | Scores: (min: 8, avg: 111.33, max: 344)
#
# Run: 147, exploration: 0.01, score: 9 | Scores: (min: 8, avg: 111.32, max: 344)
#
# Run: 148, exploration: 0.01, score: 10 | Scores: (min: 8, avg: 111.32, max: 344)
#
# Run: 149, exploration: 0.01, score: 8 | Scores: (min: 8, avg: 111.3, max: 344)
#
# ####################
# Run: 150, exploration: 0.01, score: 11 | Scores: (min: 8, avg: 111.32, max: 344)
#
# Run: 151, exploration: 0.01, score: 9 | Scores: (min: 8, avg: 111.32, max: 344)
#
# Run: 152, exploration: 0.01, score: 9 | Scores: (min: 8, avg: 111.32, max: 344)
#
# Run: 153, exploration: 0.01, score: 14 | Scores: (min: 8, avg: 111.37, max: 344)
#
# Run: 154, exploration: 0.01, score: 14 | Scores: (min: 8, avg: 111.41, max: 344)
#
# Run: 155, exploration: 0.01, score: 42 | Scores: (min: 8, avg: 111.74, max: 344)
#
# Run: 156, exploration: 0.01, score: 83 | Scores: (min: 8, avg: 112.47, max: 344)
#
# Run: 157, exploration: 0.01, score: 79 | Scores: (min: 8, avg: 113.16, max: 344)
#
# Run: 158, exploration: 0.01, score: 114 | Scores: (min: 8, avg: 114.2, max: 344)
#
# Run: 159, exploration: 0.01, score: 172 | Scores: (min: 8, avg: 115.82, max: 344)
#
# ####################
# Run: 160, exploration: 0.01, score: 181 | Scores: (min: 8, avg: 117.55, max: 344)
#
# Run: 161, exploration: 0.01, score: 179 | Scores: (min: 8, avg: 119.26, max: 344)
#
# Run: 162, exploration: 0.01, score: 200 | Scores: (min: 8, avg: 121.17, max: 344)
#
# Run: 163, exploration: 0.01, score: 160 | Scores: (min: 8, avg: 122.68, max: 344)
#
# Run: 164, exploration: 0.01, score: 194 | Scores: (min: 8, avg: 124.54, max: 344)
#
# Run: 165, exploration: 0.01, score: 197 | Scores: (min: 8, avg: 126.42, max: 344)
#
# Run: 166, exploration: 0.01, score: 196 | Scores: (min: 8, avg: 128.29, max: 344)
#
# Run: 167, exploration: 0.01, score: 205 | Scores: (min: 8, avg: 130.24, max: 344)
#
# Run: 168, exploration: 0.01, score: 202 | Scores: (min: 8, avg: 132.17, max: 344)
#
# Run: 169, exploration: 0.01, score: 232 | Scores: (min: 8, avg: 134.39, max: 344)
#
# ####################
# Run: 170, exploration: 0.01, score: 124 | Scores: (min: 8, avg: 135.54, max: 344)
#
# Run: 171, exploration: 0.01, score: 234 | Scores: (min: 8, avg: 137.79, max: 344)
#
# Run: 172, exploration: 0.01, score: 278 | Scores: (min: 8, avg: 140.48, max: 344)
#
# Run: 173, exploration: 0.01, score: 232 | Scores: (min: 8, avg: 142.7, max: 344)
#
# Run: 174, exploration: 0.01, score: 185 | Scores: (min: 8, avg: 144.45, max: 344)
#
# Run: 175, exploration: 0.01, score: 157 | Scores: (min: 8, avg: 145.92, max: 344)
#
# Run: 176, exploration: 0.01, score: 116 | Scores: (min: 8, avg: 146.98, max: 344)
#
# Run: 177, exploration: 0.01, score: 71 | Scores: (min: 8, avg: 147.42, max: 344)
#
# Run: 178, exploration: 0.01, score: 196 | Scores: (min: 8, avg: 149.27, max: 344)
#
# Run: 179, exploration: 0.01, score: 269 | Scores: (min: 8, avg: 151.86, max: 344)
#
# ####################
# Run: 180, exploration: 0.01, score: 193 | Scores: (min: 8, avg: 153.69, max: 344)
#
# Run: 181, exploration: 0.01, score: 226 | Scores: (min: 8, avg: 155.86, max: 344)
#
# Run: 182, exploration: 0.01, score: 427 | Scores: (min: 8, avg: 160.02, max: 427)
#
# Run: 183, exploration: 0.01, score: 76 | Scores: (min: 8, avg: 159.37, max: 427)
# Run: 184, exploration: 0.01, score: 230 | Scores: (min: 8, avg: 158.72, max: 427)
#
# Run: 185, exploration: 0.01, score: 173 | Scores: (min: 8, avg: 158.71, max: 427)
#
# Run: 186, exploration: 0.01, score: 189 | Scores: (min: 8, avg: 159.09, max: 427)
#
# Run: 187, exploration: 0.01, score: 200 | Scores: (min: 8, avg: 159.48, max: 427)
#
# Run: 188, exploration: 0.01, score: 284 | Scores: (min: 8, avg: 160.38, max: 427)
#
# Run: 189, exploration: 0.01, score: 205 | Scores: (min: 8, avg: 162.09, max: 427)
#
# ####################
# Run: 190, exploration: 0.01, score: 201 | Scores: (min: 8, avg: 161.43, max: 427)
#
# Run: 191, exploration: 0.01, score: 160 | Scores: (min: 8, avg: 161.45, max: 427)
#
# Run: 192, exploration: 0.01, score: 319 | Scores: (min: 8, avg: 163.04, max: 427)
#
# Run: 193, exploration: 0.01, score: 156 | Scores: (min: 8, avg: 162.76, max: 427)
#
# Run: 194, exploration: 0.01, score: 252 | Scores: (min: 8, avg: 163.39, max: 427)
#
# Run: 195, exploration: 0.01, score: 93 | Scores: (min: 8, avg: 162.51, max: 427)
#
# Run: 196, exploration: 0.01, score: 167 | Scores: (min: 8, avg: 162.54, max: 427)
#
# Run: 197, exploration: 0.01, score: 309 | Scores: (min: 8, avg: 163.94, max: 427)
#
# Run: 198, exploration: 0.01, score: 252 | Scores: (min: 8, avg: 164.66, max: 427)
#
# Run: 199, exploration: 0.01, score: 500 | Scores: (min: 8, avg: 168.06, max: 500)
#
# ####################
# Run: 200, exploration: 0.01, score: 218 | Scores: (min: 8, avg: 168.57, max: 500)
#
# Run: 201, exploration: 0.01, score: 333 | Scores: (min: 8, avg: 170.3, max: 500)
#
# Run: 202, exploration: 0.01, score: 248 | Scores: (min: 8, avg: 171.1, max: 500)
#
# Run: 203, exploration: 0.01, score: 500 | Scores: (min: 8, avg: 174.47, max: 500)
#
# Run: 204, exploration: 0.01, score: 295 | Scores: (min: 8, avg: 175.77, max: 500)
#
# Run: 205, exploration: 0.01, score: 205 | Scores: (min: 8, avg: 175.62, max: 500)
#
# Run: 206, exploration: 0.01, score: 310 | Scores: (min: 8, avg: 176.69, max: 500)
#
# Run: 207, exploration: 0.01, score: 207 | Scores: (min: 8, avg: 177.09, max: 500)
#
# Run: 208, exploration: 0.01, score: 245 | Scores: (min: 8, avg: 177.41, max: 500)
#
# Run: 209, exploration: 0.01, score: 192 | Scores: (min: 8, avg: 177.14, max: 500)
#
# ####################
# Run: 210, exploration: 0.01, score: 190 | Scores: (min: 8, avg: 177.18, max: 500)
#
# Run: 211, exploration: 0.01, score: 277 | Scores: (min: 8, avg: 178.15, max: 500)
#
# Run: 212, exploration: 0.01, score: 236 | Scores: (min: 8, avg: 178.12, max: 500)
#
# Run: 213, exploration: 0.01, score: 211 | Scores: (min: 8, avg: 178.15, max: 500)
#
# Run: 214, exploration: 0.01, score: 245 | Scores: (min: 8, avg: 178.85, max: 500)
#
# Run: 215, exploration: 0.01, score: 138 | Scores: (min: 8, avg: 178.59, max: 500)
#
# Run: 216, exploration: 0.01, score: 72 | Scores: (min: 8, avg: 176.49, max: 500)
#
# Run: 217, exploration: 0.01, score: 92 | Scores: (min: 8, avg: 175.1, max: 500)
#
# Run: 218, exploration: 0.01, score: 236 | Scores: (min: 8, avg: 175.63, max: 500)
#
# Run: 219, exploration: 0.01, score: 204 | Scores: (min: 8, avg: 176.02, max: 500)
#
# ####################
# Run: 220, exploration: 0.01, score: 293 | Scores: (min: 8, avg: 177.26, max: 500)
#
# Run: 221, exploration: 0.01, score: 255 | Scores: (min: 8, avg: 177.62, max: 500)
#
# Run: 222, exploration: 0.01, score: 177 | Scores: (min: 8, avg: 177.28, max: 500)
#
# Run: 223, exploration: 0.01, score: 203 | Scores: (min: 8, avg: 177.16, max: 500)
#
# Run: 224, exploration: 0.01, score: 173 | Scores: (min: 8, avg: 176.69, max: 500)
#
# Run: 225, exploration: 0.01, score: 254 | Scores: (min: 8, avg: 177.3, max: 500)
#
# Run: 226, exploration: 0.01, score: 113 | Scores: (min: 8, avg: 176.16, max: 500)
#
# Run: 227, exploration: 0.01, score: 16 | Scores: (min: 8, avg: 174.86, max: 500)
#
# Run: 228, exploration: 0.01, score: 97 | Scores: (min: 8, avg: 174.58, max: 500)
#
# Run: 229, exploration: 0.01, score: 169 | Scores: (min: 8, avg: 174.07, max: 500)
#
# ####################
# Run: 230, exploration: 0.01, score: 213 | Scores: (min: 8, avg: 174.07, max: 500)
#
# Run: 231, exploration: 0.01, score: 13 | Scores: (min: 8, avg: 171.93, max: 500)
#
# Run: 232, exploration: 0.01, score: 130 | Scores: (min: 8, avg: 170.44, max: 500)
#
# Run: 233, exploration: 0.01, score: 320 | Scores: (min: 8, avg: 170.86, max: 500)
#
# Run: 234, exploration: 0.01, score: 139 | Scores: (min: 8, avg: 168.81, max: 500)
#
# Run: 235, exploration: 0.01, score: 246 | Scores: (min: 8, avg: 169, max: 500)
#
# Run: 236, exploration: 0.01, score: 179 | Scores: (min: 8, avg: 167.93, max: 500)
#
# Run: 237, exploration: 0.01, score: 162 | Scores: (min: 8, avg: 168.95, max: 500)
#
# Run: 238, exploration: 0.01, score: 413 | Scores: (min: 8, avg: 172.92, max: 500)
#
# Run: 239, exploration: 0.01, score: 66 | Scores: (min: 8, avg: 173.43, max: 500)
#
# ####################
# Run: 240, exploration: 0.01, score: 493 | Scores: (min: 8, avg: 178.27, max: 500)
#
# Run: 241, exploration: 0.01, score: 169 | Scores: (min: 8, avg: 179.87, max: 500)
#
# Run: 242, exploration: 0.01, score: 275 | Scores: (min: 8, avg: 182.52, max: 500)
#
# Run: 243, exploration: 0.01, score: 396 | Scores: (min: 8, avg: 186.39, max: 500)
#
# Run: 244, exploration: 0.01, score: 149 | Scores: (min: 8, avg: 187.79, max: 500)
#
# Run: 245, exploration: 0.01, score: 110 | Scores: (min: 8, avg: 188.79, max: 500)
#
# Run: 246, exploration: 0.01, score: 189 | Scores: (min: 8, avg: 190.6, max: 500)
#
# Run: 247, exploration: 0.01, score: 17 | Scores: (min: 8, avg: 190.68, max: 500)
#
# Run: 248, exploration: 0.01, score: 143 | Scores: (min: 8, avg: 192.01, max: 500)
#
# Run: 249, exploration: 0.01, score: 243 | Scores: (min: 9, avg: 194.36, max: 500)

# %% [markdown]
# Next, decrease discount factor, or gamma, by .01

# %%
# Note: the baseline average at run# 250 was 101.74
reset_to_baseline_settings()
GAMMA = 0.94
cartpole(250)
# Out:
# Run: 1, exploration: 0.9752487531218751, score: 25 | Scores: (min: 25, avg: 25, max: 25)
#
# Run: 2, exploration: 0.8390886103705794, score: 31 | Scores: (min: 25, avg: 28, max: 31)
#
# Run: 3, exploration: 0.7705488893118823, score: 18 | Scores: (min: 18, avg: 24.666666666666668, max: 31)
#
# Run: 4, exploration: 0.7219385759785162, score: 14 | Scores: (min: 14, avg: 22, max: 31)
#
# Run: 5, exploration: 0.6730128848950395, score: 15 | Scores: (min: 14, avg: 20.6, max: 31)
#
# Run: 6, exploration: 0.6211445383053219, score: 17 | Scores: (min: 14, avg: 20, max: 31)
#
# Run: 7, exploration: 0.5937455908197752, score: 10 | Scores: (min: 10, avg: 18.571428571428573, max: 31)
#
# Run: 8, exploration: 0.5507399854171277, score: 16 | Scores: (min: 10, avg: 18.25, max: 31)
#
# Run: 9, exploration: 0.5238143793828016, score: 11 | Scores: (min: 10, avg: 17.444444444444443, max: 31)
#
# ####################
# Run: 10, exploration: 0.4883155414435353, score: 15 | Scores: (min: 10, avg: 17.2, max: 31)
#
# Run: 11, exploration: 0.457510005540005, score: 14 | Scores: (min: 10, avg: 16.90909090909091, max: 31)
#
# Run: 12, exploration: 0.42437208406280985, score: 16 | Scores: (min: 10, avg: 16.833333333333332, max: 31)
#
# Run: 13, exploration: 0.40769130904675194, score: 9 | Scores: (min: 9, avg: 16.23076923076923, max: 31)
#
# Run: 14, exploration: 0.3936343764094253, score: 8 | Scores: (min: 8, avg: 15.642857142857142, max: 31)
#
# Run: 15, exploration: 0.3743896431025813, score: 11 | Scores: (min: 8, avg: 15.333333333333334, max: 31)
#
# Run: 16, exploration: 0.3543053533848483, score: 12 | Scores: (min: 8, avg: 15.125, max: 31)
#
# Run: 17, exploration: 0.3403786882983606, score: 9 | Scores: (min: 8, avg: 14.764705882352942, max: 31)
#
# Run: 18, exploration: 0.3237376186352221, score: 11 | Scores: (min: 8, avg: 14.555555555555555, max: 31)
#
# Run: 19, exploration: 0.30483872516307353, score: 13 | Scores: (min: 8, avg: 14.473684210526315, max: 31)
#
# ####################
# Run: 20, exploration: 0.2913921604631864, score: 10 | Scores: (min: 8, avg: 14.25, max: 31)
#
# Run: 21, exploration: 0.27714603575484437, score: 11 | Scores: (min: 8, avg: 14.095238095238095, max: 31)
#
# Run: 22, exploration: 0.2662522686041882, score: 9 | Scores: (min: 8, avg: 13.863636363636363, max: 31)
#
# Run: 23, exploration: 0.2494556624678441, score: 14 | Scores: (min: 8, avg: 13.869565217391305, max: 31)
#
# Run: 24, exploration: 0.23489314109365644, score: 13 | Scores: (min: 8, avg: 13.833333333333334, max: 31)
#
# Run: 25, exploration: 0.22453190559909803, score: 10 | Scores: (min: 8, avg: 13.68, max: 31)
#
# Run: 26, exploration: 0.21462770857094118, score: 10 | Scores: (min: 8, avg: 13.538461538461538, max: 31)
#
# Run: 27, exploration: 0.2031139149609751, score: 12 | Scores: (min: 8, avg: 13.481481481481481, max: 31)
#
# Run: 28, exploration: 0.19513012515638165, score: 9 | Scores: (min: 8, avg: 13.321428571428571, max: 31)
#
# Run: 29, exploration: 0.18746015382974018, score: 9 | Scores: (min: 8, avg: 13.172413793103448, max: 31)
#
# ####################
# Run: 30, exploration: 0.17919120740315364, score: 10 | Scores: (min: 8, avg: 13.066666666666666, max: 31)
#
# Run: 31, exploration: 0.1712870076899825, score: 10 | Scores: (min: 8, avg: 12.96774193548387, max: 31)
#
# Run: 32, exploration: 0.16538114245489302, score: 8 | Scores: (min: 8, avg: 12.8125, max: 31)
#
# Run: 33, exploration: 0.1580861105294992, score: 10 | Scores: (min: 8, avg: 12.727272727272727, max: 31)
#
# Run: 34, exploration: 0.15111286553822956, score: 10 | Scores: (min: 8, avg: 12.647058823529411, max: 31)
#
# Run: 35, exploration: 0.14590259167570602, score: 8 | Scores: (min: 8, avg: 12.514285714285714, max: 31)
#
# Run: 36, exploration: 0.14016760486247823, score: 9 | Scores: (min: 8, avg: 12.416666666666666, max: 31)
#
# Run: 37, exploration: 0.1346580429260134, score: 9 | Scores: (min: 8, avg: 12.324324324324325, max: 31)
#
# Run: 38, exploration: 0.12679708435358925, score: 13 | Scores: (min: 8, avg: 12.342105263157896, max: 31)
#
# Run: 39, exploration: 0.12181307688414106, score: 9 | Scores: (min: 8, avg: 12.256410256410257, max: 31)
#
# ####################
# Run: 40, exploration: 0.11702497557911415, score: 9 | Scores: (min: 8, avg: 12.175, max: 31)
#
# Run: 41, exploration: 0.11130363979080501, score: 11 | Scores: (min: 8, avg: 12.146341463414634, max: 31)
#
# Run: 42, exploration: 0.10586201936274783, score: 11 | Scores: (min: 8, avg: 12.119047619047619, max: 31)
#
# Run: 43, exploration: 0.10170090558064004, score: 9 | Scores: (min: 8, avg: 12.046511627906977, max: 31)
#
# Run: 44, exploration: 0.09721483575406, score: 10 | Scores: (min: 8, avg: 12, max: 31)
#
# Run: 45, exploration: 0.09199970504166631, score: 12 | Scores: (min: 8, avg: 12, max: 31)
#
# Run: 46, exploration: 0.08662902049662846, score: 13 | Scores: (min: 8, avg: 12.021739130434783, max: 31)
#
# Run: 47, exploration: 0.0811640021330769, score: 14 | Scores: (min: 8, avg: 12.063829787234043, max: 31)
#
# Run: 48, exploration: 0.07604374613140748, score: 14 | Scores: (min: 8, avg: 12.104166666666666, max: 31)
#
# Run: 49, exploration: 0.07018314008827135, score: 17 | Scores: (min: 8, avg: 12.204081632653061, max: 31)
#
# ####################
# Run: 50, exploration: 0.05918580250061433, score: 35 | Scores: (min: 8, avg: 12.66, max: 35)
#
# Run: 51, exploration: 0.05143559895690903, score: 29 | Scores: (min: 8, avg: 12.980392156862745, max: 35)
#
# Run: 52, exploration: 0.04652918187562211, score: 21 | Scores: (min: 8, avg: 13.134615384615385, max: 35)
#
# Run: 53, exploration: 0.0378853869148274, score: 42 | Scores: (min: 8, avg: 13.679245283018869, max: 42)
#
# Run: 54, exploration: 0.031948941366546975, score: 35 | Scores: (min: 8, avg: 14.074074074074074, max: 42)
#
# Run: 55, exploration: 0.029192542808371146, score: 19 | Scores: (min: 8, avg: 14.163636363636364, max: 42)
#
# Run: 56, exploration: 0.021937519923982282, score: 58 | Scores: (min: 8, avg: 14.946428571428571, max: 58)
#
# Run: 57, exploration: 0.020246819920648168, score: 17 | Scores: (min: 8, avg: 14.982456140350877, max: 58)
#
# Run: 58, exploration: 0.018686420266267767, score: 17 | Scores: (min: 8, avg: 15.017241379310345, max: 58)
#
# Run: 59, exploration: 0.012203600316175803, score: 86 | Scores: (min: 8, avg: 16.220338983050848, max: 86)
#
# ####################
# Run: 60, exploration: 0.01, score: 49 | Scores: (min: 8, avg: 16.766666666666666, max: 86)
#
# Run: 61, exploration: 0.01, score: 55 | Scores: (min: 8, avg: 17.39344262295082, max: 86)
#
# Run: 62, exploration: 0.01, score: 27 | Scores: (min: 8, avg: 17.548387096774192, max: 86)
#
# Run: 63, exploration: 0.01, score: 47 | Scores: (min: 8, avg: 18.015873015873016, max: 86)
#
# Run: 64, exploration: 0.01, score: 16 | Scores: (min: 8, avg: 17.984375, max: 86)
#
# Run: 65, exploration: 0.01, score: 55 | Scores: (min: 8, avg: 18.553846153846155, max: 86)
#
# Run: 66, exploration: 0.01, score: 73 | Scores: (min: 8, avg: 19.37878787878788, max: 86)
#
# Run: 67, exploration: 0.01, score: 114 | Scores: (min: 8, avg: 20.791044776119403, max: 114)
#
# Run: 68, exploration: 0.01, score: 25 | Scores: (min: 8, avg: 20.852941176470587, max: 114)
#
# Run: 69, exploration: 0.01, score: 33 | Scores: (min: 8, avg: 21.028985507246375, max: 114)
#
# ####################
# Run: 70, exploration: 0.01, score: 28 | Scores: (min: 8, avg: 21.12857142857143, max: 114)
#
# Run: 71, exploration: 0.01, score: 34 | Scores: (min: 8, avg: 21.309859154929576, max: 114)
#
# Run: 72, exploration: 0.01, score: 53 | Scores: (min: 8, avg: 21.75, max: 114)
#
# Run: 73, exploration: 0.01, score: 46 | Scores: (min: 8, avg: 22.08219178082192, max: 114)
#
# Run: 74, exploration: 0.01, score: 24 | Scores: (min: 8, avg: 22.10810810810811, max: 114)
#
# Run: 75, exploration: 0.01, score: 43 | Scores: (min: 8, avg: 22.386666666666667, max: 114)
#
# Run: 76, exploration: 0.01, score: 67 | Scores: (min: 8, avg: 22.973684210526315, max: 114)
#
# Run: 77, exploration: 0.01, score: 56 | Scores: (min: 8, avg: 23.4025974025974, max: 114)
#
# Run: 78, exploration: 0.01, score: 69 | Scores: (min: 8, avg: 23.987179487179485, max: 114)
#
# Run: 79, exploration: 0.01, score: 74 | Scores: (min: 8, avg: 24.620253164556964, max: 114)
#
# ####################
# Run: 80, exploration: 0.01, score: 100 | Scores: (min: 8, avg: 25.5625, max: 114)
#
# Run: 81, exploration: 0.01, score: 78 | Scores: (min: 8, avg: 26.209876543209877, max: 114)
# Run: 82, exploration: 0.01, score: 98 | Scores: (min: 8, avg: 27.085365853658537, max: 114)
#
# Run: 83, exploration: 0.01, score: 124 | Scores: (min: 8, avg: 28.253012048192772, max: 124)
#
# Run: 84, exploration: 0.01, score: 125 | Scores: (min: 8, avg: 29.404761904761905, max: 125)
#
# Run: 85, exploration: 0.01, score: 90 | Scores: (min: 8, avg: 30.11764705882353, max: 125)
#
# Run: 86, exploration: 0.01, score: 151 | Scores: (min: 8, avg: 31.523255813953487, max: 151)
#
# Run: 87, exploration: 0.01, score: 105 | Scores: (min: 8, avg: 32.367816091954026, max: 151)
#
# Run: 88, exploration: 0.01, score: 225 | Scores: (min: 8, avg: 34.55681818181818, max: 225)
#
# Run: 89, exploration: 0.01, score: 128 | Scores: (min: 8, avg: 35.60674157303371, max: 225)
#
# ####################
# Run: 90, exploration: 0.01, score: 270 | Scores: (min: 8, avg: 38.21111111111111, max: 270)
#
# Run: 91, exploration: 0.01, score: 243 | Scores: (min: 8, avg: 40.46153846153846, max: 270)
#
# Run: 92, exploration: 0.01, score: 167 | Scores: (min: 8, avg: 41.83695652173913, max: 270)
#
# Run: 93, exploration: 0.01, score: 145 | Scores: (min: 8, avg: 42.946236559139784, max: 270)
#
# Run: 94, exploration: 0.01, score: 377 | Scores: (min: 8, avg: 46.5, max: 377)
#
# Run: 95, exploration: 0.01, score: 176 | Scores: (min: 8, avg: 47.863157894736844, max: 377)
#
# Run: 96, exploration: 0.01, score: 243 | Scores: (min: 8, avg: 49.895833333333336, max: 377)
#
# Run: 97, exploration: 0.01, score: 307 | Scores: (min: 8, avg: 52.54639175257732, max: 377)
#
# Run: 98, exploration: 0.01, score: 373 | Scores: (min: 8, avg: 55.816326530612244, max: 377)
#
# Run: 99, exploration: 0.01, score: 174 | Scores: (min: 8, avg: 57.01010101010101, max: 377)
#
# ####################
# Run: 100, exploration: 0.01, score: 106 | Scores: (min: 8, avg: 57.5, max: 377)
#
# Run: 101, exploration: 0.01, score: 432 | Scores: (min: 8, avg: 61.57, max: 432)
#
# Run: 102, exploration: 0.01, score: 255 | Scores: (min: 8, avg: 63.81, max: 432)
#
# Run: 103, exploration: 0.01, score: 229 | Scores: (min: 8, avg: 65.92, max: 432)
#
# Run: 104, exploration: 0.01, score: 248 | Scores: (min: 8, avg: 68.26, max: 432)
#
# Run: 105, exploration: 0.01, score: 326 | Scores: (min: 8, avg: 71.37, max: 432)
#
# Run: 106, exploration: 0.01, score: 188 | Scores: (min: 8, avg: 73.08, max: 432)
#
# Run: 107, exploration: 0.01, score: 500 | Scores: (min: 8, avg: 77.98, max: 500)
#
# Run: 108, exploration: 0.01, score: 191 | Scores: (min: 8, avg: 79.73, max: 500)
#
# Run: 109, exploration: 0.01, score: 491 | Scores: (min: 8, avg: 84.53, max: 500)
#
# ####################
# Run: 110, exploration: 0.01, score: 296 | Scores: (min: 8, avg: 87.34, max: 500)
#
# Run: 111, exploration: 0.01, score: 404 | Scores: (min: 8, avg: 91.24, max: 500)
#
# Run: 112, exploration: 0.01, score: 415 | Scores: (min: 8, avg: 95.23, max: 500)
#
# Run: 113, exploration: 0.01, score: 270 | Scores: (min: 8, avg: 97.84, max: 500)
#
# Run: 114, exploration: 0.01, score: 292 | Scores: (min: 8, avg: 100.68, max: 500)
#
# Run: 115, exploration: 0.01, score: 399 | Scores: (min: 8, avg: 104.56, max: 500)
#
# Run: 116, exploration: 0.01, score: 33 | Scores: (min: 8, avg: 104.77, max: 500)
#
# Run: 117, exploration: 0.01, score: 178 | Scores: (min: 8, avg: 106.46, max: 500)
#
# Run: 118, exploration: 0.01, score: 214 | Scores: (min: 8, avg: 108.49, max: 500)
#
# Run: 119, exploration: 0.01, score: 237 | Scores: (min: 8, avg: 110.73, max: 500)
#
# ####################
# Run: 120, exploration: 0.01, score: 225 | Scores: (min: 8, avg: 112.88, max: 500)
#
# Run: 121, exploration: 0.01, score: 211 | Scores: (min: 8, avg: 114.88, max: 500)
#
# Run: 122, exploration: 0.01, score: 233 | Scores: (min: 8, avg: 117.12, max: 500)
#
# Run: 123, exploration: 0.01, score: 288 | Scores: (min: 8, avg: 119.86, max: 500)
#
# Run: 124, exploration: 0.01, score: 196 | Scores: (min: 8, avg: 121.69, max: 500)
#
# Run: 125, exploration: 0.01, score: 230 | Scores: (min: 8, avg: 123.89, max: 500)
#
# Run: 126, exploration: 0.01, score: 277 | Scores: (min: 8, avg: 126.56, max: 500)
#
# Run: 127, exploration: 0.01, score: 320 | Scores: (min: 8, avg: 129.64, max: 500)
#
# Run: 128, exploration: 0.01, score: 163 | Scores: (min: 8, avg: 131.18, max: 500)
#
# Run: 129, exploration: 0.01, score: 239 | Scores: (min: 8, avg: 133.48, max: 500)
#
# ####################
# Run: 130, exploration: 0.01, score: 186 | Scores: (min: 8, avg: 135.24, max: 500)
#
# Run: 131, exploration: 0.01, score: 234 | Scores: (min: 8, avg: 137.48, max: 500)
#
# Run: 132, exploration: 0.01, score: 200 | Scores: (min: 8, avg: 139.4, max: 500)
#
# Run: 133, exploration: 0.01, score: 249 | Scores: (min: 8, avg: 141.79, max: 500)
#
# Run: 134, exploration: 0.01, score: 327 | Scores: (min: 8, avg: 144.96, max: 500)
#
# Run: 135, exploration: 0.01, score: 500 | Scores: (min: 9, avg: 149.88, max: 500)
#
# Run: 136, exploration: 0.01, score: 215 | Scores: (min: 9, avg: 151.94, max: 500)
#
# Run: 137, exploration: 0.01, score: 239 | Scores: (min: 9, avg: 154.24, max: 500)
#
# Run: 138, exploration: 0.01, score: 174 | Scores: (min: 9, avg: 155.85, max: 500)
#
# Run: 139, exploration: 0.01, score: 194 | Scores: (min: 9, avg: 157.7, max: 500)
#
# ####################
# Run: 140, exploration: 0.01, score: 206 | Scores: (min: 9, avg: 159.67, max: 500)
#
# Run: 141, exploration: 0.01, score: 145 | Scores: (min: 9, avg: 161.01, max: 500)
#
# Run: 142, exploration: 0.01, score: 278 | Scores: (min: 9, avg: 163.68, max: 500)
#
# Run: 143, exploration: 0.01, score: 229 | Scores: (min: 10, avg: 165.88, max: 500)
#
# Run: 144, exploration: 0.01, score: 274 | Scores: (min: 12, avg: 168.52, max: 500)
#
# Run: 145, exploration: 0.01, score: 248 | Scores: (min: 13, avg: 170.88, max: 500)
#
# Run: 146, exploration: 0.01, score: 228 | Scores: (min: 14, avg: 173.03, max: 500)
#
# Run: 147, exploration: 0.01, score: 200 | Scores: (min: 14, avg: 174.89, max: 500)
#
# Run: 148, exploration: 0.01, score: 154 | Scores: (min: 16, avg: 176.29, max: 500)
#
# Run: 149, exploration: 0.01, score: 129 | Scores: (min: 16, avg: 177.41, max: 500)
#
# ####################
# Run: 150, exploration: 0.01, score: 163 | Scores: (min: 16, avg: 178.69, max: 500)
#
# Run: 151, exploration: 0.01, score: 297 | Scores: (min: 16, avg: 181.37, max: 500)
#
# Run: 152, exploration: 0.01, score: 191 | Scores: (min: 16, avg: 183.07, max: 500)
#
# Run: 153, exploration: 0.01, score: 201 | Scores: (min: 16, avg: 184.66, max: 500)
#
# Run: 154, exploration: 0.01, score: 194 | Scores: (min: 16, avg: 186.25, max: 500)
#
# Run: 155, exploration: 0.01, score: 500 | Scores: (min: 16, avg: 191.06, max: 500)
#
# Run: 156, exploration: 0.01, score: 140 | Scores: (min: 16, avg: 191.88, max: 500)
#
# Run: 157, exploration: 0.01, score: 277 | Scores: (min: 16, avg: 194.48, max: 500)
#
# Run: 158, exploration: 0.01, score: 132 | Scores: (min: 16, avg: 195.63, max: 500)
#
# Solved in 58 runs, 158 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-fcb5d5ec864c> in <module>
#       2 reset_to_baseline_settings()
#       3 GAMMA = 0.94
# ----> 4 cartpole(250)
#
# <ipython-input-4-6270a8499d29> in cartpole(max_run)
#      26                     print("####################")
#      27                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step), end=' | ')
# ---> 28                 score_logger.add_score(step, run)
#      29                 break
#      30             dqn_solver.experience_replay()
#
# U:\Cartpole\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %% [markdown]
# Next, increase learning rate by .0002

# %%
# Note: the baseline average at run# 250 was 101.74
reset_to_baseline_settings()
LEARNING_RATE = 0.0012
cartpole(250)
# Out:
# Run: 1, exploration: 1.0, score: 14 | Scores: (min: 14, avg: 14, max: 14)
#
# Run: 2, exploration: 0.9322301194154049, score: 20 | Scores: (min: 14, avg: 17, max: 20)
#
# Run: 3, exploration: 0.8734200960253871, score: 14 | Scores: (min: 14, avg: 16, max: 20)
#
# Run: 4, exploration: 0.7861544476842928, score: 22 | Scores: (min: 14, avg: 17.5, max: 22)
#
# Run: 5, exploration: 0.7147372386831305, score: 20 | Scores: (min: 14, avg: 18, max: 22)
#
# Run: 6, exploration: 0.6832098777212641, score: 10 | Scores: (min: 10, avg: 16.666666666666668, max: 22)
#
# Run: 7, exploration: 0.6498078359349755, score: 11 | Scores: (min: 10, avg: 15.857142857142858, max: 22)
#
# Run: 8, exploration: 0.5937455908197752, score: 19 | Scores: (min: 10, avg: 16.25, max: 22)
#
# Run: 9, exploration: 0.5618938591163328, score: 12 | Scores: (min: 10, avg: 15.777777777777779, max: 22)
#
# ####################
# Run: 10, exploration: 0.5398075216808175, score: 9 | Scores: (min: 9, avg: 15.1, max: 22)
#
# Run: 11, exploration: 0.5134164023722473, score: 11 | Scores: (min: 9, avg: 14.727272727272727, max: 22)
#
# Run: 12, exploration: 0.4907693883854626, score: 10 | Scores: (min: 9, avg: 14.333333333333334, max: 22)
#
# Run: 13, exploration: 0.446186062443672, score: 20 | Scores: (min: 9, avg: 14.76923076923077, max: 22)
#
# Run: 14, exploration: 0.42437208406280985, score: 11 | Scores: (min: 9, avg: 14.5, max: 22)
#
# Run: 15, exploration: 0.39561243860243744, score: 15 | Scores: (min: 9, avg: 14.533333333333333, max: 22)
#
# Run: 16, exploration: 0.3800621177172763, score: 9 | Scores: (min: 9, avg: 14.1875, max: 22)
#
# Run: 17, exploration: 0.3632974174544486, score: 10 | Scores: (min: 9, avg: 13.941176470588236, max: 22)
#
# Run: 18, exploration: 0.3472722151889232, score: 10 | Scores: (min: 9, avg: 13.722222222222221, max: 22)
#
# Run: 19, exploration: 0.33195389135223546, score: 10 | Scores: (min: 9, avg: 13.526315789473685, max: 22)
#
# ####################
# Run: 20, exploration: 0.3141460853680822, score: 12 | Scores: (min: 9, avg: 13.45, max: 22)
#
# Run: 21, exploration: 0.29580711868545667, score: 13 | Scores: (min: 9, avg: 13.428571428571429, max: 22)
#
# Run: 22, exploration: 0.28417984116121187, score: 9 | Scores: (min: 9, avg: 13.227272727272727, max: 22)
#
# Run: 23, exploration: 0.27164454854530906, score: 10 | Scores: (min: 9, avg: 13.08695652173913, max: 22)
#
# Run: 24, exploration: 0.25578670228422234, score: 13 | Scores: (min: 9, avg: 13.083333333333334, max: 22)
#
# Run: 25, exploration: 0.2457325055235537, score: 9 | Scores: (min: 9, avg: 12.92, max: 22)
#
# Run: 26, exploration: 0.23607350863684065, score: 9 | Scores: (min: 9, avg: 12.76923076923077, max: 22)
#
# Run: 27, exploration: 0.22566020663225933, score: 10 | Scores: (min: 9, avg: 12.666666666666666, max: 22)
#
# Run: 28, exploration: 0.21570623976979014, score: 10 | Scores: (min: 9, avg: 12.571428571428571, max: 22)
#
# Run: 29, exploration: 0.20619134658263935, score: 10 | Scores: (min: 9, avg: 12.482758620689655, max: 22)
#
# ####################
# Run: 30, exploration: 0.19611067854912728, score: 11 | Scores: (min: 9, avg: 12.433333333333334, max: 22)
#
# Run: 31, exploration: 0.18840216465300522, score: 9 | Scores: (min: 9, avg: 12.32258064516129, max: 22)
#
# Run: 32, exploration: 0.18099664897669618, score: 9 | Scores: (min: 9, avg: 12.21875, max: 22)
#
# Run: 33, exploration: 0.17388222158237718, score: 9 | Scores: (min: 9, avg: 12.121212121212121, max: 22)
#
# Run: 34, exploration: 0.1662122034722543, score: 10 | Scores: (min: 9, avg: 12.058823529411764, max: 22)
#
# Run: 35, exploration: 0.16048131420416054, score: 8 | Scores: (min: 8, avg: 11.942857142857143, max: 22)
#
# Run: 36, exploration: 0.1534024157688821, score: 10 | Scores: (min: 8, avg: 11.88888888888889, max: 22)
#
# Run: 37, exploration: 0.1473726336968319, score: 9 | Scores: (min: 8, avg: 11.81081081081081, max: 22)
#
# Run: 38, exploration: 0.14087196468590776, score: 10 | Scores: (min: 8, avg: 11.763157894736842, max: 22)
#
# Run: 39, exploration: 0.13601479046086049, score: 8 | Scores: (min: 8, avg: 11.666666666666666, max: 22)
#
# ####################
# Run: 40, exploration: 0.12871821987500112, score: 12 | Scores: (min: 8, avg: 11.675, max: 22)
#
# Run: 41, exploration: 0.12365869841532712, score: 9 | Scores: (min: 8, avg: 11.609756097560975, max: 22)
#
# Run: 42, exploration: 0.11879805134519765, score: 9 | Scores: (min: 8, avg: 11.547619047619047, max: 22)
#
# Run: 43, exploration: 0.1135578192100607, score: 10 | Scores: (min: 8, avg: 11.511627906976743, max: 22)
#
# Run: 44, exploration: 0.1085487359239089, score: 10 | Scores: (min: 8, avg: 11.477272727272727, max: 22)
#
# Run: 45, exploration: 0.1042820154910064, score: 9 | Scores: (min: 8, avg: 11.422222222222222, max: 22)
#
# Run: 46, exploration: 0.09918368135888474, score: 11 | Scores: (min: 8, avg: 11.41304347826087, max: 22)
#
# Run: 47, exploration: 0.09480864735409487, score: 10 | Scores: (min: 8, avg: 11.382978723404255, max: 22)
#
# Run: 48, exploration: 0.09108200798387568, score: 9 | Scores: (min: 8, avg: 11.333333333333334, max: 22)
#
# Run: 49, exploration: 0.08706434220766679, score: 10 | Scores: (min: 8, avg: 11.306122448979592, max: 22)
#
# ####################
# Run: 50, exploration: 0.08280777787605056, score: 11 | Scores: (min: 8, avg: 11.3, max: 22)
#
# Run: 51, exploration: 0.07995261925574046, score: 8 | Scores: (min: 8, avg: 11.235294117647058, max: 22)
#
# Run: 52, exploration: 0.07680992513462537, score: 9 | Scores: (min: 8, avg: 11.192307692307692, max: 22)
#
# Run: 53, exploration: 0.07416156859737154, score: 8 | Scores: (min: 8, avg: 11.132075471698114, max: 22)
#
# Run: 54, exploration: 0.07018314008827135, score: 12 | Scores: (min: 8, avg: 11.148148148148149, max: 22)
#
# Run: 55, exploration: 0.06708733218678724, score: 10 | Scores: (min: 8, avg: 11.127272727272727, max: 22)
#
# Run: 56, exploration: 0.06412808167716157, score: 10 | Scores: (min: 8, avg: 11.107142857142858, max: 22)
#
# Run: 57, exploration: 0.06129936495526111, score: 10 | Scores: (min: 8, avg: 11.087719298245615, max: 22)
#
# Run: 58, exploration: 0.058889873488111255, score: 9 | Scores: (min: 8, avg: 11.051724137931034, max: 22)
#
# Run: 59, exploration: 0.056292216338080694, score: 10 | Scores: (min: 8, avg: 11.033898305084746, max: 22)
#
# ####################
# Run: 60, exploration: 0.05380914294022049, score: 10 | Scores: (min: 8, avg: 11.016666666666667, max: 22)
#
# Run: 61, exploration: 0.051178420962124486, score: 11 | Scores: (min: 8, avg: 11.01639344262295, max: 22)
#
# Run: 62, exploration: 0.04892091923449087, score: 10 | Scores: (min: 8, avg: 11, max: 22)
#
# Run: 63, exploration: 0.0451506389749415, score: 17 | Scores: (min: 8, avg: 11.095238095238095, max: 22)
#
# Run: 64, exploration: 0.0418803316354751, score: 16 | Scores: (min: 8, avg: 11.171875, max: 22)
#
# Run: 65, exploration: 0.03845939824099909, score: 18 | Scores: (min: 8, avg: 11.276923076923078, max: 22)
#
# Run: 66, exploration: 0.03514130927386981, score: 19 | Scores: (min: 8, avg: 11.393939393939394, max: 22)
#
# Run: 67, exploration: 0.031948941366546975, score: 20 | Scores: (min: 8, avg: 11.522388059701493, max: 22)
#
# Run: 68, exploration: 0.025754252208694463, score: 44 | Scores: (min: 8, avg: 12, max: 44)
#
# Run: 69, exploration: 0.024250791254731636, score: 13 | Scores: (min: 8, avg: 12.014492753623188, max: 44)
#
# ####################
# Run: 70, exploration: 0.021181128426399323, score: 28 | Scores: (min: 8, avg: 12.242857142857142, max: 44)
#
# Run: 71, exploration: 0.018969543067746772, score: 23 | Scores: (min: 8, avg: 12.394366197183098, max: 44)
#
# Run: 72, exploration: 0.0175075817047932, score: 17 | Scores: (min: 8, avg: 12.458333333333334, max: 44)
#
# Run: 73, exploration: 0.015215016325303928, score: 29 | Scores: (min: 8, avg: 12.684931506849315, max: 44)
#
# Run: 74, exploration: 0.013156542237201536, score: 30 | Scores: (min: 8, avg: 12.91891891891892, max: 44)
#
# Run: 75, exploration: 0.01, score: 78 | Scores: (min: 8, avg: 13.786666666666667, max: 78)
#
# Run: 76, exploration: 0.01, score: 26 | Scores: (min: 8, avg: 13.947368421052632, max: 78)
#
# Run: 77, exploration: 0.01, score: 28 | Scores: (min: 8, avg: 14.12987012987013, max: 78)
#
# Run: 78, exploration: 0.01, score: 37 | Scores: (min: 8, avg: 14.423076923076923, max: 78)
#
# Run: 79, exploration: 0.01, score: 75 | Scores: (min: 8, avg: 15.189873417721518, max: 78)
# ####################
# Run: 80, exploration: 0.01, score: 72 | Scores: (min: 8, avg: 15.9, max: 78)
#
# Run: 81, exploration: 0.01, score: 67 | Scores: (min: 8, avg: 16.530864197530864, max: 78)
#
# Run: 82, exploration: 0.01, score: 64 | Scores: (min: 8, avg: 17.109756097560975, max: 78)
#
# Run: 83, exploration: 0.01, score: 64 | Scores: (min: 8, avg: 17.674698795180724, max: 78)
#
# Run: 84, exploration: 0.01, score: 60 | Scores: (min: 8, avg: 18.178571428571427, max: 78)
#
# Run: 85, exploration: 0.01, score: 62 | Scores: (min: 8, avg: 18.694117647058825, max: 78)
#
# Run: 86, exploration: 0.01, score: 88 | Scores: (min: 8, avg: 19.5, max: 88)
#
# Run: 87, exploration: 0.01, score: 67 | Scores: (min: 8, avg: 20.04597701149425, max: 88)
#
# Run: 88, exploration: 0.01, score: 107 | Scores: (min: 8, avg: 21.03409090909091, max: 107)
#
# Run: 89, exploration: 0.01, score: 70 | Scores: (min: 8, avg: 21.584269662921347, max: 107)
#
# ####################
# Run: 90, exploration: 0.01, score: 80 | Scores: (min: 8, avg: 22.233333333333334, max: 107)
#
# Run: 91, exploration: 0.01, score: 64 | Scores: (min: 8, avg: 22.692307692307693, max: 107)
#
# Run: 92, exploration: 0.01, score: 79 | Scores: (min: 8, avg: 23.304347826086957, max: 107)
#
# Run: 93, exploration: 0.01, score: 57 | Scores: (min: 8, avg: 23.666666666666668, max: 107)
#
# Run: 94, exploration: 0.01, score: 37 | Scores: (min: 8, avg: 23.80851063829787, max: 107)
#
# Run: 95, exploration: 0.01, score: 72 | Scores: (min: 8, avg: 24.31578947368421, max: 107)
#
# Run: 96, exploration: 0.01, score: 90 | Scores: (min: 8, avg: 25, max: 107)
#
# Run: 97, exploration: 0.01, score: 87 | Scores: (min: 8, avg: 25.63917525773196, max: 107)
#
# Run: 98, exploration: 0.01, score: 86 | Scores: (min: 8, avg: 26.255102040816325, max: 107)
#
# Run: 99, exploration: 0.01, score: 172 | Scores: (min: 8, avg: 27.727272727272727, max: 172)
#
# ####################
# Run: 100, exploration: 0.01, score: 157 | Scores: (min: 8, avg: 29.02, max: 172)
#
# Run: 101, exploration: 0.01, score: 157 | Scores: (min: 8, avg: 30.45, max: 172)
#
# Run: 102, exploration: 0.01, score: 244 | Scores: (min: 8, avg: 32.69, max: 244)
#
# Run: 103, exploration: 0.01, score: 156 | Scores: (min: 8, avg: 34.11, max: 244)
#
# Run: 104, exploration: 0.01, score: 155 | Scores: (min: 8, avg: 35.44, max: 244)
#
# Run: 105, exploration: 0.01, score: 177 | Scores: (min: 8, avg: 37.01, max: 244)
#
# Run: 106, exploration: 0.01, score: 218 | Scores: (min: 8, avg: 39.09, max: 244)
#
# Run: 107, exploration: 0.01, score: 209 | Scores: (min: 8, avg: 41.07, max: 244)
#
# Run: 108, exploration: 0.01, score: 152 | Scores: (min: 8, avg: 42.4, max: 244)
#
# Run: 109, exploration: 0.01, score: 280 | Scores: (min: 8, avg: 45.08, max: 280)
#
# ####################
# Run: 110, exploration: 0.01, score: 232 | Scores: (min: 8, avg: 47.31, max: 280)
#
# Run: 111, exploration: 0.01, score: 254 | Scores: (min: 8, avg: 49.74, max: 280)
#
# Run: 112, exploration: 0.01, score: 203 | Scores: (min: 8, avg: 51.67, max: 280)
#
# Run: 113, exploration: 0.01, score: 228 | Scores: (min: 8, avg: 53.75, max: 280)
#
# Run: 114, exploration: 0.01, score: 235 | Scores: (min: 8, avg: 55.99, max: 280)
#
# Run: 115, exploration: 0.01, score: 304 | Scores: (min: 8, avg: 58.88, max: 304)
#
# Run: 116, exploration: 0.01, score: 251 | Scores: (min: 8, avg: 61.3, max: 304)
#
# Run: 117, exploration: 0.01, score: 219 | Scores: (min: 8, avg: 63.39, max: 304)
#
# Run: 118, exploration: 0.01, score: 223 | Scores: (min: 8, avg: 65.52, max: 304)
#
# Run: 119, exploration: 0.01, score: 244 | Scores: (min: 8, avg: 67.86, max: 304)
#
# ####################
# Run: 120, exploration: 0.01, score: 268 | Scores: (min: 8, avg: 70.42, max: 304)
#
# Run: 121, exploration: 0.01, score: 291 | Scores: (min: 8, avg: 73.2, max: 304)
#
# Run: 122, exploration: 0.01, score: 500 | Scores: (min: 8, avg: 78.11, max: 500)
#
# Run: 123, exploration: 0.01, score: 317 | Scores: (min: 8, avg: 81.18, max: 500)
#
# Run: 124, exploration: 0.01, score: 432 | Scores: (min: 8, avg: 85.37, max: 500)
#
# Run: 125, exploration: 0.01, score: 433 | Scores: (min: 8, avg: 89.61, max: 500)
#
# Run: 126, exploration: 0.01, score: 500 | Scores: (min: 8, avg: 94.52, max: 500)
#
# Run: 127, exploration: 0.01, score: 310 | Scores: (min: 8, avg: 97.52, max: 500)
#
# Run: 128, exploration: 0.01, score: 120 | Scores: (min: 8, avg: 98.62, max: 500)
#
# Run: 129, exploration: 0.01, score: 323 | Scores: (min: 8, avg: 101.75, max: 500)
#
# ####################
# Run: 130, exploration: 0.01, score: 196 | Scores: (min: 8, avg: 103.6, max: 500)
#
# Run: 131, exploration: 0.01, score: 198 | Scores: (min: 8, avg: 105.49, max: 500)
#
# Run: 132, exploration: 0.01, score: 149 | Scores: (min: 8, avg: 106.89, max: 500)
#
# Run: 133, exploration: 0.01, score: 274 | Scores: (min: 8, avg: 109.54, max: 500)
#
# Run: 134, exploration: 0.01, score: 161 | Scores: (min: 8, avg: 111.05, max: 500)
#
# Run: 135, exploration: 0.01, score: 228 | Scores: (min: 8, avg: 113.25, max: 500)
#
# Run: 136, exploration: 0.01, score: 150 | Scores: (min: 8, avg: 114.65, max: 500)
#
# Run: 137, exploration: 0.01, score: 130 | Scores: (min: 8, avg: 115.86, max: 500)
#
# Run: 138, exploration: 0.01, score: 167 | Scores: (min: 8, avg: 117.43, max: 500)
#
# Run: 139, exploration: 0.01, score: 205 | Scores: (min: 8, avg: 119.4, max: 500)
#
# ####################
# Run: 140, exploration: 0.01, score: 131 | Scores: (min: 8, avg: 120.59, max: 500)
#
# Run: 141, exploration: 0.01, score: 267 | Scores: (min: 8, avg: 123.17, max: 500)
#
# Run: 142, exploration: 0.01, score: 140 | Scores: (min: 8, avg: 124.48, max: 500)
#
# Run: 143, exploration: 0.01, score: 266 | Scores: (min: 8, avg: 127.04, max: 500)
#
# Run: 144, exploration: 0.01, score: 227 | Scores: (min: 8, avg: 129.21, max: 500)
#
# Run: 145, exploration: 0.01, score: 195 | Scores: (min: 8, avg: 131.07, max: 500)
#
# Run: 146, exploration: 0.01, score: 243 | Scores: (min: 8, avg: 133.39, max: 500)
#
# Run: 147, exploration: 0.01, score: 243 | Scores: (min: 8, avg: 135.72, max: 500)
#
# Run: 148, exploration: 0.01, score: 343 | Scores: (min: 8, avg: 139.06, max: 500)
#
# Run: 149, exploration: 0.01, score: 171 | Scores: (min: 8, avg: 140.67, max: 500)
#
# ####################
# Run: 150, exploration: 0.01, score: 168 | Scores: (min: 8, avg: 142.24, max: 500)
#
# Run: 151, exploration: 0.01, score: 237 | Scores: (min: 8, avg: 144.53, max: 500)
#
# Run: 152, exploration: 0.01, score: 196 | Scores: (min: 8, avg: 146.4, max: 500)
#
# Run: 153, exploration: 0.01, score: 115 | Scores: (min: 9, avg: 147.47, max: 500)
#
# Run: 154, exploration: 0.01, score: 66 | Scores: (min: 9, avg: 148.01, max: 500)
#
# Run: 155, exploration: 0.01, score: 223 | Scores: (min: 9, avg: 150.14, max: 500)
#
# Run: 156, exploration: 0.01, score: 284 | Scores: (min: 9, avg: 152.88, max: 500)
#
# Run: 157, exploration: 0.01, score: 199 | Scores: (min: 9, avg: 154.77, max: 500)
#
# Run: 158, exploration: 0.01, score: 188 | Scores: (min: 10, avg: 156.56, max: 500)
#
# Run: 159, exploration: 0.01, score: 336 | Scores: (min: 10, avg: 159.82, max: 500)
#
# ####################
# Run: 160, exploration: 0.01, score: 203 | Scores: (min: 10, avg: 161.75, max: 500)
#
# Run: 161, exploration: 0.01, score: 245 | Scores: (min: 10, avg: 164.09, max: 500)
#
# Run: 162, exploration: 0.01, score: 226 | Scores: (min: 13, avg: 166.25, max: 500)
#
# Run: 163, exploration: 0.01, score: 221 | Scores: (min: 13, avg: 168.29, max: 500)
#
# Run: 164, exploration: 0.01, score: 151 | Scores: (min: 13, avg: 169.64, max: 500)
#
# Run: 165, exploration: 0.01, score: 303 | Scores: (min: 13, avg: 172.49, max: 500)
#
# Run: 166, exploration: 0.01, score: 369 | Scores: (min: 13, avg: 175.99, max: 500)
#
# Run: 167, exploration: 0.01, score: 212 | Scores: (min: 13, avg: 177.91, max: 500)
#
# Run: 168, exploration: 0.01, score: 332 | Scores: (min: 13, avg: 180.79, max: 500)
#
# Run: 169, exploration: 0.01, score: 209 | Scores: (min: 17, avg: 182.75, max: 500)
#
# ####################
# Run: 170, exploration: 0.01, score: 143 | Scores: (min: 17, avg: 183.9, max: 500)
#
# Run: 171, exploration: 0.01, score: 162 | Scores: (min: 17, avg: 185.29, max: 500)
#
# Run: 172, exploration: 0.01, score: 234 | Scores: (min: 26, avg: 187.46, max: 500)
#
# Run: 173, exploration: 0.01, score: 430 | Scores: (min: 26, avg: 191.47, max: 500)
#
# Run: 174, exploration: 0.01, score: 359 | Scores: (min: 26, avg: 194.76, max: 500)
# Run: 175, exploration: 0.01, score: 206 | Scores: (min: 26, avg: 196.04, max: 500)
#
# Solved in 75 runs, 175 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-8c71437ff418> in <module>
#       2 reset_to_baseline_settings()
#       3 LEARNING_RATE = 0.0012
# ----> 4 cartpole(250)
#
# <ipython-input-4-6270a8499d29> in cartpole(max_run)
#      26                     print("####################")
#      27                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step), end=' | ')
# ---> 28                 score_logger.add_score(step, run)
#      29                 break
#      30             dqn_solver.experience_replay()
#
# U:\Cartpole\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %% [markdown]
# Next, decrease learning rate by .0002

# %%
# Note: the baseline average at run# 250 was 101.74
reset_to_baseline_settings()
LEARNING_RATE = 0.0008  
cartpole(250)
# Out:
# Run: 1, exploration: 1.0, score: 16 | Scores: (min: 16, avg: 16, max: 16)
#
# Run: 2, exploration: 0.9229311239742362, score: 20 | Scores: (min: 16, avg: 18, max: 20)
#
# Run: 3, exploration: 0.8866535105013078, score: 9 | Scores: (min: 9, avg: 15, max: 20)
#
# Run: 4, exploration: 0.7666961448653229, score: 30 | Scores: (min: 9, avg: 18.75, max: 30)
#
# Run: 5, exploration: 0.7219385759785162, score: 13 | Scores: (min: 9, avg: 17.6, max: 30)
#
# Run: 6, exploration: 0.6763948591909945, score: 14 | Scores: (min: 9, avg: 17, max: 30)
#
# Run: 7, exploration: 0.6465587967553006, score: 10 | Scores: (min: 9, avg: 16, max: 30)
#
# Run: 8, exploration: 0.6057704364907278, score: 14 | Scores: (min: 9, avg: 15.75, max: 30)
#
# Run: 9, exploration: 0.5618938591163328, score: 16 | Scores: (min: 9, avg: 15.777777777777779, max: 30)
#
# ####################
# Run: 10, exploration: 0.531750826943791, score: 12 | Scores: (min: 9, avg: 15.4, max: 30)
#
# Run: 11, exploration: 0.47622912292284103, score: 23 | Scores: (min: 9, avg: 16.09090909090909, max: 30)
#
# Run: 12, exploration: 0.43732904629000013, score: 18 | Scores: (min: 9, avg: 16.25, max: 30)
#
# Run: 13, exploration: 0.42013897252428334, score: 9 | Scores: (min: 9, avg: 15.692307692307692, max: 30)
#
# Run: 14, exploration: 0.3936343764094253, score: 14 | Scores: (min: 9, avg: 15.571428571428571, max: 30)
#
# Run: 15, exploration: 0.37816180712868996, score: 9 | Scores: (min: 9, avg: 15.133333333333333, max: 30)
#
# Run: 16, exploration: 0.3578751580867638, score: 12 | Scores: (min: 9, avg: 14.9375, max: 30)
#
# Run: 17, exploration: 0.3253644408394192, score: 20 | Scores: (min: 9, avg: 15.235294117647058, max: 30)
#
# Run: 18, exploration: 0.2913921604631864, score: 23 | Scores: (min: 9, avg: 15.666666666666666, max: 30)
#
# Run: 19, exploration: 0.24696734223472733, score: 34 | Scores: (min: 9, avg: 16.63157894736842, max: 34)
#
# ####################
# Run: 20, exploration: 0.2211807388415433, score: 23 | Scores: (min: 9, avg: 16.95, max: 34)
#
# Run: 21, exploration: 0.17919120740315364, score: 43 | Scores: (min: 9, avg: 18.19047619047619, max: 43)
#
# Run: 22, exploration: 0.11879805134519765, score: 83 | Scores: (min: 9, avg: 21.136363636363637, max: 83)
#
# Run: 23, exploration: 0.0996820918179746, score: 36 | Scores: (min: 9, avg: 21.782608695652176, max: 83)
#
# Run: 24, exploration: 0.09017346495423652, score: 21 | Scores: (min: 9, avg: 21.75, max: 83)
#
# Run: 25, exploration: 0.07528520976374668, score: 37 | Scores: (min: 9, avg: 22.36, max: 83)
#
# Run: 26, exploration: 0.06129936495526111, score: 42 | Scores: (min: 9, avg: 23.115384615384617, max: 83)
#
# Run: 27, exploration: 0.046997986793891174, score: 54 | Scores: (min: 9, avg: 24.25925925925926, max: 83)
#
# Run: 28, exploration: 0.034271518052411715, score: 64 | Scores: (min: 9, avg: 25.678571428571427, max: 83)
#
# Run: 29, exploration: 0.026807992814067, score: 50 | Scores: (min: 9, avg: 26.517241379310345, max: 83)
#
# ####################
# Run: 30, exploration: 0.019353724157029815, score: 66 | Scores: (min: 9, avg: 27.833333333333332, max: 83)
#
# Run: 31, exploration: 0.01, score: 147 | Scores: (min: 9, avg: 31.677419354838708, max: 147)
#
# Run: 32, exploration: 0.01, score: 196 | Scores: (min: 9, avg: 36.8125, max: 196)
#
# Run: 33, exploration: 0.01, score: 167 | Scores: (min: 9, avg: 40.75757575757576, max: 196)
#
# Run: 34, exploration: 0.01, score: 212 | Scores: (min: 9, avg: 45.794117647058826, max: 212)
#
# Run: 35, exploration: 0.01, score: 184 | Scores: (min: 9, avg: 49.74285714285714, max: 212)
#
# Run: 36, exploration: 0.01, score: 168 | Scores: (min: 9, avg: 53.02777777777778, max: 212)
#
# Run: 37, exploration: 0.01, score: 148 | Scores: (min: 9, avg: 55.5945945945946, max: 212)
#
# Run: 38, exploration: 0.01, score: 203 | Scores: (min: 9, avg: 59.473684210526315, max: 212)
#
# Run: 39, exploration: 0.01, score: 163 | Scores: (min: 9, avg: 62.12820512820513, max: 212)
#
# ####################
# Run: 40, exploration: 0.01, score: 272 | Scores: (min: 9, avg: 67.375, max: 272)
#
# Run: 41, exploration: 0.01, score: 233 | Scores: (min: 9, avg: 71.41463414634147, max: 272)
#
# Run: 42, exploration: 0.01, score: 332 | Scores: (min: 9, avg: 77.61904761904762, max: 332)
#
# Run: 43, exploration: 0.01, score: 217 | Scores: (min: 9, avg: 80.86046511627907, max: 332)
#
# Run: 44, exploration: 0.01, score: 202 | Scores: (min: 9, avg: 83.61363636363636, max: 332)
#
# Run: 45, exploration: 0.01, score: 190 | Scores: (min: 9, avg: 85.97777777777777, max: 332)
#
# Run: 46, exploration: 0.01, score: 217 | Scores: (min: 9, avg: 88.82608695652173, max: 332)
#
# Run: 47, exploration: 0.01, score: 177 | Scores: (min: 9, avg: 90.70212765957447, max: 332)
#
# Run: 48, exploration: 0.01, score: 190 | Scores: (min: 9, avg: 92.77083333333333, max: 332)
#
# Run: 49, exploration: 0.01, score: 176 | Scores: (min: 9, avg: 94.46938775510205, max: 332)
#
# ####################
# Run: 50, exploration: 0.01, score: 170 | Scores: (min: 9, avg: 95.98, max: 332)
#
# Run: 51, exploration: 0.01, score: 309 | Scores: (min: 9, avg: 100.15686274509804, max: 332)
#
# Run: 52, exploration: 0.01, score: 209 | Scores: (min: 9, avg: 102.25, max: 332)
#
# Run: 53, exploration: 0.01, score: 198 | Scores: (min: 9, avg: 104.05660377358491, max: 332)
#
# Run: 54, exploration: 0.01, score: 190 | Scores: (min: 9, avg: 105.64814814814815, max: 332)
#
# Run: 55, exploration: 0.01, score: 167 | Scores: (min: 9, avg: 106.76363636363637, max: 332)
#
# Run: 56, exploration: 0.01, score: 224 | Scores: (min: 9, avg: 108.85714285714286, max: 332)
#
# Run: 57, exploration: 0.01, score: 159 | Scores: (min: 9, avg: 109.73684210526316, max: 332)
#
# Run: 58, exploration: 0.01, score: 169 | Scores: (min: 9, avg: 110.75862068965517, max: 332)
#
# Run: 59, exploration: 0.01, score: 168 | Scores: (min: 9, avg: 111.72881355932203, max: 332)
#
# ####################
# Run: 60, exploration: 0.01, score: 139 | Scores: (min: 9, avg: 112.18333333333334, max: 332)
#
# Run: 61, exploration: 0.01, score: 158 | Scores: (min: 9, avg: 112.93442622950819, max: 332)
#
# Run: 62, exploration: 0.01, score: 160 | Scores: (min: 9, avg: 113.69354838709677, max: 332)
#
# Run: 63, exploration: 0.01, score: 200 | Scores: (min: 9, avg: 115.06349206349206, max: 332)
#
# Run: 64, exploration: 0.01, score: 211 | Scores: (min: 9, avg: 116.5625, max: 332)
#
# Run: 65, exploration: 0.01, score: 199 | Scores: (min: 9, avg: 117.83076923076923, max: 332)
#
# Run: 66, exploration: 0.01, score: 157 | Scores: (min: 9, avg: 118.42424242424242, max: 332)
#
# Run: 67, exploration: 0.01, score: 173 | Scores: (min: 9, avg: 119.23880597014926, max: 332)
#
# Run: 68, exploration: 0.01, score: 154 | Scores: (min: 9, avg: 119.75, max: 332)
#
# Run: 69, exploration: 0.01, score: 243 | Scores: (min: 9, avg: 121.53623188405797, max: 332)
#
# ####################
# Run: 70, exploration: 0.01, score: 154 | Scores: (min: 9, avg: 122, max: 332)
#
# Run: 71, exploration: 0.01, score: 46 | Scores: (min: 9, avg: 120.92957746478874, max: 332)
#
# Run: 72, exploration: 0.01, score: 215 | Scores: (min: 9, avg: 122.23611111111111, max: 332)
#
# Run: 73, exploration: 0.01, score: 238 | Scores: (min: 9, avg: 123.82191780821918, max: 332)
#
# Run: 74, exploration: 0.01, score: 186 | Scores: (min: 9, avg: 124.66216216216216, max: 332)
#
# Run: 75, exploration: 0.01, score: 210 | Scores: (min: 9, avg: 125.8, max: 332)
#
# Run: 76, exploration: 0.01, score: 195 | Scores: (min: 9, avg: 126.71052631578948, max: 332)
#
# Run: 77, exploration: 0.01, score: 156 | Scores: (min: 9, avg: 127.0909090909091, max: 332)
#
# Run: 78, exploration: 0.01, score: 133 | Scores: (min: 9, avg: 127.16666666666667, max: 332)
#
# Run: 79, exploration: 0.01, score: 32 | Scores: (min: 9, avg: 125.9620253164557, max: 332)
#
# ####################
# Run: 80, exploration: 0.01, score: 230 | Scores: (min: 9, avg: 127.2625, max: 332)
#
# Run: 81, exploration: 0.01, score: 292 | Scores: (min: 9, avg: 129.2962962962963, max: 332)
#
# Run: 82, exploration: 0.01, score: 82 | Scores: (min: 9, avg: 128.71951219512195, max: 332)
#
# Run: 83, exploration: 0.01, score: 166 | Scores: (min: 9, avg: 129.16867469879517, max: 332)
#
# Run: 84, exploration: 0.01, score: 305 | Scores: (min: 9, avg: 131.26190476190476, max: 332)
#
# Run: 85, exploration: 0.01, score: 173 | Scores: (min: 9, avg: 131.75294117647059, max: 332)
#
# Run: 86, exploration: 0.01, score: 242 | Scores: (min: 9, avg: 133.03488372093022, max: 332)
# Run: 87, exploration: 0.01, score: 233 | Scores: (min: 9, avg: 134.183908045977, max: 332)
#
# Run: 88, exploration: 0.01, score: 204 | Scores: (min: 9, avg: 134.97727272727272, max: 332)
#
# Run: 89, exploration: 0.01, score: 136 | Scores: (min: 9, avg: 134.98876404494382, max: 332)
#
# ####################
# Run: 90, exploration: 0.01, score: 482 | Scores: (min: 9, avg: 138.84444444444443, max: 482)
#
# Run: 91, exploration: 0.01, score: 211 | Scores: (min: 9, avg: 139.63736263736263, max: 482)
#
# Run: 92, exploration: 0.01, score: 191 | Scores: (min: 9, avg: 140.19565217391303, max: 482)
#
# Run: 93, exploration: 0.01, score: 183 | Scores: (min: 9, avg: 140.65591397849462, max: 482)
#
# Run: 94, exploration: 0.01, score: 227 | Scores: (min: 9, avg: 141.5744680851064, max: 482)
#
# Run: 95, exploration: 0.01, score: 210 | Scores: (min: 9, avg: 142.29473684210527, max: 482)
#
# Run: 96, exploration: 0.01, score: 251 | Scores: (min: 9, avg: 143.42708333333334, max: 482)
#
# Run: 97, exploration: 0.01, score: 86 | Scores: (min: 9, avg: 142.83505154639175, max: 482)
#
# Run: 98, exploration: 0.01, score: 207 | Scores: (min: 9, avg: 143.48979591836735, max: 482)
#
# Run: 99, exploration: 0.01, score: 206 | Scores: (min: 9, avg: 144.12121212121212, max: 482)
#
# ####################
# Run: 100, exploration: 0.01, score: 316 | Scores: (min: 9, avg: 145.84, max: 482)
#
# Run: 101, exploration: 0.01, score: 243 | Scores: (min: 9, avg: 148.11, max: 482)
#
# Run: 102, exploration: 0.01, score: 286 | Scores: (min: 9, avg: 150.77, max: 482)
#
# Run: 103, exploration: 0.01, score: 265 | Scores: (min: 9, avg: 153.33, max: 482)
#
# Run: 104, exploration: 0.01, score: 172 | Scores: (min: 9, avg: 154.75, max: 482)
#
# Run: 105, exploration: 0.01, score: 171 | Scores: (min: 9, avg: 156.33, max: 482)
#
# Run: 106, exploration: 0.01, score: 439 | Scores: (min: 9, avg: 160.58, max: 482)
#
# Run: 107, exploration: 0.01, score: 121 | Scores: (min: 9, avg: 161.69, max: 482)
#
# Run: 108, exploration: 0.01, score: 191 | Scores: (min: 9, avg: 163.46, max: 482)
#
# Run: 109, exploration: 0.01, score: 500 | Scores: (min: 9, avg: 168.3, max: 500)
#
# ####################
# Run: 110, exploration: 0.01, score: 280 | Scores: (min: 9, avg: 170.98, max: 500)
#
# Run: 111, exploration: 0.01, score: 251 | Scores: (min: 9, avg: 173.26, max: 500)
#
# Run: 112, exploration: 0.01, score: 354 | Scores: (min: 9, avg: 176.62, max: 500)
#
# Run: 113, exploration: 0.01, score: 131 | Scores: (min: 9, avg: 177.84, max: 500)
#
# Run: 114, exploration: 0.01, score: 435 | Scores: (min: 9, avg: 182.05, max: 500)
#
# Run: 115, exploration: 0.01, score: 292 | Scores: (min: 12, avg: 184.88, max: 500)
#
# Run: 116, exploration: 0.01, score: 105 | Scores: (min: 20, avg: 185.81, max: 500)
#
# Run: 117, exploration: 0.01, score: 236 | Scores: (min: 21, avg: 187.97, max: 500)
#
# Run: 118, exploration: 0.01, score: 223 | Scores: (min: 21, avg: 189.97, max: 500)
#
# Run: 119, exploration: 0.01, score: 305 | Scores: (min: 21, avg: 192.68, max: 500)
#
# ####################
# Run: 120, exploration: 0.01, score: 208 | Scores: (min: 21, avg: 194.53, max: 500)
#
# Run: 121, exploration: 0.01, score: 144 | Scores: (min: 21, avg: 195.54, max: 500)
#
# Solved in 21 runs, 121 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-afb5429bdb8f> in <module>
#       2 reset_to_baseline_settings()
#       3 LEARNING_RATE = 0.0008
# ----> 4 cartpole(250)
#
# <ipython-input-4-6270a8499d29> in cartpole(max_run)
#      26                     print("####################")
#      27                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step), end=' | ')
# ---> 28                 score_logger.add_score(step, run)
#      29                 break
#      30             dqn_solver.experience_replay()
#
# U:\Cartpole\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %% [markdown]
# Next, we will change the exploration factor by increasing exploration_max by .2

# %%
# Note: the baseline average at run# 250 was 101.74
reset_to_baseline_settings()
EXPLORATION_MAX = 1.2
cartpole(250)
# Out:
# Run: 1, exploration: 1.1702985037462499, score: 25 | Scores: (min: 25, avg: 25, max: 25)
#
# Run: 2, exploration: 1.080104913447893, score: 17 | Scores: (min: 17, avg: 21, max: 25)
#
# Run: 3, exploration: 1.0221622315204157, score: 12 | Scores: (min: 12, avg: 18, max: 25)
#
# Run: 4, exploration: 0.9339750684823697, score: 19 | Scores: (min: 12, avg: 18.25, max: 25)
#
# Run: 5, exploration: 0.8364559210025934, score: 23 | Scores: (min: 12, avg: 19.2, max: 25)
#
# Run: 6, exploration: 0.7915838916528757, score: 12 | Scores: (min: 12, avg: 18, max: 25)
#
# Run: 7, exploration: 0.75288345846457, score: 11 | Scores: (min: 11, avg: 17, max: 25)
#
# Run: 8, exploration: 0.719673451664079, score: 10 | Scores: (min: 10, avg: 16.125, max: 25)
#
# Run: 9, exploration: 0.6776609356176874, score: 13 | Scores: (min: 10, avg: 15.777777777777779, max: 25)
#
# ####################
# Run: 10, exploration: 0.6349104873708861, score: 14 | Scores: (min: 10, avg: 15.6, max: 25)
#
# Run: 11, exploration: 0.6008504474950233, score: 12 | Scores: (min: 10, avg: 15.272727272727273, max: 25)
#
# Run: 12, exploration: 0.5629456124814924, score: 14 | Scores: (min: 10, avg: 15.166666666666666, max: 25)
#
# Run: 13, exploration: 0.516962226729589, score: 18 | Scores: (min: 10, avg: 15.384615384615385, max: 25)
#
# Run: 14, exploration: 0.49415880493533193, score: 10 | Scores: (min: 10, avg: 15, max: 25)
#
# Run: 15, exploration: 0.46764944820568916, score: 12 | Scores: (min: 10, avg: 14.8, max: 25)
#
# Run: 16, exploration: 0.4447861276951592, score: 11 | Scores: (min: 10, avg: 14.5625, max: 25)
#
# Run: 17, exploration: 0.42304059194150834, score: 11 | Scores: (min: 10, avg: 14.352941176470589, max: 25)
#
# Run: 18, exploration: 0.39834466962268217, score: 13 | Scores: (min: 10, avg: 14.277777777777779, max: 25)
#
# Run: 19, exploration: 0.37886965069517403, score: 11 | Scores: (min: 10, avg: 14.105263157894736, max: 25)
#
# ####################
# Run: 20, exploration: 0.35854502908769736, score: 12 | Scores: (min: 10, avg: 14, max: 25)
#
# Run: 21, exploration: 0.33761417669475413, score: 13 | Scores: (min: 10, avg: 13.952380952380953, max: 25)
#
# Run: 22, exploration: 0.3195027223250256, score: 12 | Scores: (min: 10, avg: 13.863636363636363, max: 25)
#
# Run: 23, exploration: 0.30388227591472433, score: 11 | Scores: (min: 10, avg: 13.73913043478261, max: 25)
#
# Run: 24, exploration: 0.28902551109148905, score: 11 | Scores: (min: 10, avg: 13.625, max: 25)
#
# Run: 25, exploration: 0.26809109528532266, score: 16 | Scores: (min: 10, avg: 13.72, max: 25)
#
# Run: 26, exploration: 0.2562654840337035, score: 10 | Scores: (min: 10, avg: 13.576923076923077, max: 25)
#
# Run: 27, exploration: 0.24496150548057274, score: 10 | Scores: (min: 10, avg: 13.444444444444445, max: 25)
#
# Run: 28, exploration: 0.23182044258953585, score: 12 | Scores: (min: 10, avg: 13.392857142857142, max: 25)
#
# Run: 29, exploration: 0.21182010748051255, score: 19 | Scores: (min: 10, avg: 13.586206896551724, max: 25)
#
# ####################
# Run: 30, exploration: 0.19065661571396866, score: 22 | Scores: (min: 10, avg: 13.866666666666667, max: 25)
#
# Run: 31, exploration: 0.1682011258349737, score: 26 | Scores: (min: 10, avg: 14.258064516129032, max: 26)
#
# Run: 32, exploration: 0.1552380541206042, score: 17 | Scores: (min: 10, avg: 14.34375, max: 26)
#
# Run: 33, exploration: 0.13025848310869048, score: 36 | Scores: (min: 10, avg: 15, max: 36)
#
# Run: 34, exploration: 0.10766711715535832, score: 39 | Scores: (min: 10, avg: 15.705882352941176, max: 39)
#
# Run: 35, exploration: 0.05364031362139977, score: 140 | Scores: (min: 10, avg: 19.257142857142856, max: 140)
#
# Run: 36, exploration: 0.0339931692233392, score: 92 | Scores: (min: 10, avg: 21.27777777777778, max: 140)
#
# Run: 37, exploration: 0.02567344674294003, score: 57 | Scores: (min: 10, avg: 22.243243243243242, max: 140)
#
# Run: 38, exploration: 0.013928361466644137, score: 123 | Scores: (min: 10, avg: 24.894736842105264, max: 140)
#
# Run: 39, exploration: 0.01, score: 89 | Scores: (min: 10, avg: 26.53846153846154, max: 140)
#
# ####################
# Run: 40, exploration: 0.01, score: 63 | Scores: (min: 10, avg: 27.45, max: 140)
#
# Run: 41, exploration: 0.01, score: 81 | Scores: (min: 10, avg: 28.75609756097561, max: 140)
#
# Run: 42, exploration: 0.01, score: 104 | Scores: (min: 10, avg: 30.547619047619047, max: 140)
#
# Run: 43, exploration: 0.01, score: 49 | Scores: (min: 10, avg: 30.976744186046513, max: 140)
#
# Run: 44, exploration: 0.01, score: 57 | Scores: (min: 10, avg: 31.568181818181817, max: 140)
#
# Run: 45, exploration: 0.01, score: 64 | Scores: (min: 10, avg: 32.28888888888889, max: 140)
#
# Run: 46, exploration: 0.01, score: 68 | Scores: (min: 10, avg: 33.06521739130435, max: 140)
#
# Run: 47, exploration: 0.01, score: 120 | Scores: (min: 10, avg: 34.91489361702128, max: 140)
#
# Run: 48, exploration: 0.01, score: 89 | Scores: (min: 10, avg: 36.041666666666664, max: 140)
#
# Run: 49, exploration: 0.01, score: 121 | Scores: (min: 10, avg: 37.775510204081634, max: 140)
#
# ####################
# Run: 50, exploration: 0.01, score: 108 | Scores: (min: 10, avg: 39.18, max: 140)
#
# Run: 51, exploration: 0.01, score: 135 | Scores: (min: 10, avg: 41.05882352941177, max: 140)
#
# Run: 52, exploration: 0.01, score: 152 | Scores: (min: 10, avg: 43.19230769230769, max: 152)
#
# Run: 53, exploration: 0.01, score: 132 | Scores: (min: 10, avg: 44.867924528301884, max: 152)
#
# Run: 54, exploration: 0.01, score: 103 | Scores: (min: 10, avg: 45.94444444444444, max: 152)
#
# Run: 55, exploration: 0.01, score: 147 | Scores: (min: 10, avg: 47.78181818181818, max: 152)
#
# Run: 56, exploration: 0.01, score: 157 | Scores: (min: 10, avg: 49.732142857142854, max: 157)
#
# Run: 57, exploration: 0.01, score: 128 | Scores: (min: 10, avg: 51.10526315789474, max: 157)
#
# Run: 58, exploration: 0.01, score: 150 | Scores: (min: 10, avg: 52.810344827586206, max: 157)
#
# Run: 59, exploration: 0.01, score: 254 | Scores: (min: 10, avg: 56.220338983050844, max: 254)
#
# ####################
# Run: 60, exploration: 0.01, score: 179 | Scores: (min: 10, avg: 58.266666666666666, max: 254)
#
# Run: 61, exploration: 0.01, score: 198 | Scores: (min: 10, avg: 60.557377049180324, max: 254)
#
# Run: 62, exploration: 0.01, score: 194 | Scores: (min: 10, avg: 62.70967741935484, max: 254)
#
# Run: 63, exploration: 0.01, score: 208 | Scores: (min: 10, avg: 65.01587301587301, max: 254)
#
# Run: 64, exploration: 0.01, score: 164 | Scores: (min: 10, avg: 66.5625, max: 254)
#
# Run: 65, exploration: 0.01, score: 259 | Scores: (min: 10, avg: 69.52307692307693, max: 259)
#
# Run: 66, exploration: 0.01, score: 194 | Scores: (min: 10, avg: 71.4090909090909, max: 259)
#
# Run: 67, exploration: 0.01, score: 207 | Scores: (min: 10, avg: 73.43283582089552, max: 259)
#
# Run: 68, exploration: 0.01, score: 300 | Scores: (min: 10, avg: 76.76470588235294, max: 300)
#
# Run: 69, exploration: 0.01, score: 500 | Scores: (min: 10, avg: 82.89855072463769, max: 500)
#
# ####################
# Run: 70, exploration: 0.01, score: 262 | Scores: (min: 10, avg: 85.45714285714286, max: 500)
#
# Run: 71, exploration: 0.01, score: 191 | Scores: (min: 10, avg: 86.94366197183099, max: 500)
#
# Run: 72, exploration: 0.01, score: 182 | Scores: (min: 10, avg: 88.26388888888889, max: 500)
#
# Run: 73, exploration: 0.01, score: 137 | Scores: (min: 10, avg: 88.93150684931507, max: 500)
#
# Run: 74, exploration: 0.01, score: 152 | Scores: (min: 10, avg: 89.78378378378379, max: 500)
#
# Run: 75, exploration: 0.01, score: 153 | Scores: (min: 10, avg: 90.62666666666667, max: 500)
#
# Run: 76, exploration: 0.01, score: 168 | Scores: (min: 10, avg: 91.64473684210526, max: 500)
#
# Run: 77, exploration: 0.01, score: 150 | Scores: (min: 10, avg: 92.40259740259741, max: 500)
#
# Run: 78, exploration: 0.01, score: 210 | Scores: (min: 10, avg: 93.91025641025641, max: 500)
#
# Run: 79, exploration: 0.01, score: 240 | Scores: (min: 10, avg: 95.75949367088607, max: 500)
#
# ####################
# Run: 80, exploration: 0.01, score: 201 | Scores: (min: 10, avg: 97.075, max: 500)
#
# Run: 81, exploration: 0.01, score: 219 | Scores: (min: 10, avg: 98.58024691358025, max: 500)
#
# Run: 82, exploration: 0.01, score: 159 | Scores: (min: 10, avg: 99.3170731707317, max: 500)
#
# Run: 83, exploration: 0.01, score: 151 | Scores: (min: 10, avg: 99.93975903614458, max: 500)
#
# Run: 84, exploration: 0.01, score: 244 | Scores: (min: 10, avg: 101.6547619047619, max: 500)
# Run: 85, exploration: 0.01, score: 130 | Scores: (min: 10, avg: 101.98823529411764, max: 500)
#
# Run: 86, exploration: 0.01, score: 176 | Scores: (min: 10, avg: 102.84883720930233, max: 500)
#
# Run: 87, exploration: 0.01, score: 174 | Scores: (min: 10, avg: 103.66666666666667, max: 500)
#
# Run: 88, exploration: 0.01, score: 320 | Scores: (min: 10, avg: 106.125, max: 500)
#
# Run: 89, exploration: 0.01, score: 327 | Scores: (min: 10, avg: 108.6067415730337, max: 500)
#
# ####################
# Run: 90, exploration: 0.01, score: 152 | Scores: (min: 10, avg: 109.08888888888889, max: 500)
#
# Run: 91, exploration: 0.01, score: 176 | Scores: (min: 10, avg: 109.82417582417582, max: 500)
#
# Run: 92, exploration: 0.01, score: 275 | Scores: (min: 10, avg: 111.6195652173913, max: 500)
#
# Run: 93, exploration: 0.01, score: 236 | Scores: (min: 10, avg: 112.95698924731182, max: 500)
#
# Run: 94, exploration: 0.01, score: 239 | Scores: (min: 10, avg: 114.29787234042553, max: 500)
#
# Run: 95, exploration: 0.01, score: 236 | Scores: (min: 10, avg: 115.57894736842105, max: 500)
#
# Run: 96, exploration: 0.01, score: 200 | Scores: (min: 10, avg: 116.45833333333333, max: 500)
#
# Run: 97, exploration: 0.01, score: 128 | Scores: (min: 10, avg: 116.57731958762886, max: 500)
#
# Run: 98, exploration: 0.01, score: 259 | Scores: (min: 10, avg: 118.03061224489795, max: 500)
#
# Run: 99, exploration: 0.01, score: 280 | Scores: (min: 10, avg: 119.66666666666667, max: 500)
#
# ####################
# Run: 100, exploration: 0.01, score: 192 | Scores: (min: 10, avg: 120.39, max: 500)
#
# Run: 101, exploration: 0.01, score: 236 | Scores: (min: 10, avg: 122.5, max: 500)
#
# Run: 102, exploration: 0.01, score: 190 | Scores: (min: 10, avg: 124.23, max: 500)
#
# Run: 103, exploration: 0.01, score: 163 | Scores: (min: 10, avg: 125.74, max: 500)
#
# Run: 104, exploration: 0.01, score: 228 | Scores: (min: 10, avg: 127.83, max: 500)
#
# Run: 105, exploration: 0.01, score: 278 | Scores: (min: 10, avg: 130.38, max: 500)
#
# Run: 106, exploration: 0.01, score: 137 | Scores: (min: 10, avg: 131.63, max: 500)
#
# Run: 107, exploration: 0.01, score: 144 | Scores: (min: 10, avg: 132.96, max: 500)
#
# Run: 108, exploration: 0.01, score: 142 | Scores: (min: 10, avg: 134.28, max: 500)
#
# Run: 109, exploration: 0.01, score: 233 | Scores: (min: 10, avg: 136.48, max: 500)
#
# ####################
# Run: 110, exploration: 0.01, score: 246 | Scores: (min: 10, avg: 138.8, max: 500)
#
# Run: 111, exploration: 0.01, score: 162 | Scores: (min: 10, avg: 140.3, max: 500)
#
# Run: 112, exploration: 0.01, score: 228 | Scores: (min: 10, avg: 142.44, max: 500)
#
# Run: 113, exploration: 0.01, score: 177 | Scores: (min: 10, avg: 144.03, max: 500)
#
# Run: 114, exploration: 0.01, score: 49 | Scores: (min: 10, avg: 144.42, max: 500)
#
# Run: 115, exploration: 0.01, score: 106 | Scores: (min: 10, avg: 145.36, max: 500)
#
# Run: 116, exploration: 0.01, score: 222 | Scores: (min: 10, avg: 147.47, max: 500)
#
# Run: 117, exploration: 0.01, score: 159 | Scores: (min: 10, avg: 148.95, max: 500)
#
# Run: 118, exploration: 0.01, score: 145 | Scores: (min: 10, avg: 150.27, max: 500)
#
# Run: 119, exploration: 0.01, score: 191 | Scores: (min: 10, avg: 152.07, max: 500)
#
# ####################
# Run: 120, exploration: 0.01, score: 160 | Scores: (min: 10, avg: 153.55, max: 500)
#
# Run: 121, exploration: 0.01, score: 265 | Scores: (min: 10, avg: 156.07, max: 500)
#
# Run: 122, exploration: 0.01, score: 270 | Scores: (min: 10, avg: 158.65, max: 500)
#
# Run: 123, exploration: 0.01, score: 140 | Scores: (min: 10, avg: 159.94, max: 500)
#
# Run: 124, exploration: 0.01, score: 304 | Scores: (min: 10, avg: 162.87, max: 500)
#
# Run: 125, exploration: 0.01, score: 48 | Scores: (min: 10, avg: 163.19, max: 500)
#
# Run: 126, exploration: 0.01, score: 247 | Scores: (min: 10, avg: 165.56, max: 500)
#
# Run: 127, exploration: 0.01, score: 148 | Scores: (min: 12, avg: 166.94, max: 500)
#
# Run: 128, exploration: 0.01, score: 186 | Scores: (min: 17, avg: 168.68, max: 500)
#
# Run: 129, exploration: 0.01, score: 220 | Scores: (min: 17, avg: 170.69, max: 500)
#
# ####################
# Run: 130, exploration: 0.01, score: 322 | Scores: (min: 17, avg: 173.69, max: 500)
#
# Run: 131, exploration: 0.01, score: 298 | Scores: (min: 17, avg: 176.41, max: 500)
#
# Run: 132, exploration: 0.01, score: 340 | Scores: (min: 36, avg: 179.64, max: 500)
#
# Run: 133, exploration: 0.01, score: 110 | Scores: (min: 39, avg: 180.38, max: 500)
#
# Run: 134, exploration: 0.01, score: 113 | Scores: (min: 48, avg: 181.12, max: 500)
#
# Run: 135, exploration: 0.01, score: 189 | Scores: (min: 48, avg: 181.61, max: 500)
#
# Run: 136, exploration: 0.01, score: 221 | Scores: (min: 48, avg: 182.9, max: 500)
#
# Run: 137, exploration: 0.01, score: 149 | Scores: (min: 48, avg: 183.82, max: 500)
#
# Run: 138, exploration: 0.01, score: 87 | Scores: (min: 48, avg: 183.46, max: 500)
#
# Run: 139, exploration: 0.01, score: 172 | Scores: (min: 48, avg: 184.29, max: 500)
#
# ####################
# Run: 140, exploration: 0.01, score: 244 | Scores: (min: 48, avg: 186.1, max: 500)
#
# Run: 141, exploration: 0.01, score: 252 | Scores: (min: 48, avg: 187.81, max: 500)
#
# Run: 142, exploration: 0.01, score: 144 | Scores: (min: 48, avg: 188.21, max: 500)
#
# Run: 143, exploration: 0.01, score: 212 | Scores: (min: 48, avg: 189.84, max: 500)
#
# Run: 144, exploration: 0.01, score: 173 | Scores: (min: 48, avg: 191, max: 500)
#
# Run: 145, exploration: 0.01, score: 205 | Scores: (min: 48, avg: 192.41, max: 500)
#
# Run: 146, exploration: 0.01, score: 164 | Scores: (min: 48, avg: 193.37, max: 500)
#
# Run: 147, exploration: 0.01, score: 368 | Scores: (min: 48, avg: 195.85, max: 500)
#
# Solved in 47 runs, 147 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-2bc317cdbaeb> in <module>
#       2 reset_to_baseline_settings()
#       3 EXPLORATION_MAX = 1.2
# ----> 4 cartpole(250)
#
# <ipython-input-4-6270a8499d29> in cartpole(max_run)
#      26                     print("####################")
#      27                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step), end=' | ')
# ---> 28                 score_logger.add_score(step, run)
#      29                 break
#      30             dqn_solver.experience_replay()
#
# U:\Cartpole\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %% [markdown]
# Next, we will change the exploration factor by decreasing exploration_max by .2

# %%
# Note: the baseline average at run# 250 was 101.74
reset_to_baseline_settings()
EXPLORATION_MAX = .8
cartpole(250)
# Out:
# Run: 1, exploration: 0.8, score: 14 | Scores: (min: 14, avg: 14, max: 14)
#
# Run: 2, exploration: 0.6481259022523785, score: 48 | Scores: (min: 14, avg: 31, max: 48)
#
# Run: 3, exploration: 0.6102901313127972, score: 13 | Scores: (min: 13, avg: 25, max: 48)
#
# Run: 4, exploration: 0.5775508607828131, score: 12 | Scores: (min: 12, avg: 21.75, max: 48)
#
# Run: 5, exploration: 0.5465679021770115, score: 12 | Scores: (min: 12, avg: 19.8, max: 48)
#
# Run: 6, exploration: 0.5095270607151027, score: 15 | Scores: (min: 12, avg: 19, max: 48)
#
# Run: 7, exploration: 0.47262149029254136, score: 16 | Scores: (min: 12, avg: 18.571428571428573, max: 48)
#
# Run: 8, exploration: 0.43838902839203386, score: 16 | Scores: (min: 12, avg: 18.25, max: 48)
#
# Run: 9, exploration: 0.40257986431827397, score: 18 | Scores: (min: 12, avg: 18.22222222222222, max: 48)
#
# ####################
# Run: 10, exploration: 0.3848218967584385, score: 10 | Scores: (min: 10, avg: 17.4, max: 48)
#
# Run: 11, exploration: 0.36969571923133676, score: 9 | Scores: (min: 9, avg: 16.636363636363637, max: 48)
#
# Run: 12, exploration: 0.3429182770639612, score: 16 | Scores: (min: 9, avg: 16.583333333333332, max: 48)
#
# Run: 13, exploration: 0.26159955042365357, score: 55 | Scores: (min: 9, avg: 19.53846153846154, max: 55)
#
# Run: 14, exploration: 0.18980784614017332, score: 65 | Scores: (min: 9, avg: 22.785714285714285, max: 65)
#
# Run: 15, exploration: 0.1616786763089362, score: 33 | Scores: (min: 9, avg: 23.466666666666665, max: 65)
#
# Run: 16, exploration: 0.13098517244712451, score: 43 | Scores: (min: 9, avg: 24.6875, max: 65)
#
# Run: 17, exploration: 0.10143766748287157, score: 52 | Scores: (min: 9, avg: 26.294117647058822, max: 65)
#
# Run: 18, exploration: 0.07777186860324815, score: 54 | Scores: (min: 9, avg: 27.833333333333332, max: 65)
#
# Run: 19, exploration: 0.06332407350293168, score: 42 | Scores: (min: 9, avg: 28.57894736842105, max: 65)
#
# ####################
# Run: 20, exploration: 0.05475681588901173, score: 30 | Scores: (min: 9, avg: 28.65, max: 65)
#
# Run: 21, exploration: 0.035581408035528596, score: 87 | Scores: (min: 9, avg: 31.428571428571427, max: 87)
#
# Run: 22, exploration: 0.02700800908923182, score: 56 | Scores: (min: 9, avg: 32.54545454545455, max: 87)
#
# Run: 23, exploration: 0.019992974673876045, score: 61 | Scores: (min: 9, avg: 33.78260869565217, max: 87)
#
# Run: 24, exploration: 0.017201639358753833, score: 31 | Scores: (min: 9, avg: 33.666666666666664, max: 87)
#
# Run: 25, exploration: 0.012797690478054709, score: 60 | Scores: (min: 9, avg: 34.72, max: 87)
#
# Run: 26, exploration: 0.01, score: 154 | Scores: (min: 9, avg: 39.30769230769231, max: 154)
#
# Run: 27, exploration: 0.01, score: 279 | Scores: (min: 9, avg: 48.18518518518518, max: 279)
#
# Run: 28, exploration: 0.01, score: 179 | Scores: (min: 9, avg: 52.857142857142854, max: 279)
#
# Run: 29, exploration: 0.01, score: 238 | Scores: (min: 9, avg: 59.241379310344826, max: 279)
#
# ####################
# Run: 30, exploration: 0.01, score: 203 | Scores: (min: 9, avg: 64.03333333333333, max: 279)
#
# Run: 31, exploration: 0.01, score: 228 | Scores: (min: 9, avg: 69.3225806451613, max: 279)
#
# Run: 32, exploration: 0.01, score: 308 | Scores: (min: 9, avg: 76.78125, max: 308)
#
# Run: 33, exploration: 0.01, score: 166 | Scores: (min: 9, avg: 79.48484848484848, max: 308)
#
# Run: 34, exploration: 0.01, score: 379 | Scores: (min: 9, avg: 88.29411764705883, max: 379)
#
# Run: 35, exploration: 0.01, score: 259 | Scores: (min: 9, avg: 93.17142857142858, max: 379)
#
# Run: 36, exploration: 0.01, score: 237 | Scores: (min: 9, avg: 97.16666666666667, max: 379)
#
# Run: 37, exploration: 0.01, score: 219 | Scores: (min: 9, avg: 100.45945945945945, max: 379)
#
# Run: 38, exploration: 0.01, score: 178 | Scores: (min: 9, avg: 102.5, max: 379)
#
# Run: 39, exploration: 0.01, score: 187 | Scores: (min: 9, avg: 104.66666666666667, max: 379)
#
# ####################
# Run: 40, exploration: 0.01, score: 173 | Scores: (min: 9, avg: 106.375, max: 379)
#
# Run: 41, exploration: 0.01, score: 283 | Scores: (min: 9, avg: 110.6829268292683, max: 379)
#
# Run: 42, exploration: 0.01, score: 258 | Scores: (min: 9, avg: 114.19047619047619, max: 379)
#
# Run: 43, exploration: 0.01, score: 205 | Scores: (min: 9, avg: 116.30232558139535, max: 379)
#
# Run: 44, exploration: 0.01, score: 292 | Scores: (min: 9, avg: 120.29545454545455, max: 379)
#
# Run: 45, exploration: 0.01, score: 270 | Scores: (min: 9, avg: 123.62222222222222, max: 379)
#
# Run: 46, exploration: 0.01, score: 205 | Scores: (min: 9, avg: 125.3913043478261, max: 379)
#
# Run: 47, exploration: 0.01, score: 356 | Scores: (min: 9, avg: 130.29787234042553, max: 379)
#
# Run: 48, exploration: 0.01, score: 239 | Scores: (min: 9, avg: 132.5625, max: 379)
#
# Run: 49, exploration: 0.01, score: 500 | Scores: (min: 9, avg: 140.0612244897959, max: 500)
#
# ####################
# Run: 50, exploration: 0.01, score: 500 | Scores: (min: 9, avg: 147.26, max: 500)
#
# Run: 51, exploration: 0.01, score: 452 | Scores: (min: 9, avg: 153.23529411764707, max: 500)
#
# Run: 52, exploration: 0.01, score: 208 | Scores: (min: 9, avg: 154.28846153846155, max: 500)
#
# Run: 53, exploration: 0.01, score: 188 | Scores: (min: 9, avg: 154.9245283018868, max: 500)
#
# Run: 54, exploration: 0.01, score: 217 | Scores: (min: 9, avg: 156.07407407407408, max: 500)
#
# Run: 55, exploration: 0.01, score: 195 | Scores: (min: 9, avg: 156.78181818181818, max: 500)
#
# Run: 56, exploration: 0.01, score: 237 | Scores: (min: 9, avg: 158.21428571428572, max: 500)
#
# Run: 57, exploration: 0.01, score: 286 | Scores: (min: 9, avg: 160.4561403508772, max: 500)
#
# Run: 58, exploration: 0.01, score: 270 | Scores: (min: 9, avg: 162.3448275862069, max: 500)
#
# Run: 59, exploration: 0.01, score: 238 | Scores: (min: 9, avg: 163.6271186440678, max: 500)
#
# ####################
# Run: 60, exploration: 0.01, score: 192 | Scores: (min: 9, avg: 164.1, max: 500)
#
# Run: 61, exploration: 0.01, score: 180 | Scores: (min: 9, avg: 164.36065573770492, max: 500)
#
# Run: 62, exploration: 0.01, score: 203 | Scores: (min: 9, avg: 164.98387096774192, max: 500)
#
# Run: 63, exploration: 0.01, score: 148 | Scores: (min: 9, avg: 164.71428571428572, max: 500)
#
# Run: 64, exploration: 0.01, score: 237 | Scores: (min: 9, avg: 165.84375, max: 500)
#
# Run: 65, exploration: 0.01, score: 239 | Scores: (min: 9, avg: 166.96923076923076, max: 500)
#
# Run: 66, exploration: 0.01, score: 271 | Scores: (min: 9, avg: 168.54545454545453, max: 500)
#
# Run: 67, exploration: 0.01, score: 260 | Scores: (min: 9, avg: 169.91044776119404, max: 500)
#
# Run: 68, exploration: 0.01, score: 272 | Scores: (min: 9, avg: 171.41176470588235, max: 500)
#
# Run: 69, exploration: 0.01, score: 333 | Scores: (min: 9, avg: 173.7536231884058, max: 500)
#
# ####################
# Run: 70, exploration: 0.01, score: 179 | Scores: (min: 9, avg: 173.82857142857142, max: 500)
#
# Run: 71, exploration: 0.01, score: 208 | Scores: (min: 9, avg: 174.30985915492957, max: 500)
#
# Run: 72, exploration: 0.01, score: 182 | Scores: (min: 9, avg: 174.41666666666666, max: 500)
#
# Run: 73, exploration: 0.01, score: 248 | Scores: (min: 9, avg: 175.42465753424656, max: 500)
#
# Run: 74, exploration: 0.01, score: 167 | Scores: (min: 9, avg: 175.3108108108108, max: 500)
#
# Run: 75, exploration: 0.01, score: 204 | Scores: (min: 9, avg: 175.69333333333333, max: 500)
#
# Run: 76, exploration: 0.01, score: 211 | Scores: (min: 9, avg: 176.1578947368421, max: 500)
#
# Run: 77, exploration: 0.01, score: 196 | Scores: (min: 9, avg: 176.41558441558442, max: 500)
#
# Run: 78, exploration: 0.01, score: 212 | Scores: (min: 9, avg: 176.87179487179486, max: 500)
#
# Run: 79, exploration: 0.01, score: 215 | Scores: (min: 9, avg: 177.35443037974684, max: 500)
#
# ####################
# Run: 80, exploration: 0.01, score: 204 | Scores: (min: 9, avg: 177.6875, max: 500)
#
# Run: 81, exploration: 0.01, score: 192 | Scores: (min: 9, avg: 177.8641975308642, max: 500)
#
# Run: 82, exploration: 0.01, score: 196 | Scores: (min: 9, avg: 178.08536585365854, max: 500)
#
# Run: 83, exploration: 0.01, score: 302 | Scores: (min: 9, avg: 179.57831325301206, max: 500)
#
# Run: 84, exploration: 0.01, score: 126 | Scores: (min: 9, avg: 178.9404761904762, max: 500)
#
# Run: 85, exploration: 0.01, score: 22 | Scores: (min: 9, avg: 177.09411764705882, max: 500)
# Run: 86, exploration: 0.01, score: 9 | Scores: (min: 9, avg: 175.13953488372093, max: 500)
#
# Run: 87, exploration: 0.01, score: 14 | Scores: (min: 9, avg: 173.28735632183907, max: 500)
#
# Run: 88, exploration: 0.01, score: 12 | Scores: (min: 9, avg: 171.45454545454547, max: 500)
#
# Run: 89, exploration: 0.01, score: 194 | Scores: (min: 9, avg: 171.7078651685393, max: 500)
#
# ####################
# Run: 90, exploration: 0.01, score: 177 | Scores: (min: 9, avg: 171.76666666666668, max: 500)
#
# Run: 91, exploration: 0.01, score: 223 | Scores: (min: 9, avg: 172.32967032967034, max: 500)
#
# Run: 92, exploration: 0.01, score: 203 | Scores: (min: 9, avg: 172.66304347826087, max: 500)
#
# Run: 93, exploration: 0.01, score: 289 | Scores: (min: 9, avg: 173.91397849462365, max: 500)
#
# Run: 94, exploration: 0.01, score: 239 | Scores: (min: 9, avg: 174.60638297872342, max: 500)
#
# Run: 95, exploration: 0.01, score: 199 | Scores: (min: 9, avg: 174.86315789473684, max: 500)
#
# Run: 96, exploration: 0.01, score: 191 | Scores: (min: 9, avg: 175.03125, max: 500)
#
# Run: 97, exploration: 0.01, score: 218 | Scores: (min: 9, avg: 175.4742268041237, max: 500)
#
# Run: 98, exploration: 0.01, score: 247 | Scores: (min: 9, avg: 176.20408163265307, max: 500)
#
# Run: 99, exploration: 0.01, score: 188 | Scores: (min: 9, avg: 176.32323232323233, max: 500)
#
# ####################
# Run: 100, exploration: 0.01, score: 156 | Scores: (min: 9, avg: 176.12, max: 500)
#
# Run: 101, exploration: 0.01, score: 213 | Scores: (min: 9, avg: 178.11, max: 500)
#
# Run: 102, exploration: 0.01, score: 149 | Scores: (min: 9, avg: 179.12, max: 500)
#
# Run: 103, exploration: 0.01, score: 161 | Scores: (min: 9, avg: 180.6, max: 500)
#
# Run: 104, exploration: 0.01, score: 202 | Scores: (min: 9, avg: 182.5, max: 500)
#
# Run: 105, exploration: 0.01, score: 270 | Scores: (min: 9, avg: 185.08, max: 500)
#
# Run: 106, exploration: 0.01, score: 218 | Scores: (min: 9, avg: 187.11, max: 500)
#
# Run: 107, exploration: 0.01, score: 189 | Scores: (min: 9, avg: 188.84, max: 500)
#
# Run: 108, exploration: 0.01, score: 260 | Scores: (min: 9, avg: 191.28, max: 500)
#
# Run: 109, exploration: 0.01, score: 227 | Scores: (min: 9, avg: 193.37, max: 500)
#
# ####################
# Run: 110, exploration: 0.01, score: 282 | Scores: (min: 9, avg: 196.09, max: 500)
#
# Solved in 10 runs, 110 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-2d3487fb0136> in <module>
#       2 reset_to_baseline_settings()
#       3 EXPLORATION_MAX = .8
# ----> 4 cartpole(250)
#
# <ipython-input-3-6270a8499d29> in cartpole(max_run)
#      26                     print("####################")
#      27                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step), end=' | ')
# ---> 28                 score_logger.add_score(step, run)
#      29                 break
#      30             dqn_solver.experience_replay()
#
# U:\Cartpole\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %% [markdown]
# Next, we will change the exploration factor by increasing exploration_min by .002

# %%
# Note: the baseline average at run# 250 was 101.74
reset_to_baseline_settings()
EXPLORATION_MIN = 0.012
cartpole(250)
# Out:
# Run: 1, exploration: 0.8, score: 18 | Scores: (min: 18, avg: 18, max: 18)
#
# Run: 2, exploration: 0.738344899179389, score: 18 | Scores: (min: 18, avg: 18, max: 18)
#
# Run: 3, exploration: 0.6679145338549811, score: 21 | Scores: (min: 18, avg: 19, max: 21)
#
# Run: 4, exploration: 0.6320839780376225, score: 12 | Scores: (min: 12, avg: 17.25, max: 21)
#
# Run: 5, exploration: 0.5775508607828131, score: 19 | Scores: (min: 12, avg: 17.6, max: 21)
#
# Run: 6, exploration: 0.5438350626661264, score: 13 | Scores: (min: 12, avg: 16.833333333333332, max: 21)
#
# Run: 7, exploration: 0.5198462687479806, score: 10 | Scores: (min: 10, avg: 15.857142857142858, max: 21)
#
# Run: 8, exploration: 0.43184601734465417, score: 38 | Scores: (min: 10, avg: 18.625, max: 38)
#
# Run: 9, exploration: 0.40867945628830904, score: 12 | Scores: (min: 10, avg: 17.88888888888889, max: 38)
#
# ####################
# Run: 10, exploration: 0.3848218967584385, score: 13 | Scores: (min: 10, avg: 17.4, max: 38)
#
# Run: 11, exploration: 0.3498632370320004, score: 20 | Scores: (min: 10, avg: 17.636363636363637, max: 38)
#
# Run: 12, exploration: 0.32943920329022186, score: 13 | Scores: (min: 10, avg: 17.25, max: 38)
#
# Run: 13, exploration: 0.31020746730977433, score: 13 | Scores: (min: 10, avg: 16.923076923076923, max: 38)
#
# Run: 14, exploration: 0.2906379339635589, score: 14 | Scores: (min: 10, avg: 16.714285714285715, max: 38)
#
# Run: 15, exploration: 0.27367130717456134, score: 13 | Scores: (min: 10, avg: 16.466666666666665, max: 38)
#
# Run: 16, exploration: 0.25899009490817765, score: 12 | Scores: (min: 10, avg: 16.1875, max: 38)
#
# Run: 17, exploration: 0.21950520323855172, score: 34 | Scores: (min: 10, avg: 17.235294117647058, max: 38)
#
# Run: 18, exploration: 0.20258818394314973, score: 17 | Scores: (min: 10, avg: 17.22222222222222, max: 38)
#
# Run: 19, exploration: 0.1734321525787257, score: 32 | Scores: (min: 10, avg: 18, max: 38)
#
# ####################
# Run: 20, exploration: 0.15072173172240425, score: 29 | Scores: (min: 10, avg: 18.55, max: 38)
#
# Run: 21, exploration: 0.12967859535196447, score: 31 | Scores: (min: 10, avg: 19.142857142857142, max: 38)
#
# Run: 22, exploration: 0.10990816632780845, score: 34 | Scores: (min: 10, avg: 19.818181818181817, max: 38)
#
# Run: 23, exploration: 0.08176957232614292, score: 60 | Scores: (min: 10, avg: 21.565217391304348, max: 60)
#
# Run: 24, exploration: 0.06792751294352277, score: 38 | Scores: (min: 10, avg: 22.25, max: 60)
#
# Run: 25, exploration: 0.05181936349256775, score: 55 | Scores: (min: 10, avg: 23.56, max: 60)
#
# Run: 26, exploration: 0.03576020908093326, score: 75 | Scores: (min: 10, avg: 25.53846153846154, max: 75)
#
# Run: 27, exploration: 0.023237264075463487, score: 87 | Scores: (min: 10, avg: 27.814814814814813, max: 87)
#
# Run: 28, exploration: 0.020706936449201633, score: 24 | Scores: (min: 10, avg: 27.678571428571427, max: 87)
#
# Run: 29, exploration: 0.012862000480456994, score: 96 | Scores: (min: 10, avg: 30.03448275862069, max: 96)
#
# ####################
# Run: 30, exploration: 0.012, score: 95 | Scores: (min: 10, avg: 32.2, max: 96)
#
# Run: 31, exploration: 0.012, score: 101 | Scores: (min: 10, avg: 34.41935483870968, max: 101)
#
# Run: 32, exploration: 0.012, score: 168 | Scores: (min: 10, avg: 38.59375, max: 168)
#
# Run: 33, exploration: 0.012, score: 137 | Scores: (min: 10, avg: 41.57575757575758, max: 168)
#
# Run: 34, exploration: 0.012, score: 151 | Scores: (min: 10, avg: 44.794117647058826, max: 168)
#
# Run: 35, exploration: 0.012, score: 172 | Scores: (min: 10, avg: 48.42857142857143, max: 172)
#
# Run: 36, exploration: 0.012, score: 185 | Scores: (min: 10, avg: 52.22222222222222, max: 185)
#
# Run: 37, exploration: 0.012, score: 324 | Scores: (min: 10, avg: 59.567567567567565, max: 324)
#
# Run: 38, exploration: 0.012, score: 228 | Scores: (min: 10, avg: 64, max: 324)
#
# Run: 39, exploration: 0.012, score: 202 | Scores: (min: 10, avg: 67.53846153846153, max: 324)
#
# ####################
# Run: 40, exploration: 0.012, score: 140 | Scores: (min: 10, avg: 69.35, max: 324)
#
# Run: 41, exploration: 0.012, score: 153 | Scores: (min: 10, avg: 71.39024390243902, max: 324)
#
# Run: 42, exploration: 0.012, score: 152 | Scores: (min: 10, avg: 73.30952380952381, max: 324)
#
# Run: 43, exploration: 0.012, score: 159 | Scores: (min: 10, avg: 75.30232558139535, max: 324)
#
# Run: 44, exploration: 0.012, score: 198 | Scores: (min: 10, avg: 78.0909090909091, max: 324)
#
# Run: 45, exploration: 0.012, score: 174 | Scores: (min: 10, avg: 80.22222222222223, max: 324)
#
# Run: 46, exploration: 0.012, score: 141 | Scores: (min: 10, avg: 81.54347826086956, max: 324)
#
# Run: 47, exploration: 0.012, score: 144 | Scores: (min: 10, avg: 82.87234042553192, max: 324)
#
# Run: 48, exploration: 0.012, score: 146 | Scores: (min: 10, avg: 84.1875, max: 324)
#
# Run: 49, exploration: 0.012, score: 145 | Scores: (min: 10, avg: 85.42857142857143, max: 324)
#
# ####################
# Run: 50, exploration: 0.012, score: 135 | Scores: (min: 10, avg: 86.42, max: 324)
#
# Run: 51, exploration: 0.012, score: 150 | Scores: (min: 10, avg: 87.66666666666667, max: 324)
#
# Run: 52, exploration: 0.012, score: 159 | Scores: (min: 10, avg: 89.03846153846153, max: 324)
#
# Run: 53, exploration: 0.012, score: 143 | Scores: (min: 10, avg: 90.05660377358491, max: 324)
#
# Run: 54, exploration: 0.012, score: 141 | Scores: (min: 10, avg: 91, max: 324)
#
# Run: 55, exploration: 0.012, score: 130 | Scores: (min: 10, avg: 91.7090909090909, max: 324)
#
# Run: 56, exploration: 0.012, score: 148 | Scores: (min: 10, avg: 92.71428571428571, max: 324)
#
# Run: 57, exploration: 0.012, score: 143 | Scores: (min: 10, avg: 93.59649122807018, max: 324)
#
# Run: 58, exploration: 0.012, score: 138 | Scores: (min: 10, avg: 94.36206896551724, max: 324)
#
# Run: 59, exploration: 0.012, score: 137 | Scores: (min: 10, avg: 95.08474576271186, max: 324)
#
# ####################
# Run: 60, exploration: 0.012, score: 141 | Scores: (min: 10, avg: 95.85, max: 324)
#
# Run: 61, exploration: 0.012, score: 195 | Scores: (min: 10, avg: 97.47540983606558, max: 324)
#
# Run: 62, exploration: 0.012, score: 159 | Scores: (min: 10, avg: 98.46774193548387, max: 324)
#
# Run: 63, exploration: 0.012, score: 143 | Scores: (min: 10, avg: 99.17460317460318, max: 324)
#
# Run: 64, exploration: 0.012, score: 166 | Scores: (min: 10, avg: 100.21875, max: 324)
#
# Run: 65, exploration: 0.012, score: 142 | Scores: (min: 10, avg: 100.86153846153846, max: 324)
#
# Run: 66, exploration: 0.012, score: 127 | Scores: (min: 10, avg: 101.25757575757575, max: 324)
#
# Run: 67, exploration: 0.012, score: 160 | Scores: (min: 10, avg: 102.13432835820896, max: 324)
#
# Run: 68, exploration: 0.012, score: 172 | Scores: (min: 10, avg: 103.16176470588235, max: 324)
#
# Run: 69, exploration: 0.012, score: 131 | Scores: (min: 10, avg: 103.56521739130434, max: 324)
#
# ####################
# Run: 70, exploration: 0.012, score: 160 | Scores: (min: 10, avg: 104.37142857142857, max: 324)
#
# Run: 71, exploration: 0.012, score: 157 | Scores: (min: 10, avg: 105.11267605633803, max: 324)
#
# Run: 72, exploration: 0.012, score: 151 | Scores: (min: 10, avg: 105.75, max: 324)
#
# Run: 73, exploration: 0.012, score: 172 | Scores: (min: 10, avg: 106.65753424657534, max: 324)
#
# Run: 74, exploration: 0.012, score: 164 | Scores: (min: 10, avg: 107.43243243243244, max: 324)
#
# Run: 75, exploration: 0.012, score: 141 | Scores: (min: 10, avg: 107.88, max: 324)
#
# Run: 76, exploration: 0.012, score: 140 | Scores: (min: 10, avg: 108.30263157894737, max: 324)
#
# Run: 77, exploration: 0.012, score: 172 | Scores: (min: 10, avg: 109.12987012987013, max: 324)
#
# Run: 78, exploration: 0.012, score: 146 | Scores: (min: 10, avg: 109.6025641025641, max: 324)
#
# Run: 79, exploration: 0.012, score: 163 | Scores: (min: 10, avg: 110.27848101265823, max: 324)
#
# ####################
# Run: 80, exploration: 0.012, score: 152 | Scores: (min: 10, avg: 110.8, max: 324)
#
# Run: 81, exploration: 0.012, score: 181 | Scores: (min: 10, avg: 111.66666666666667, max: 324)
#
# Run: 82, exploration: 0.012, score: 63 | Scores: (min: 10, avg: 111.07317073170732, max: 324)
#
# Run: 83, exploration: 0.012, score: 251 | Scores: (min: 10, avg: 112.75903614457832, max: 324)
#
# Run: 84, exploration: 0.012, score: 173 | Scores: (min: 10, avg: 113.47619047619048, max: 324)
#
# Run: 85, exploration: 0.012, score: 201 | Scores: (min: 10, avg: 114.50588235294117, max: 324)
# Run: 86, exploration: 0.012, score: 132 | Scores: (min: 10, avg: 114.70930232558139, max: 324)
#
# Run: 87, exploration: 0.012, score: 153 | Scores: (min: 10, avg: 115.14942528735632, max: 324)
#
# Run: 88, exploration: 0.012, score: 250 | Scores: (min: 10, avg: 116.68181818181819, max: 324)
#
# Run: 89, exploration: 0.012, score: 147 | Scores: (min: 10, avg: 117.02247191011236, max: 324)
#
# ####################
# Run: 90, exploration: 0.012, score: 169 | Scores: (min: 10, avg: 117.6, max: 324)
#
# Run: 91, exploration: 0.012, score: 154 | Scores: (min: 10, avg: 118, max: 324)
#
# Run: 92, exploration: 0.012, score: 167 | Scores: (min: 10, avg: 118.53260869565217, max: 324)
#
# Run: 93, exploration: 0.012, score: 166 | Scores: (min: 10, avg: 119.04301075268818, max: 324)
#
# Run: 94, exploration: 0.012, score: 196 | Scores: (min: 10, avg: 119.86170212765957, max: 324)
#
# Run: 95, exploration: 0.012, score: 94 | Scores: (min: 10, avg: 119.58947368421053, max: 324)
#
# Run: 96, exploration: 0.012, score: 150 | Scores: (min: 10, avg: 119.90625, max: 324)
#
# Run: 97, exploration: 0.012, score: 198 | Scores: (min: 10, avg: 120.71134020618557, max: 324)
#
# Run: 98, exploration: 0.012, score: 138 | Scores: (min: 10, avg: 120.88775510204081, max: 324)
#
# Run: 99, exploration: 0.012, score: 175 | Scores: (min: 10, avg: 121.43434343434343, max: 324)
#
# ####################
# Run: 100, exploration: 0.012, score: 146 | Scores: (min: 10, avg: 121.68, max: 324)
#
# Run: 101, exploration: 0.012, score: 141 | Scores: (min: 10, avg: 122.91, max: 324)
#
# Run: 102, exploration: 0.012, score: 201 | Scores: (min: 10, avg: 124.74, max: 324)
#
# Run: 103, exploration: 0.012, score: 146 | Scores: (min: 10, avg: 125.99, max: 324)
#
# Run: 104, exploration: 0.012, score: 179 | Scores: (min: 10, avg: 127.66, max: 324)
#
# Run: 105, exploration: 0.012, score: 164 | Scores: (min: 10, avg: 129.11, max: 324)
#
# Run: 106, exploration: 0.012, score: 136 | Scores: (min: 10, avg: 130.34, max: 324)
#
# Run: 107, exploration: 0.012, score: 143 | Scores: (min: 12, avg: 131.67, max: 324)
#
# Run: 108, exploration: 0.012, score: 166 | Scores: (min: 12, avg: 132.95, max: 324)
#
# Run: 109, exploration: 0.012, score: 119 | Scores: (min: 12, avg: 134.02, max: 324)
#
# ####################
# Run: 110, exploration: 0.012, score: 159 | Scores: (min: 12, avg: 135.48, max: 324)
#
# Run: 111, exploration: 0.012, score: 142 | Scores: (min: 12, avg: 136.7, max: 324)
#
# Run: 112, exploration: 0.012, score: 119 | Scores: (min: 12, avg: 137.76, max: 324)
#
# Run: 113, exploration: 0.012, score: 139 | Scores: (min: 12, avg: 139.02, max: 324)
#
# Run: 114, exploration: 0.012, score: 162 | Scores: (min: 12, avg: 140.5, max: 324)
#
# Run: 115, exploration: 0.012, score: 132 | Scores: (min: 12, avg: 141.69, max: 324)
#
# Run: 116, exploration: 0.012, score: 249 | Scores: (min: 17, avg: 144.06, max: 324)
#
# Run: 117, exploration: 0.012, score: 175 | Scores: (min: 17, avg: 145.47, max: 324)
#
# Run: 118, exploration: 0.012, score: 284 | Scores: (min: 24, avg: 148.14, max: 324)
#
# Run: 119, exploration: 0.012, score: 130 | Scores: (min: 24, avg: 149.12, max: 324)
#
# ####################
# Run: 120, exploration: 0.012, score: 134 | Scores: (min: 24, avg: 150.17, max: 324)
#
# Run: 121, exploration: 0.012, score: 131 | Scores: (min: 24, avg: 151.17, max: 324)
#
# Run: 122, exploration: 0.012, score: 172 | Scores: (min: 24, avg: 152.55, max: 324)
#
# Run: 123, exploration: 0.012, score: 192 | Scores: (min: 24, avg: 153.87, max: 324)
#
# Run: 124, exploration: 0.012, score: 31 | Scores: (min: 24, avg: 153.8, max: 324)
#
# Run: 125, exploration: 0.012, score: 308 | Scores: (min: 24, avg: 156.33, max: 324)
#
# Run: 126, exploration: 0.012, score: 124 | Scores: (min: 24, avg: 156.82, max: 324)
#
# Run: 127, exploration: 0.012, score: 121 | Scores: (min: 24, avg: 157.16, max: 324)
#
# Run: 128, exploration: 0.012, score: 17 | Scores: (min: 17, avg: 157.09, max: 324)
#
# Run: 129, exploration: 0.012, score: 143 | Scores: (min: 17, avg: 157.56, max: 324)
#
# ####################
# Run: 130, exploration: 0.012, score: 72 | Scores: (min: 17, avg: 157.33, max: 324)
#
# Run: 131, exploration: 0.012, score: 19 | Scores: (min: 17, avg: 156.51, max: 324)
#
# Run: 132, exploration: 0.012, score: 156 | Scores: (min: 17, avg: 156.39, max: 324)
#
# Run: 133, exploration: 0.012, score: 149 | Scores: (min: 17, avg: 156.51, max: 324)
#
# Run: 134, exploration: 0.012, score: 189 | Scores: (min: 17, avg: 156.89, max: 324)
#
# Run: 135, exploration: 0.012, score: 130 | Scores: (min: 17, avg: 156.47, max: 324)
#
# Run: 136, exploration: 0.012, score: 156 | Scores: (min: 17, avg: 156.18, max: 324)
#
# Run: 137, exploration: 0.012, score: 151 | Scores: (min: 17, avg: 154.45, max: 308)
#
# Run: 138, exploration: 0.012, score: 255 | Scores: (min: 17, avg: 154.72, max: 308)
#
# Run: 139, exploration: 0.012, score: 16 | Scores: (min: 16, avg: 152.86, max: 308)
#
# ####################
# Run: 140, exploration: 0.012, score: 11 | Scores: (min: 11, avg: 151.57, max: 308)
#
# Run: 141, exploration: 0.012, score: 77 | Scores: (min: 11, avg: 150.81, max: 308)
#
# Run: 142, exploration: 0.012, score: 171 | Scores: (min: 11, avg: 151, max: 308)
#
# Run: 143, exploration: 0.012, score: 222 | Scores: (min: 11, avg: 151.63, max: 308)
#
# Run: 144, exploration: 0.012, score: 115 | Scores: (min: 11, avg: 150.8, max: 308)
#
# Run: 145, exploration: 0.012, score: 126 | Scores: (min: 11, avg: 150.32, max: 308)
#
# Run: 146, exploration: 0.012, score: 122 | Scores: (min: 11, avg: 150.13, max: 308)
#
# Run: 147, exploration: 0.012, score: 107 | Scores: (min: 11, avg: 149.76, max: 308)
#
# Run: 148, exploration: 0.012, score: 100 | Scores: (min: 11, avg: 149.3, max: 308)
#
# Run: 149, exploration: 0.012, score: 122 | Scores: (min: 11, avg: 149.07, max: 308)
#
# ####################
# Run: 150, exploration: 0.012, score: 116 | Scores: (min: 11, avg: 148.88, max: 308)
#
# Run: 151, exploration: 0.012, score: 110 | Scores: (min: 11, avg: 148.48, max: 308)
#
# Run: 152, exploration: 0.012, score: 113 | Scores: (min: 11, avg: 148.02, max: 308)
#
# Run: 153, exploration: 0.012, score: 106 | Scores: (min: 11, avg: 147.65, max: 308)
#
# Run: 154, exploration: 0.012, score: 108 | Scores: (min: 11, avg: 147.32, max: 308)
#
# Run: 155, exploration: 0.012, score: 105 | Scores: (min: 11, avg: 147.07, max: 308)
#
# Run: 156, exploration: 0.012, score: 112 | Scores: (min: 11, avg: 146.71, max: 308)
#
# Run: 157, exploration: 0.012, score: 209 | Scores: (min: 11, avg: 147.37, max: 308)
#
# Run: 158, exploration: 0.012, score: 158 | Scores: (min: 11, avg: 147.57, max: 308)
#
# Run: 159, exploration: 0.012, score: 135 | Scores: (min: 11, avg: 147.55, max: 308)
#
# ####################
# Run: 160, exploration: 0.012, score: 206 | Scores: (min: 11, avg: 148.2, max: 308)
#
# Run: 161, exploration: 0.012, score: 123 | Scores: (min: 11, avg: 147.48, max: 308)
#
# Run: 162, exploration: 0.012, score: 136 | Scores: (min: 11, avg: 147.25, max: 308)
#
# Run: 163, exploration: 0.012, score: 132 | Scores: (min: 11, avg: 147.14, max: 308)
#
# Run: 164, exploration: 0.012, score: 156 | Scores: (min: 11, avg: 147.04, max: 308)
#
# Run: 165, exploration: 0.012, score: 271 | Scores: (min: 11, avg: 148.33, max: 308)
#
# Run: 166, exploration: 0.012, score: 289 | Scores: (min: 11, avg: 149.95, max: 308)
#
# Run: 167, exploration: 0.012, score: 140 | Scores: (min: 11, avg: 149.75, max: 308)
#
# Run: 168, exploration: 0.012, score: 85 | Scores: (min: 11, avg: 148.88, max: 308)
#
# Run: 169, exploration: 0.012, score: 139 | Scores: (min: 11, avg: 148.96, max: 308)
#
# ####################
# Run: 170, exploration: 0.012, score: 236 | Scores: (min: 11, avg: 149.72, max: 308)
#
# Run: 171, exploration: 0.012, score: 107 | Scores: (min: 11, avg: 149.22, max: 308)
#
# Run: 172, exploration: 0.012, score: 10 | Scores: (min: 10, avg: 147.81, max: 308)
#
# Run: 173, exploration: 0.012, score: 9 | Scores: (min: 9, avg: 146.18, max: 308)
#
# Run: 174, exploration: 0.012, score: 10 | Scores: (min: 9, avg: 144.64, max: 308)
#
# Run: 175, exploration: 0.012, score: 8 | Scores: (min: 8, avg: 143.31, max: 308)
#
# Run: 176, exploration: 0.012, score: 10 | Scores: (min: 8, avg: 142.01, max: 308)
#
# Run: 177, exploration: 0.012, score: 9 | Scores: (min: 8, avg: 140.38, max: 308)
#
# Run: 178, exploration: 0.012, score: 10 | Scores: (min: 8, avg: 139.02, max: 308)
#
# Run: 179, exploration: 0.012, score: 9 | Scores: (min: 8, avg: 137.48, max: 308)
# ####################
# Run: 180, exploration: 0.012, score: 9 | Scores: (min: 8, avg: 136.05, max: 308)
#
# Run: 181, exploration: 0.012, score: 10 | Scores: (min: 8, avg: 134.34, max: 308)
#
# Run: 182, exploration: 0.012, score: 9 | Scores: (min: 8, avg: 133.8, max: 308)
#
# Run: 183, exploration: 0.012, score: 8 | Scores: (min: 8, avg: 131.37, max: 308)
#
# Run: 184, exploration: 0.012, score: 10 | Scores: (min: 8, avg: 129.74, max: 308)
#
# Run: 185, exploration: 0.012, score: 9 | Scores: (min: 8, avg: 127.82, max: 308)
#
# Run: 186, exploration: 0.012, score: 10 | Scores: (min: 8, avg: 126.6, max: 308)
#
# Run: 187, exploration: 0.012, score: 9 | Scores: (min: 8, avg: 125.16, max: 308)
#
# Run: 188, exploration: 0.012, score: 8 | Scores: (min: 8, avg: 122.74, max: 308)
#
# Run: 189, exploration: 0.012, score: 10 | Scores: (min: 8, avg: 121.37, max: 308)
#
# ####################
# Run: 190, exploration: 0.012, score: 9 | Scores: (min: 8, avg: 119.77, max: 308)
#
# Run: 191, exploration: 0.012, score: 10 | Scores: (min: 8, avg: 118.33, max: 308)
#
# Run: 192, exploration: 0.012, score: 10 | Scores: (min: 8, avg: 116.76, max: 308)
#
# Run: 193, exploration: 0.012, score: 11 | Scores: (min: 8, avg: 115.21, max: 308)
#
# Run: 194, exploration: 0.012, score: 10 | Scores: (min: 8, avg: 113.35, max: 308)
#
# Run: 195, exploration: 0.012, score: 10 | Scores: (min: 8, avg: 112.51, max: 308)
#
# Run: 196, exploration: 0.012, score: 9 | Scores: (min: 8, avg: 111.1, max: 308)
#
# Run: 197, exploration: 0.012, score: 9 | Scores: (min: 8, avg: 109.21, max: 308)
#
# Run: 198, exploration: 0.012, score: 10 | Scores: (min: 8, avg: 107.93, max: 308)
#
# Run: 199, exploration: 0.012, score: 9 | Scores: (min: 8, avg: 106.27, max: 308)
#
# ####################
# Run: 200, exploration: 0.012, score: 10 | Scores: (min: 8, avg: 104.91, max: 308)
#
# Run: 201, exploration: 0.012, score: 10 | Scores: (min: 8, avg: 103.6, max: 308)
#
# Run: 202, exploration: 0.012, score: 9 | Scores: (min: 8, avg: 101.68, max: 308)
#
# Run: 203, exploration: 0.012, score: 10 | Scores: (min: 8, avg: 100.32, max: 308)
#
# Run: 204, exploration: 0.012, score: 9 | Scores: (min: 8, avg: 98.62, max: 308)
#
# Run: 205, exploration: 0.012, score: 11 | Scores: (min: 8, avg: 97.09, max: 308)
#
# Run: 206, exploration: 0.012, score: 8 | Scores: (min: 8, avg: 95.81, max: 308)
#
# Run: 207, exploration: 0.012, score: 9 | Scores: (min: 8, avg: 94.47, max: 308)
#
# Run: 208, exploration: 0.012, score: 10 | Scores: (min: 8, avg: 92.91, max: 308)
#
# Run: 209, exploration: 0.012, score: 10 | Scores: (min: 8, avg: 91.82, max: 308)
#
# ####################
# Run: 210, exploration: 0.012, score: 10 | Scores: (min: 8, avg: 90.33, max: 308)
#
# Run: 211, exploration: 0.012, score: 11 | Scores: (min: 8, avg: 89.02, max: 308)
#
# Run: 212, exploration: 0.012, score: 12 | Scores: (min: 8, avg: 87.95, max: 308)
#
# Run: 213, exploration: 0.012, score: 10 | Scores: (min: 8, avg: 86.66, max: 308)
#
# Run: 214, exploration: 0.012, score: 12 | Scores: (min: 8, avg: 85.16, max: 308)
#
# Run: 215, exploration: 0.012, score: 13 | Scores: (min: 8, avg: 83.97, max: 308)
#
# Run: 216, exploration: 0.012, score: 10 | Scores: (min: 8, avg: 81.58, max: 308)
#
# Run: 217, exploration: 0.012, score: 10 | Scores: (min: 8, avg: 79.93, max: 308)
#
# Run: 218, exploration: 0.012, score: 10 | Scores: (min: 8, avg: 77.19, max: 308)
#
# Run: 219, exploration: 0.012, score: 10 | Scores: (min: 8, avg: 75.99, max: 308)
#
# ####################
# Run: 220, exploration: 0.012, score: 11 | Scores: (min: 8, avg: 74.76, max: 308)
#
# Run: 221, exploration: 0.012, score: 10 | Scores: (min: 8, avg: 73.55, max: 308)
#
# Run: 222, exploration: 0.012, score: 11 | Scores: (min: 8, avg: 71.94, max: 308)
#
# Run: 223, exploration: 0.012, score: 103 | Scores: (min: 8, avg: 71.05, max: 308)
#
# Run: 224, exploration: 0.012, score: 100 | Scores: (min: 8, avg: 71.74, max: 308)
#
# Run: 225, exploration: 0.012, score: 116 | Scores: (min: 8, avg: 69.82, max: 289)
#
# Run: 226, exploration: 0.012, score: 126 | Scores: (min: 8, avg: 69.84, max: 289)
#
# Run: 227, exploration: 0.012, score: 75 | Scores: (min: 8, avg: 69.38, max: 289)
#
# Run: 228, exploration: 0.012, score: 53 | Scores: (min: 8, avg: 69.74, max: 289)
#
# Run: 229, exploration: 0.012, score: 48 | Scores: (min: 8, avg: 68.79, max: 289)
#
# ####################
# Run: 230, exploration: 0.012, score: 17 | Scores: (min: 8, avg: 68.24, max: 289)
#
# Run: 231, exploration: 0.012, score: 11 | Scores: (min: 8, avg: 68.16, max: 289)
#
# Run: 232, exploration: 0.012, score: 28 | Scores: (min: 8, avg: 66.88, max: 289)
#
# Run: 233, exploration: 0.012, score: 96 | Scores: (min: 8, avg: 66.35, max: 289)
#
# Run: 234, exploration: 0.012, score: 224 | Scores: (min: 8, avg: 66.7, max: 289)
#
# Run: 235, exploration: 0.012, score: 112 | Scores: (min: 8, avg: 66.52, max: 289)
#
# Run: 236, exploration: 0.012, score: 149 | Scores: (min: 8, avg: 66.45, max: 289)
#
# Run: 237, exploration: 0.012, score: 175 | Scores: (min: 8, avg: 66.69, max: 289)
#
# Run: 238, exploration: 0.012, score: 127 | Scores: (min: 8, avg: 65.41, max: 289)
#
# Run: 239, exploration: 0.012, score: 300 | Scores: (min: 8, avg: 68.25, max: 300)
#
# ####################
# Run: 240, exploration: 0.012, score: 109 | Scores: (min: 8, avg: 69.23, max: 300)
#
# Run: 241, exploration: 0.012, score: 161 | Scores: (min: 8, avg: 70.07, max: 300)
#
# Run: 242, exploration: 0.012, score: 189 | Scores: (min: 8, avg: 70.25, max: 300)
#
# Run: 243, exploration: 0.012, score: 295 | Scores: (min: 8, avg: 70.98, max: 300)
#
# Run: 244, exploration: 0.012, score: 201 | Scores: (min: 8, avg: 71.84, max: 300)
#
# Run: 245, exploration: 0.012, score: 290 | Scores: (min: 8, avg: 73.48, max: 300)
#
# Run: 246, exploration: 0.012, score: 197 | Scores: (min: 8, avg: 74.23, max: 300)
#
# Run: 247, exploration: 0.012, score: 167 | Scores: (min: 8, avg: 74.83, max: 300)
#
# Run: 248, exploration: 0.012, score: 178 | Scores: (min: 8, avg: 75.61, max: 300)
#
# Run: 249, exploration: 0.012, score: 225 | Scores: (min: 8, avg: 76.64, max: 300)

# %% [markdown]
# Next, we will change the exploration factor by decreasing exploration_min by .002

# %%
# Note: the baseline average at run# 250 was 101.74
reset_to_baseline_settings()
EXPLORATION_MIN = 0.008
cartpole(250)
# Out:
# Run: 1, exploration: 0.7801990024975001, score: 25 | Scores: (min: 25, avg: 25, max: 25)
#
# Run: 2, exploration: 0.7309799088100746, score: 14 | Scores: (min: 14, avg: 19.5, max: 25)
#
# Run: 3, exploration: 0.6780342802418761, score: 16 | Scores: (min: 14, avg: 18.333333333333332, max: 25)
#
# Run: 4, exploration: 0.6226500456549138, score: 18 | Scores: (min: 14, avg: 18.25, max: 25)
#
# Run: 5, exploration: 0.5689308419917721, score: 19 | Scores: (min: 14, avg: 18.4, max: 25)
#
# Run: 6, exploration: 0.48461634919258256, score: 33 | Scores: (min: 14, avg: 20.833333333333332, max: 33)
#
# Run: 7, exploration: 0.4655675554722388, score: 9 | Scores: (min: 9, avg: 19.142857142857142, max: 33)
#
# Run: 8, exploration: 0.4405919883337024, score: 12 | Scores: (min: 9, avg: 18.25, max: 33)
#
# Run: 9, exploration: 0.4211572899560216, score: 10 | Scores: (min: 9, avg: 17.333333333333332, max: 33)
#
# ####################
# Run: 10, exploration: 0.39856413017169917, score: 12 | Scores: (min: 9, avg: 16.8, max: 33)
#
# Run: 11, exploration: 0.38098329833827305, score: 10 | Scores: (min: 9, avg: 16.181818181818183, max: 33)
#
# Run: 12, exploration: 0.3641779644098442, score: 10 | Scores: (min: 9, avg: 15.666666666666666, max: 33)
#
# Run: 13, exploration: 0.3277920072737707, score: 22 | Scores: (min: 9, avg: 16.153846153846153, max: 33)
#
# Run: 14, exploration: 0.2920984260940291, score: 24 | Scores: (min: 9, avg: 16.714285714285715, max: 33)
#
# Run: 15, exploration: 0.25899009490817765, score: 25 | Scores: (min: 9, avg: 17.266666666666666, max: 33)
#
# Run: 16, exploration: 0.2250761177965029, score: 29 | Scores: (min: 9, avg: 18, max: 33)
#
# Run: 17, exploration: 0.20360621501824094, score: 21 | Scores: (min: 9, avg: 18.176470588235293, max: 33)
#
# Run: 18, exploration: 0.18604006560899772, score: 19 | Scores: (min: 9, avg: 18.22222222222222, max: 33)
#
# Run: 19, exploration: 0.17517956877727905, score: 13 | Scores: (min: 9, avg: 17.94736842105263, max: 33)
#
# ####################
# Run: 20, exploration: 0.16495307726611147, score: 13 | Scores: (min: 9, avg: 17.7, max: 33)
#
# Run: 21, exploration: 0.15224032900422135, score: 17 | Scores: (min: 9, avg: 17.666666666666668, max: 33)
#
# Run: 22, exploration: 0.13910577726590187, score: 19 | Scores: (min: 9, avg: 17.727272727272727, max: 33)
#
# Run: 23, exploration: 0.12710441047597945, score: 19 | Scores: (min: 9, avg: 17.782608695652176, max: 33)
#
# Run: 24, exploration: 0.11497998180569793, score: 21 | Scores: (min: 9, avg: 17.916666666666668, max: 33)
#
# Run: 25, exploration: 0.10093047914545722, score: 27 | Scores: (min: 9, avg: 18.28, max: 33)
#
# Run: 26, exploration: 0.09176157709961741, score: 20 | Scores: (min: 9, avg: 18.346153846153847, max: 33)
#
# Run: 27, exploration: 0.07584691788327606, score: 39 | Scores: (min: 9, avg: 19.11111111111111, max: 39)
#
# Run: 28, exploration: 0.06792751294352277, score: 23 | Scores: (min: 9, avg: 19.25, max: 39)
#
# Run: 29, exploration: 0.062067059021439275, score: 19 | Scores: (min: 9, avg: 19.24137931034483, max: 39)
#
# ####################
# Run: 30, exploration: 0.05448303180956667, score: 27 | Scores: (min: 9, avg: 19.5, max: 39)
#
# Run: 31, exploration: 0.04073802308585122, score: 59 | Scores: (min: 9, avg: 20.774193548387096, max: 59)
#
# Run: 32, exploration: 0.026076790404871538, score: 90 | Scores: (min: 9, avg: 22.9375, max: 90)
#
# Run: 33, exploration: 0.020500384758120847, score: 49 | Scores: (min: 9, avg: 23.727272727272727, max: 90)
#
# Run: 34, exploration: 0.011010930580335502, score: 125 | Scores: (min: 9, avg: 26.705882352941178, max: 125)
#
# Run: 35, exploration: 0.010578124411820364, score: 9 | Scores: (min: 9, avg: 26.2, max: 125)
#
# Run: 36, exploration: 0.010213397524131992, score: 8 | Scores: (min: 8, avg: 25.694444444444443, max: 125)
#
# Run: 37, exploration: 0.009473630609590774, score: 16 | Scores: (min: 8, avg: 25.43243243243243, max: 125)
#
# Run: 38, exploration: 0.008, score: 103 | Scores: (min: 8, avg: 27.473684210526315, max: 125)
#
# Run: 39, exploration: 0.008, score: 65 | Scores: (min: 8, avg: 28.435897435897434, max: 125)
#
# ####################
# Run: 40, exploration: 0.008, score: 93 | Scores: (min: 8, avg: 30.05, max: 125)
#
# Run: 41, exploration: 0.008, score: 17 | Scores: (min: 8, avg: 29.73170731707317, max: 125)
#
# Run: 42, exploration: 0.008, score: 134 | Scores: (min: 8, avg: 32.214285714285715, max: 134)
#
# Run: 43, exploration: 0.008, score: 49 | Scores: (min: 8, avg: 32.604651162790695, max: 134)
#
# Run: 44, exploration: 0.008, score: 56 | Scores: (min: 8, avg: 33.13636363636363, max: 134)
#
# Run: 45, exploration: 0.008, score: 87 | Scores: (min: 8, avg: 34.333333333333336, max: 134)
#
# Run: 46, exploration: 0.008, score: 20 | Scores: (min: 8, avg: 34.02173913043478, max: 134)
#
# Run: 47, exploration: 0.008, score: 50 | Scores: (min: 8, avg: 34.361702127659576, max: 134)
#
# Run: 48, exploration: 0.008, score: 49 | Scores: (min: 8, avg: 34.666666666666664, max: 134)
#
# Run: 49, exploration: 0.008, score: 74 | Scores: (min: 8, avg: 35.46938775510204, max: 134)
#
# ####################
# Run: 50, exploration: 0.008, score: 82 | Scores: (min: 8, avg: 36.4, max: 134)
#
# Run: 51, exploration: 0.008, score: 113 | Scores: (min: 8, avg: 37.90196078431372, max: 134)
#
# Run: 52, exploration: 0.008, score: 189 | Scores: (min: 8, avg: 40.80769230769231, max: 189)
#
# Run: 53, exploration: 0.008, score: 117 | Scores: (min: 8, avg: 42.24528301886792, max: 189)
#
# Run: 54, exploration: 0.008, score: 121 | Scores: (min: 8, avg: 43.7037037037037, max: 189)
#
# Run: 55, exploration: 0.008, score: 111 | Scores: (min: 8, avg: 44.92727272727273, max: 189)
#
# Run: 56, exploration: 0.008, score: 95 | Scores: (min: 8, avg: 45.82142857142857, max: 189)
#
# Run: 57, exploration: 0.008, score: 165 | Scores: (min: 8, avg: 47.91228070175438, max: 189)
#
# Run: 58, exploration: 0.008, score: 136 | Scores: (min: 8, avg: 49.43103448275862, max: 189)
#
# Run: 59, exploration: 0.008, score: 130 | Scores: (min: 8, avg: 50.79661016949152, max: 189)
#
# ####################
# Run: 60, exploration: 0.008, score: 160 | Scores: (min: 8, avg: 52.61666666666667, max: 189)
#
# Run: 61, exploration: 0.008, score: 118 | Scores: (min: 8, avg: 53.68852459016394, max: 189)
#
# Run: 62, exploration: 0.008, score: 156 | Scores: (min: 8, avg: 55.33870967741935, max: 189)
#
# Run: 63, exploration: 0.008, score: 97 | Scores: (min: 8, avg: 56, max: 189)
#
# Run: 64, exploration: 0.008, score: 115 | Scores: (min: 8, avg: 56.921875, max: 189)
#
# Run: 65, exploration: 0.008, score: 193 | Scores: (min: 8, avg: 59.01538461538462, max: 193)
#
# Run: 66, exploration: 0.008, score: 124 | Scores: (min: 8, avg: 60, max: 193)
#
# Run: 67, exploration: 0.008, score: 162 | Scores: (min: 8, avg: 61.52238805970149, max: 193)
#
# Run: 68, exploration: 0.008, score: 259 | Scores: (min: 8, avg: 64.42647058823529, max: 259)
#
# Run: 69, exploration: 0.008, score: 265 | Scores: (min: 8, avg: 67.33333333333333, max: 265)
#
# ####################
# Run: 70, exploration: 0.008, score: 233 | Scores: (min: 8, avg: 69.7, max: 265)
#
# Run: 71, exploration: 0.008, score: 194 | Scores: (min: 8, avg: 71.45070422535211, max: 265)
#
# Run: 72, exploration: 0.008, score: 193 | Scores: (min: 8, avg: 73.13888888888889, max: 265)
#
# Run: 73, exploration: 0.008, score: 175 | Scores: (min: 8, avg: 74.53424657534246, max: 265)
#
# Run: 74, exploration: 0.008, score: 275 | Scores: (min: 8, avg: 77.24324324324324, max: 275)
#
# Run: 75, exploration: 0.008, score: 217 | Scores: (min: 8, avg: 79.10666666666667, max: 275)
#
# Run: 76, exploration: 0.008, score: 266 | Scores: (min: 8, avg: 81.5657894736842, max: 275)
#
# Run: 77, exploration: 0.008, score: 326 | Scores: (min: 8, avg: 84.74025974025975, max: 326)
#
# Run: 78, exploration: 0.008, score: 157 | Scores: (min: 8, avg: 85.66666666666667, max: 326)
#
# Run: 79, exploration: 0.008, score: 229 | Scores: (min: 8, avg: 87.48101265822785, max: 326)
#
# ####################
# Run: 80, exploration: 0.008, score: 168 | Scores: (min: 8, avg: 88.4875, max: 326)
#
# Run: 81, exploration: 0.008, score: 226 | Scores: (min: 8, avg: 90.18518518518519, max: 326)
#
# Run: 82, exploration: 0.008, score: 210 | Scores: (min: 8, avg: 91.64634146341463, max: 326)
#
# Run: 83, exploration: 0.008, score: 171 | Scores: (min: 8, avg: 92.60240963855422, max: 326)
#
# Run: 84, exploration: 0.008, score: 165 | Scores: (min: 8, avg: 93.46428571428571, max: 326)
# Run: 85, exploration: 0.008, score: 164 | Scores: (min: 8, avg: 94.29411764705883, max: 326)
#
# Run: 86, exploration: 0.008, score: 332 | Scores: (min: 8, avg: 97.05813953488372, max: 332)
#
# Run: 87, exploration: 0.008, score: 180 | Scores: (min: 8, avg: 98.01149425287356, max: 332)
#
# Run: 88, exploration: 0.008, score: 147 | Scores: (min: 8, avg: 98.56818181818181, max: 332)
#
# Run: 89, exploration: 0.008, score: 207 | Scores: (min: 8, avg: 99.78651685393258, max: 332)
#
# ####################
# Run: 90, exploration: 0.008, score: 177 | Scores: (min: 8, avg: 100.64444444444445, max: 332)
#
# Run: 91, exploration: 0.008, score: 137 | Scores: (min: 8, avg: 101.04395604395604, max: 332)
#
# Run: 92, exploration: 0.008, score: 182 | Scores: (min: 8, avg: 101.92391304347827, max: 332)
#
# Run: 93, exploration: 0.008, score: 150 | Scores: (min: 8, avg: 102.44086021505376, max: 332)
#
# Run: 94, exploration: 0.008, score: 176 | Scores: (min: 8, avg: 103.22340425531915, max: 332)
#
# Run: 95, exploration: 0.008, score: 213 | Scores: (min: 8, avg: 104.37894736842105, max: 332)
#
# Run: 96, exploration: 0.008, score: 271 | Scores: (min: 8, avg: 106.11458333333333, max: 332)
#
# Run: 97, exploration: 0.008, score: 202 | Scores: (min: 8, avg: 107.10309278350516, max: 332)
#
# Run: 98, exploration: 0.008, score: 177 | Scores: (min: 8, avg: 107.81632653061224, max: 332)
#
# Run: 99, exploration: 0.008, score: 175 | Scores: (min: 8, avg: 108.4949494949495, max: 332)
#
# ####################
# Run: 100, exploration: 0.008, score: 200 | Scores: (min: 8, avg: 109.41, max: 332)
#
# Run: 101, exploration: 0.008, score: 134 | Scores: (min: 8, avg: 110.5, max: 332)
#
# Run: 102, exploration: 0.008, score: 166 | Scores: (min: 8, avg: 112.02, max: 332)
#
# Run: 103, exploration: 0.008, score: 182 | Scores: (min: 8, avg: 113.68, max: 332)
#
# Run: 104, exploration: 0.008, score: 183 | Scores: (min: 8, avg: 115.33, max: 332)
#
# Run: 105, exploration: 0.008, score: 159 | Scores: (min: 8, avg: 116.73, max: 332)
#
# Run: 106, exploration: 0.008, score: 170 | Scores: (min: 8, avg: 118.1, max: 332)
#
# Run: 107, exploration: 0.008, score: 161 | Scores: (min: 8, avg: 119.62, max: 332)
#
# Run: 108, exploration: 0.008, score: 162 | Scores: (min: 8, avg: 121.12, max: 332)
#
# Run: 109, exploration: 0.008, score: 150 | Scores: (min: 8, avg: 122.52, max: 332)
#
# ####################
# Run: 110, exploration: 0.008, score: 145 | Scores: (min: 8, avg: 123.85, max: 332)
#
# Run: 111, exploration: 0.008, score: 160 | Scores: (min: 8, avg: 125.35, max: 332)
#
# Run: 112, exploration: 0.008, score: 223 | Scores: (min: 8, avg: 127.48, max: 332)
#
# Run: 113, exploration: 0.008, score: 170 | Scores: (min: 8, avg: 128.96, max: 332)
#
# Run: 114, exploration: 0.008, score: 165 | Scores: (min: 8, avg: 130.37, max: 332)
#
# Run: 115, exploration: 0.008, score: 239 | Scores: (min: 8, avg: 132.51, max: 332)
#
# Run: 116, exploration: 0.008, score: 185 | Scores: (min: 8, avg: 134.07, max: 332)
#
# Run: 117, exploration: 0.008, score: 190 | Scores: (min: 8, avg: 135.76, max: 332)
#
# Run: 118, exploration: 0.008, score: 141 | Scores: (min: 8, avg: 136.98, max: 332)
#
# Run: 119, exploration: 0.008, score: 148 | Scores: (min: 8, avg: 138.33, max: 332)
#
# ####################
# Run: 120, exploration: 0.008, score: 196 | Scores: (min: 8, avg: 140.16, max: 332)
#
# Run: 121, exploration: 0.008, score: 153 | Scores: (min: 8, avg: 141.52, max: 332)
#
# Run: 122, exploration: 0.008, score: 204 | Scores: (min: 8, avg: 143.37, max: 332)
#
# Run: 123, exploration: 0.008, score: 186 | Scores: (min: 8, avg: 145.04, max: 332)
#
# Run: 124, exploration: 0.008, score: 261 | Scores: (min: 8, avg: 147.44, max: 332)
#
# Run: 125, exploration: 0.008, score: 166 | Scores: (min: 8, avg: 148.83, max: 332)
#
# Run: 126, exploration: 0.008, score: 134 | Scores: (min: 8, avg: 149.97, max: 332)
#
# Run: 127, exploration: 0.008, score: 108 | Scores: (min: 8, avg: 150.66, max: 332)
#
# Run: 128, exploration: 0.008, score: 195 | Scores: (min: 8, avg: 152.38, max: 332)
#
# Run: 129, exploration: 0.008, score: 200 | Scores: (min: 8, avg: 154.19, max: 332)
#
# ####################
# Run: 130, exploration: 0.008, score: 107 | Scores: (min: 8, avg: 154.99, max: 332)
#
# Run: 131, exploration: 0.008, score: 147 | Scores: (min: 8, avg: 155.87, max: 332)
#
# Run: 132, exploration: 0.008, score: 186 | Scores: (min: 8, avg: 156.83, max: 332)
#
# Run: 133, exploration: 0.008, score: 173 | Scores: (min: 8, avg: 158.07, max: 332)
#
# Run: 134, exploration: 0.008, score: 189 | Scores: (min: 8, avg: 158.71, max: 332)
#
# Run: 135, exploration: 0.008, score: 122 | Scores: (min: 8, avg: 159.84, max: 332)
#
# Run: 136, exploration: 0.008, score: 117 | Scores: (min: 16, avg: 160.93, max: 332)
#
# Run: 137, exploration: 0.008, score: 215 | Scores: (min: 17, avg: 162.92, max: 332)
#
# Run: 138, exploration: 0.008, score: 136 | Scores: (min: 17, avg: 163.25, max: 332)
#
# Run: 139, exploration: 0.008, score: 133 | Scores: (min: 17, avg: 163.93, max: 332)
#
# ####################
# Run: 140, exploration: 0.008, score: 142 | Scores: (min: 17, avg: 164.42, max: 332)
#
# Run: 141, exploration: 0.008, score: 150 | Scores: (min: 20, avg: 165.75, max: 332)
#
# Run: 142, exploration: 0.008, score: 163 | Scores: (min: 20, avg: 166.04, max: 332)
#
# Run: 143, exploration: 0.008, score: 153 | Scores: (min: 20, avg: 167.08, max: 332)
#
# Run: 144, exploration: 0.008, score: 168 | Scores: (min: 20, avg: 168.2, max: 332)
#
# Run: 145, exploration: 0.008, score: 266 | Scores: (min: 20, avg: 169.99, max: 332)
#
# Run: 146, exploration: 0.008, score: 172 | Scores: (min: 49, avg: 171.51, max: 332)
#
# Run: 147, exploration: 0.008, score: 183 | Scores: (min: 49, avg: 172.84, max: 332)
#
# Run: 148, exploration: 0.008, score: 268 | Scores: (min: 74, avg: 175.03, max: 332)
#
# Run: 149, exploration: 0.008, score: 127 | Scores: (min: 82, avg: 175.56, max: 332)
#
# ####################
# Run: 150, exploration: 0.008, score: 140 | Scores: (min: 95, avg: 176.14, max: 332)
#
# Run: 151, exploration: 0.008, score: 108 | Scores: (min: 95, avg: 176.09, max: 332)
#
# Run: 152, exploration: 0.008, score: 184 | Scores: (min: 95, avg: 176.04, max: 332)
#
# Run: 153, exploration: 0.008, score: 115 | Scores: (min: 95, avg: 176.02, max: 332)
#
# Run: 154, exploration: 0.008, score: 149 | Scores: (min: 95, avg: 176.3, max: 332)
#
# Run: 155, exploration: 0.008, score: 193 | Scores: (min: 95, avg: 177.12, max: 332)
#
# Run: 156, exploration: 0.008, score: 162 | Scores: (min: 97, avg: 177.79, max: 332)
#
# Run: 157, exploration: 0.008, score: 162 | Scores: (min: 97, avg: 177.76, max: 332)
#
# Run: 158, exploration: 0.008, score: 161 | Scores: (min: 97, avg: 178.01, max: 332)
#
# Run: 159, exploration: 0.008, score: 104 | Scores: (min: 97, avg: 177.75, max: 332)
#
# ####################
# Run: 160, exploration: 0.008, score: 218 | Scores: (min: 97, avg: 178.33, max: 332)
#
# Run: 161, exploration: 0.008, score: 137 | Scores: (min: 97, avg: 178.52, max: 332)
#
# Run: 162, exploration: 0.008, score: 154 | Scores: (min: 97, avg: 178.5, max: 332)
#
# Run: 163, exploration: 0.008, score: 182 | Scores: (min: 104, avg: 179.35, max: 332)
#
# Run: 164, exploration: 0.008, score: 125 | Scores: (min: 104, avg: 179.45, max: 332)
#
# Run: 165, exploration: 0.008, score: 98 | Scores: (min: 98, avg: 178.5, max: 332)
#
# Run: 166, exploration: 0.008, score: 128 | Scores: (min: 98, avg: 178.54, max: 332)
#
# Run: 167, exploration: 0.008, score: 13 | Scores: (min: 13, avg: 177.05, max: 332)
#
# Run: 168, exploration: 0.008, score: 113 | Scores: (min: 13, avg: 175.59, max: 332)
#
# Run: 169, exploration: 0.008, score: 177 | Scores: (min: 13, avg: 174.71, max: 332)
#
# ####################
# Run: 170, exploration: 0.008, score: 197 | Scores: (min: 13, avg: 174.35, max: 332)
#
# Run: 171, exploration: 0.008, score: 144 | Scores: (min: 13, avg: 173.85, max: 332)
#
# Run: 172, exploration: 0.008, score: 171 | Scores: (min: 13, avg: 173.63, max: 332)
#
# Run: 173, exploration: 0.008, score: 100 | Scores: (min: 13, avg: 172.88, max: 332)
#
# Run: 174, exploration: 0.008, score: 290 | Scores: (min: 13, avg: 173.03, max: 332)
#
# Run: 175, exploration: 0.008, score: 165 | Scores: (min: 13, avg: 172.51, max: 332)
#
# Run: 176, exploration: 0.008, score: 113 | Scores: (min: 13, avg: 170.98, max: 332)
#
# Run: 177, exploration: 0.008, score: 284 | Scores: (min: 13, avg: 170.56, max: 332)
# Run: 178, exploration: 0.008, score: 163 | Scores: (min: 13, avg: 170.62, max: 332)
#
# Run: 179, exploration: 0.008, score: 104 | Scores: (min: 13, avg: 169.37, max: 332)
#
# ####################
# Run: 180, exploration: 0.008, score: 123 | Scores: (min: 13, avg: 168.92, max: 332)
#
# Run: 181, exploration: 0.008, score: 209 | Scores: (min: 13, avg: 168.75, max: 332)
#
# Run: 182, exploration: 0.008, score: 119 | Scores: (min: 13, avg: 167.84, max: 332)
#
# Run: 183, exploration: 0.008, score: 171 | Scores: (min: 13, avg: 167.84, max: 332)
#
# Run: 184, exploration: 0.008, score: 143 | Scores: (min: 13, avg: 167.62, max: 332)
#
# Run: 185, exploration: 0.008, score: 186 | Scores: (min: 13, avg: 167.84, max: 332)
#
# Run: 186, exploration: 0.008, score: 108 | Scores: (min: 13, avg: 165.6, max: 290)
#
# Run: 187, exploration: 0.008, score: 169 | Scores: (min: 13, avg: 165.49, max: 290)
#
# Run: 188, exploration: 0.008, score: 129 | Scores: (min: 13, avg: 165.31, max: 290)
#
# Run: 189, exploration: 0.008, score: 120 | Scores: (min: 13, avg: 164.44, max: 290)
#
# ####################
# Run: 190, exploration: 0.008, score: 131 | Scores: (min: 13, avg: 163.98, max: 290)
#
# Run: 191, exploration: 0.008, score: 158 | Scores: (min: 13, avg: 164.19, max: 290)
#
# Run: 192, exploration: 0.008, score: 199 | Scores: (min: 13, avg: 164.36, max: 290)
#
# Run: 193, exploration: 0.008, score: 211 | Scores: (min: 13, avg: 164.97, max: 290)
#
# Run: 194, exploration: 0.008, score: 205 | Scores: (min: 13, avg: 165.26, max: 290)
#
# Run: 195, exploration: 0.008, score: 63 | Scores: (min: 13, avg: 163.76, max: 290)
#
# Run: 196, exploration: 0.008, score: 112 | Scores: (min: 13, avg: 162.17, max: 290)
#
# Run: 197, exploration: 0.008, score: 94 | Scores: (min: 13, avg: 161.09, max: 290)
#
# Run: 198, exploration: 0.008, score: 102 | Scores: (min: 13, avg: 160.34, max: 290)
#
# Run: 199, exploration: 0.008, score: 89 | Scores: (min: 13, avg: 159.48, max: 290)
#
# ####################
# Run: 200, exploration: 0.008, score: 142 | Scores: (min: 13, avg: 158.9, max: 290)
#
# Run: 201, exploration: 0.008, score: 108 | Scores: (min: 13, avg: 158.64, max: 290)
#
# Run: 202, exploration: 0.008, score: 167 | Scores: (min: 13, avg: 158.65, max: 290)
#
# Run: 203, exploration: 0.008, score: 120 | Scores: (min: 13, avg: 158.03, max: 290)
#
# Run: 204, exploration: 0.008, score: 188 | Scores: (min: 13, avg: 158.08, max: 290)
#
# Run: 205, exploration: 0.008, score: 288 | Scores: (min: 13, avg: 159.37, max: 290)
#
# Run: 206, exploration: 0.008, score: 8 | Scores: (min: 8, avg: 157.75, max: 290)
#
# Run: 207, exploration: 0.008, score: 9 | Scores: (min: 8, avg: 156.23, max: 290)
#
# Run: 208, exploration: 0.008, score: 9 | Scores: (min: 8, avg: 154.7, max: 290)
#
# Run: 209, exploration: 0.008, score: 9 | Scores: (min: 8, avg: 153.29, max: 290)
#
# ####################
# Run: 210, exploration: 0.008, score: 9 | Scores: (min: 8, avg: 151.93, max: 290)
#
# Run: 211, exploration: 0.008, score: 10 | Scores: (min: 8, avg: 150.43, max: 290)
#
# Run: 212, exploration: 0.008, score: 9 | Scores: (min: 8, avg: 148.29, max: 290)
#
# Run: 213, exploration: 0.008, score: 10 | Scores: (min: 8, avg: 146.69, max: 290)
#
# Run: 214, exploration: 0.008, score: 8 | Scores: (min: 8, avg: 145.12, max: 290)
#
# Run: 215, exploration: 0.008, score: 10 | Scores: (min: 8, avg: 142.83, max: 290)
#
# Run: 216, exploration: 0.008, score: 10 | Scores: (min: 8, avg: 141.08, max: 290)
#
# Run: 217, exploration: 0.008, score: 10 | Scores: (min: 8, avg: 139.28, max: 290)
#
# Run: 218, exploration: 0.008, score: 9 | Scores: (min: 8, avg: 137.96, max: 290)
#
# Run: 219, exploration: 0.008, score: 10 | Scores: (min: 8, avg: 136.58, max: 290)
#
# ####################
# Run: 220, exploration: 0.008, score: 9 | Scores: (min: 8, avg: 134.71, max: 290)
#
# Run: 221, exploration: 0.008, score: 11 | Scores: (min: 8, avg: 133.29, max: 290)
#
# Run: 222, exploration: 0.008, score: 10 | Scores: (min: 8, avg: 131.35, max: 290)
#
# Run: 223, exploration: 0.008, score: 9 | Scores: (min: 8, avg: 129.58, max: 290)
#
# Run: 224, exploration: 0.008, score: 12 | Scores: (min: 8, avg: 127.09, max: 290)
#
# Run: 225, exploration: 0.008, score: 10 | Scores: (min: 8, avg: 125.53, max: 290)
#
# Run: 226, exploration: 0.008, score: 10 | Scores: (min: 8, avg: 124.29, max: 290)
#
# Run: 227, exploration: 0.008, score: 9 | Scores: (min: 8, avg: 123.3, max: 290)
#
# Run: 228, exploration: 0.008, score: 8 | Scores: (min: 8, avg: 121.43, max: 290)
#
# Run: 229, exploration: 0.008, score: 10 | Scores: (min: 8, avg: 119.53, max: 290)
#
# ####################
# Run: 230, exploration: 0.008, score: 10 | Scores: (min: 8, avg: 118.56, max: 290)
#
# Run: 231, exploration: 0.008, score: 10 | Scores: (min: 8, avg: 117.19, max: 290)
#
# Run: 232, exploration: 0.008, score: 9 | Scores: (min: 8, avg: 115.42, max: 290)
#
# Run: 233, exploration: 0.008, score: 10 | Scores: (min: 8, avg: 113.79, max: 290)
#
# Run: 234, exploration: 0.008, score: 10 | Scores: (min: 8, avg: 112, max: 290)
#
# Run: 235, exploration: 0.008, score: 10 | Scores: (min: 8, avg: 110.88, max: 290)
#
# Run: 236, exploration: 0.008, score: 10 | Scores: (min: 8, avg: 109.81, max: 290)
#
# Run: 237, exploration: 0.008, score: 11 | Scores: (min: 8, avg: 107.77, max: 290)
#
# Run: 238, exploration: 0.008, score: 9 | Scores: (min: 8, avg: 106.5, max: 290)
#
# Run: 239, exploration: 0.008, score: 10 | Scores: (min: 8, avg: 105.27, max: 290)
#
# ####################
# Run: 240, exploration: 0.008, score: 10 | Scores: (min: 8, avg: 103.95, max: 290)
#
# Run: 241, exploration: 0.008, score: 9 | Scores: (min: 8, avg: 102.54, max: 290)
#
# Run: 242, exploration: 0.008, score: 10 | Scores: (min: 8, avg: 101.01, max: 290)
#
# Run: 243, exploration: 0.008, score: 9 | Scores: (min: 8, avg: 99.57, max: 290)
#
# Run: 244, exploration: 0.008, score: 9 | Scores: (min: 8, avg: 97.98, max: 290)
#
# Run: 245, exploration: 0.008, score: 10 | Scores: (min: 8, avg: 95.42, max: 290)
#
# Run: 246, exploration: 0.008, score: 9 | Scores: (min: 8, avg: 93.79, max: 290)
#
# Run: 247, exploration: 0.008, score: 9 | Scores: (min: 8, avg: 92.05, max: 290)
#
# Run: 248, exploration: 0.008, score: 10 | Scores: (min: 8, avg: 89.47, max: 290)
#
# Run: 249, exploration: 0.008, score: 10 | Scores: (min: 8, avg: 88.3, max: 290)

# %% [markdown]
# Next, we will change the exploration factor by increasing exploration_decay by .002

# %%
# Note: the baseline average at run# 250 was 101.74
reset_to_baseline_settings()
EXPLORATION_DECAY = 0.997 
cartpole(250)
# Out:
# Run: 1, exploration: 0.8, score: 14 | Scores: (min: 14, avg: 14, max: 14)
#
# Run: 2, exploration: 0.7310460524835921, score: 36 | Scores: (min: 14, avg: 25, max: 36)
#
# Run: 3, exploration: 0.6842868893850883, score: 23 | Scores: (min: 14, avg: 24.333333333333332, max: 36)
#
# Run: 4, exploration: 0.6640332134021367, score: 11 | Scores: (min: 11, avg: 21, max: 36)
#
# Run: 5, exploration: 0.6424458732078172, score: 12 | Scores: (min: 11, avg: 19.2, max: 36)
#
# Run: 6, exploration: 0.5995496929668116, score: 24 | Scores: (min: 11, avg: 20, max: 36)
#
# Run: 7, exploration: 0.5800586751618989, score: 12 | Scores: (min: 11, avg: 18.857142857142858, max: 36)
#
# Run: 8, exploration: 0.5578391422208724, score: 14 | Scores: (min: 11, avg: 18.25, max: 36)
#
# Run: 9, exploration: 0.5429569657600744, score: 10 | Scores: (min: 10, avg: 17.333333333333332, max: 36)
#
# ####################
# Run: 10, exploration: 0.5268864043803683, score: 11 | Scores: (min: 10, avg: 16.7, max: 36)
#
# Run: 11, exploration: 0.5082283556660967, score: 13 | Scores: (min: 10, avg: 16.363636363636363, max: 36)
#
# Run: 12, exploration: 0.48876033083716935, score: 14 | Scores: (min: 10, avg: 16.166666666666668, max: 36)
#
# Run: 13, exploration: 0.4742938935465297, score: 11 | Scores: (min: 10, avg: 15.76923076923077, max: 36)
#
# Run: 14, exploration: 0.45749824557174523, score: 13 | Scores: (min: 10, avg: 15.571428571428571, max: 36)
#
# Run: 15, exploration: 0.4334133482428293, score: 19 | Scores: (min: 10, avg: 15.8, max: 36)
#
# Run: 16, exploration: 0.4168111619800787, score: 14 | Scores: (min: 10, avg: 15.6875, max: 36)
#
# Run: 17, exploration: 0.4069121026445548, score: 9 | Scores: (min: 9, avg: 15.294117647058824, max: 36)
#
# Run: 18, exploration: 0.3397896184683485, score: 61 | Scores: (min: 9, avg: 17.833333333333332, max: 61)
#
# Run: 19, exploration: 0.27616970072867403, score: 70 | Scores: (min: 9, avg: 20.57894736842105, max: 70)
#
# ####################
# Run: 20, exploration: 0.1383765316515556, score: 231 | Scores: (min: 9, avg: 31.1, max: 231)
#
# Run: 21, exploration: 0.11246784262080614, score: 70 | Scores: (min: 9, avg: 32.95238095238095, max: 231)
#
# Run: 22, exploration: 0.09648980715000383, score: 52 | Scores: (min: 9, avg: 33.81818181818182, max: 231)
#
# Run: 23, exploration: 0.06335831255746843, score: 141 | Scores: (min: 9, avg: 38.47826086956522, max: 231)
#
# Run: 24, exploration: 0.04820177247345456, score: 92 | Scores: (min: 9, avg: 40.708333333333336, max: 231)
#
# Run: 25, exploration: 0.03474043597803174, score: 110 | Scores: (min: 9, avg: 43.48, max: 231)
#
# Run: 26, exploration: 0.0240793399656265, score: 123 | Scores: (min: 9, avg: 46.53846153846154, max: 231)
#
# Run: 27, exploration: 0.017670379813261763, score: 104 | Scores: (min: 9, avg: 48.666666666666664, max: 231)
#
# Run: 28, exploration: 0.014405112344918406, score: 69 | Scores: (min: 9, avg: 49.392857142857146, max: 231)
#
# Run: 29, exploration: 0.008213178355236064, score: 188 | Scores: (min: 9, avg: 54.172413793103445, max: 231)
#
# ####################
# Run: 30, exploration: 0.008, score: 483 | Scores: (min: 9, avg: 68.46666666666667, max: 483)
#
# Run: 31, exploration: 0.008, score: 101 | Scores: (min: 9, avg: 69.51612903225806, max: 483)
#
# Run: 32, exploration: 0.008, score: 88 | Scores: (min: 9, avg: 70.09375, max: 483)
#
# Run: 33, exploration: 0.008, score: 116 | Scores: (min: 9, avg: 71.48484848484848, max: 483)
#
# Run: 34, exploration: 0.008, score: 500 | Scores: (min: 9, avg: 84.08823529411765, max: 500)
#
# Run: 35, exploration: 0.008, score: 133 | Scores: (min: 9, avg: 85.48571428571428, max: 500)
#
# Run: 36, exploration: 0.008, score: 393 | Scores: (min: 9, avg: 94.02777777777777, max: 500)
#
# Run: 37, exploration: 0.008, score: 132 | Scores: (min: 9, avg: 95.05405405405405, max: 500)
#
# Run: 38, exploration: 0.008, score: 134 | Scores: (min: 9, avg: 96.07894736842105, max: 500)
#
# Run: 39, exploration: 0.008, score: 497 | Scores: (min: 9, avg: 106.35897435897436, max: 500)
#
# ####################
# Run: 40, exploration: 0.008, score: 500 | Scores: (min: 9, avg: 116.2, max: 500)
#
# Run: 41, exploration: 0.008, score: 500 | Scores: (min: 9, avg: 125.5609756097561, max: 500)
#
# Run: 42, exploration: 0.008, score: 500 | Scores: (min: 9, avg: 134.47619047619048, max: 500)
#
# Run: 43, exploration: 0.008, score: 500 | Scores: (min: 9, avg: 142.97674418604652, max: 500)
#
# Run: 44, exploration: 0.008, score: 500 | Scores: (min: 9, avg: 151.0909090909091, max: 500)
#
# Run: 45, exploration: 0.008, score: 393 | Scores: (min: 9, avg: 156.46666666666667, max: 500)
#
# Run: 46, exploration: 0.008, score: 287 | Scores: (min: 9, avg: 159.30434782608697, max: 500)
#
# Run: 47, exploration: 0.008, score: 275 | Scores: (min: 9, avg: 161.7659574468085, max: 500)
#
# Run: 48, exploration: 0.008, score: 298 | Scores: (min: 9, avg: 164.60416666666666, max: 500)
#
# Run: 49, exploration: 0.008, score: 368 | Scores: (min: 9, avg: 168.75510204081633, max: 500)
#
# ####################
# Run: 50, exploration: 0.008, score: 312 | Scores: (min: 9, avg: 171.62, max: 500)
#
# Run: 51, exploration: 0.008, score: 297 | Scores: (min: 9, avg: 174.07843137254903, max: 500)
#
# Run: 52, exploration: 0.008, score: 211 | Scores: (min: 9, avg: 174.78846153846155, max: 500)
#
# Run: 53, exploration: 0.008, score: 331 | Scores: (min: 9, avg: 177.73584905660377, max: 500)
#
# Run: 54, exploration: 0.008, score: 265 | Scores: (min: 9, avg: 179.35185185185185, max: 500)
#
# Run: 55, exploration: 0.008, score: 324 | Scores: (min: 9, avg: 181.98181818181817, max: 500)
#
# Run: 56, exploration: 0.008, score: 325 | Scores: (min: 9, avg: 184.53571428571428, max: 500)
#
# Run: 57, exploration: 0.008, score: 332 | Scores: (min: 9, avg: 187.12280701754386, max: 500)
#
# Run: 58, exploration: 0.008, score: 343 | Scores: (min: 9, avg: 189.81034482758622, max: 500)
#
# Run: 59, exploration: 0.008, score: 239 | Scores: (min: 9, avg: 190.64406779661016, max: 500)
#
# ####################
# Run: 60, exploration: 0.008, score: 267 | Scores: (min: 9, avg: 191.91666666666666, max: 500)
#
# Run: 61, exploration: 0.008, score: 266 | Scores: (min: 9, avg: 193.13114754098362, max: 500)
#
# Run: 62, exploration: 0.008, score: 283 | Scores: (min: 9, avg: 194.58064516129033, max: 500)
#
# Run: 63, exploration: 0.008, score: 227 | Scores: (min: 9, avg: 195.0952380952381, max: 500)
#
# Run: 64, exploration: 0.008, score: 54 | Scores: (min: 9, avg: 192.890625, max: 500)
#
# Run: 65, exploration: 0.008, score: 467 | Scores: (min: 9, avg: 197.1076923076923, max: 500)
#
# Run: 66, exploration: 0.008, score: 462 | Scores: (min: 9, avg: 201.12121212121212, max: 500)
#
# Run: 67, exploration: 0.008, score: 225 | Scores: (min: 9, avg: 201.47761194029852, max: 500)
#
# Run: 68, exploration: 0.008, score: 354 | Scores: (min: 9, avg: 203.72058823529412, max: 500)
#
# Run: 69, exploration: 0.008, score: 303 | Scores: (min: 9, avg: 205.15942028985506, max: 500)
#
# ####################
# Run: 70, exploration: 0.008, score: 363 | Scores: (min: 9, avg: 207.4142857142857, max: 500)
#
# Run: 71, exploration: 0.008, score: 228 | Scores: (min: 9, avg: 207.70422535211267, max: 500)
#
# Run: 72, exploration: 0.008, score: 146 | Scores: (min: 9, avg: 206.84722222222223, max: 500)
#
# Run: 73, exploration: 0.008, score: 478 | Scores: (min: 9, avg: 210.56164383561645, max: 500)
#
# Run: 74, exploration: 0.008, score: 252 | Scores: (min: 9, avg: 211.1216216216216, max: 500)
#
# Run: 75, exploration: 0.008, score: 309 | Scores: (min: 9, avg: 212.42666666666668, max: 500)
#
# Run: 76, exploration: 0.008, score: 112 | Scores: (min: 9, avg: 211.10526315789474, max: 500)
#
# Run: 77, exploration: 0.008, score: 152 | Scores: (min: 9, avg: 210.33766233766235, max: 500)
#
# Run: 78, exploration: 0.008, score: 161 | Scores: (min: 9, avg: 209.7051282051282, max: 500)
#
# Run: 79, exploration: 0.008, score: 284 | Scores: (min: 9, avg: 210.64556962025316, max: 500)
#
# ####################
# Run: 80, exploration: 0.008, score: 161 | Scores: (min: 9, avg: 210.025, max: 500)
#
# Run: 81, exploration: 0.008, score: 150 | Scores: (min: 9, avg: 209.28395061728395, max: 500)
#
# Run: 82, exploration: 0.008, score: 375 | Scores: (min: 9, avg: 211.3048780487805, max: 500)
#
# Run: 83, exploration: 0.008, score: 404 | Scores: (min: 9, avg: 213.6265060240964, max: 500)
#
# Run: 84, exploration: 0.008, score: 49 | Scores: (min: 9, avg: 211.66666666666666, max: 500)
# Run: 85, exploration: 0.008, score: 183 | Scores: (min: 9, avg: 211.3294117647059, max: 500)
#
# Run: 86, exploration: 0.008, score: 109 | Scores: (min: 9, avg: 210.13953488372093, max: 500)
#
# Run: 87, exploration: 0.008, score: 35 | Scores: (min: 9, avg: 208.1264367816092, max: 500)
#
# Run: 88, exploration: 0.008, score: 12 | Scores: (min: 9, avg: 205.89772727272728, max: 500)
#
# Run: 89, exploration: 0.008, score: 167 | Scores: (min: 9, avg: 205.46067415730337, max: 500)
#
# ####################
# Run: 90, exploration: 0.008, score: 386 | Scores: (min: 9, avg: 207.46666666666667, max: 500)
#
# Run: 91, exploration: 0.008, score: 322 | Scores: (min: 9, avg: 208.72527472527472, max: 500)
#
# Run: 92, exploration: 0.008, score: 179 | Scores: (min: 9, avg: 208.40217391304347, max: 500)
#
# Run: 93, exploration: 0.008, score: 351 | Scores: (min: 9, avg: 209.93548387096774, max: 500)
#
# Run: 94, exploration: 0.008, score: 500 | Scores: (min: 9, avg: 213.0212765957447, max: 500)
#
# Run: 95, exploration: 0.008, score: 123 | Scores: (min: 9, avg: 212.07368421052632, max: 500)
#
# Run: 96, exploration: 0.008, score: 272 | Scores: (min: 9, avg: 212.69791666666666, max: 500)
#
# Run: 97, exploration: 0.008, score: 162 | Scores: (min: 9, avg: 212.17525773195877, max: 500)
#
# Run: 98, exploration: 0.008, score: 168 | Scores: (min: 9, avg: 211.72448979591837, max: 500)
#
# Run: 99, exploration: 0.008, score: 59 | Scores: (min: 9, avg: 210.1818181818182, max: 500)
#
# ####################
# Run: 100, exploration: 0.008, score: 171 | Scores: (min: 9, avg: 209.79, max: 500)
#
# Solved in 0 runs, 100 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-3fbbe320a3cc> in <module>
#       2 reset_to_baseline_settings()
#       3 EXPLORATION_DECAY = 0.997
# ----> 4 cartpole(250)
#
# <ipython-input-3-6270a8499d29> in cartpole(max_run)
#      26                     print("####################")
#      27                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step), end=' | ')
# ---> 28                 score_logger.add_score(step, run)
#      29                 break
#      30             dqn_solver.experience_replay()
#
# U:\Cartpole\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %% [markdown]
# Finally, we will change the exploration factor by decreasing exploration_decay by .002

# %%
# Note: the baseline average at run# 250 was 101.74
reset_to_baseline_settings()
EXPLORATION_DECAY = 0.993
cartpole(250)
# Out:
# Run: 1, exploration: 0.7250692144831015, score: 34 | Scores: (min: 34, avg: 34, max: 34)
#
# Run: 2, exploration: 0.5670262481879318, score: 36 | Scores: (min: 34, avg: 35, max: 36)
#
# Run: 3, exploration: 0.5360399416300314, score: 9 | Scores: (min: 9, avg: 26.333333333333332, max: 36)
#
# Run: 4, exploration: 0.506746945032946, score: 9 | Scores: (min: 9, avg: 22, max: 36)
#
# Run: 5, exploration: 0.47905472401804494, score: 9 | Scores: (min: 9, avg: 19.4, max: 36)
#
# Run: 6, exploration: 0.41626519225154546, score: 21 | Scores: (min: 9, avg: 19.666666666666668, max: 36)
#
# Run: 7, exploration: 0.3720129626646657, score: 17 | Scores: (min: 9, avg: 19.285714285714285, max: 36)
#
# Run: 8, exploration: 0.34922177020490575, score: 10 | Scores: (min: 9, avg: 18.125, max: 36)
#
# Run: 9, exploration: 0.3232533563698685, score: 12 | Scores: (min: 9, avg: 17.444444444444443, max: 36)
#
# ####################
# Run: 10, exploration: 0.2992159748319074, score: 12 | Scores: (min: 9, avg: 16.9, max: 36)
#
# Run: 11, exploration: 0.2769660324645403, score: 12 | Scores: (min: 9, avg: 16.454545454545453, max: 36)
#
# Run: 12, exploration: 0.2599978437608432, score: 10 | Scores: (min: 9, avg: 15.916666666666666, max: 36)
#
# Run: 13, exploration: 0.23897954404772817, score: 13 | Scores: (min: 9, avg: 15.692307692307692, max: 36)
#
# Run: 14, exploration: 0.2212088314879167, score: 12 | Scores: (min: 9, avg: 15.428571428571429, max: 36)
#
# Run: 15, exploration: 0.2091204234332551, score: 9 | Scores: (min: 9, avg: 15, max: 36)
#
# Run: 16, exploration: 0.19630876282983145, score: 10 | Scores: (min: 9, avg: 14.6875, max: 36)
#
# Run: 17, exploration: 0.18299202833933786, score: 11 | Scores: (min: 9, avg: 14.470588235294118, max: 36)
#
# Run: 18, exploration: 0.16938459281880736, score: 12 | Scores: (min: 9, avg: 14.333333333333334, max: 36)
#
# Run: 19, exploration: 0.15789427717098417, score: 11 | Scores: (min: 9, avg: 14.157894736842104, max: 36)
#
# ####################
# Run: 20, exploration: 0.14615313076606692, score: 12 | Scores: (min: 9, avg: 14.05, max: 36)
#
# Run: 21, exploration: 0.13623873667937395, score: 11 | Scores: (min: 9, avg: 13.904761904761905, max: 36)
#
# Run: 22, exploration: 0.12699689205905937, score: 11 | Scores: (min: 9, avg: 13.772727272727273, max: 36)
#
# Run: 23, exploration: 0.11921648949465082, score: 10 | Scores: (min: 9, avg: 13.608695652173912, max: 36)
#
# Run: 24, exploration: 0.11191274949326077, score: 10 | Scores: (min: 9, avg: 13.458333333333334, max: 36)
#
# Run: 25, exploration: 0.10505646955577655, score: 10 | Scores: (min: 9, avg: 13.32, max: 36)
#
# Run: 26, exploration: 0.09792989460611108, score: 11 | Scores: (min: 9, avg: 13.23076923076923, max: 36)
#
# Run: 27, exploration: 0.09128675557170103, score: 11 | Scores: (min: 9, avg: 13.148148148148149, max: 36)
#
# Run: 28, exploration: 0.08509425825816698, score: 11 | Scores: (min: 9, avg: 13.071428571428571, max: 36)
#
# Run: 29, exploration: 0.08044410884950891, score: 9 | Scores: (min: 9, avg: 12.931034482758621, max: 36)
#
# ####################
# Run: 30, exploration: 0.07604807634562762, score: 9 | Scores: (min: 9, avg: 12.8, max: 36)
#
# Run: 31, exploration: 0.07088930489493406, score: 11 | Scores: (min: 9, avg: 12.741935483870968, max: 36)
#
# Run: 32, exploration: 0.06654630625417056, score: 10 | Scores: (min: 9, avg: 12.65625, max: 36)
#
# Run: 33, exploration: 0.06246937930393397, score: 10 | Scores: (min: 9, avg: 12.575757575757576, max: 36)
#
# Run: 34, exploration: 0.05782410563491094, score: 12 | Scores: (min: 9, avg: 12.558823529411764, max: 36)
#
# Run: 35, exploration: 0.054664189371129934, score: 9 | Scores: (min: 9, avg: 12.457142857142857, max: 36)
#
# Run: 36, exploration: 0.052041241873670624, score: 8 | Scores: (min: 8, avg: 12.333333333333334, max: 36)
#
# Run: 37, exploration: 0.04919734200218365, score: 9 | Scores: (min: 8, avg: 12.243243243243244, max: 36)
#
# Run: 38, exploration: 0.04618329087329565, score: 10 | Scores: (min: 8, avg: 12.18421052631579, max: 36)
#
# Run: 39, exploration: 0.04396728166115644, score: 8 | Scores: (min: 8, avg: 12.076923076923077, max: 36)
#
# ####################
# Run: 40, exploration: 0.04185760304468132, score: 8 | Scores: (min: 8, avg: 11.975, max: 36)
#
# Run: 41, exploration: 0.03929321743816284, score: 10 | Scores: (min: 8, avg: 11.926829268292684, max: 36)
#
# Run: 42, exploration: 0.037145959378988104, score: 9 | Scores: (min: 8, avg: 11.857142857142858, max: 36)
#
# Run: 43, exploration: 0.03511604261872703, score: 9 | Scores: (min: 8, avg: 11.790697674418604, max: 36)
#
# Run: 44, exploration: 0.03343107230878387, score: 8 | Scores: (min: 8, avg: 11.704545454545455, max: 36)
#
# Run: 45, exploration: 0.03160416313406789, score: 9 | Scores: (min: 8, avg: 11.644444444444444, max: 36)
#
# Run: 46, exploration: 0.02987708913968456, score: 9 | Scores: (min: 8, avg: 11.58695652173913, max: 36)
#
# Run: 47, exploration: 0.028046683866055015, score: 10 | Scores: (min: 8, avg: 11.553191489361701, max: 36)
#
# Run: 48, exploration: 0.02651401558661751, score: 9 | Scores: (min: 8, avg: 11.5, max: 36)
#
# Run: 49, exploration: 0.02506510309328337, score: 9 | Scores: (min: 8, avg: 11.448979591836734, max: 36)
#
# ####################
# Run: 50, exploration: 0.02352950179452517, score: 10 | Scores: (min: 8, avg: 11.42, max: 36)
#
# Run: 51, exploration: 0.02193336251080457, score: 11 | Scores: (min: 8, avg: 11.411764705882353, max: 36)
#
# Run: 52, exploration: 0.02030237990012636, score: 12 | Scores: (min: 8, avg: 11.423076923076923, max: 36)
#
# Run: 53, exploration: 0.018925154560015197, score: 11 | Scores: (min: 8, avg: 11.415094339622641, max: 36)
#
# Run: 54, exploration: 0.017765714209285237, score: 10 | Scores: (min: 8, avg: 11.38888888888889, max: 36)
#
# Run: 55, exploration: 0.01679487049884291, score: 9 | Scores: (min: 8, avg: 11.345454545454546, max: 36)
#
# Run: 56, exploration: 0.01587708052432148, score: 9 | Scores: (min: 8, avg: 11.303571428571429, max: 36)
#
# Run: 57, exploration: 0.014904378940653556, score: 10 | Scores: (min: 8, avg: 11.280701754385966, max: 36)
#
# Run: 58, exploration: 0.013991269444423917, score: 10 | Scores: (min: 8, avg: 11.258620689655173, max: 36)
#
# Run: 59, exploration: 0.013226687971300617, score: 9 | Scores: (min: 8, avg: 11.220338983050848, max: 36)
#
# ####################
# Run: 60, exploration: 0.01241636139289363, score: 10 | Scores: (min: 8, avg: 11.2, max: 36)
#
# Run: 61, exploration: 0.011493070697737787, score: 12 | Scores: (min: 8, avg: 11.21311475409836, max: 36)
#
# Run: 62, exploration: 0.01071343066152139, score: 11 | Scores: (min: 8, avg: 11.209677419354838, max: 36)
#
# Run: 63, exploration: 0.009986678021724748, score: 11 | Scores: (min: 8, avg: 11.206349206349206, max: 36)
#
# Run: 64, exploration: 0.009244060551017659, score: 12 | Scores: (min: 8, avg: 11.21875, max: 36)
#
# Run: 65, exploration: 0.008738899996300812, score: 9 | Scores: (min: 8, avg: 11.184615384615384, max: 36)
#
# Run: 66, exploration: 0.008089068310739541, score: 12 | Scores: (min: 8, avg: 11.196969696969697, max: 36)
#
# Run: 67, exploration: 0.008, score: 11 | Scores: (min: 8, avg: 11.194029850746269, max: 36)
#
# Run: 68, exploration: 0.008, score: 10 | Scores: (min: 8, avg: 11.176470588235293, max: 36)
#
# Run: 69, exploration: 0.008, score: 13 | Scores: (min: 8, avg: 11.202898550724637, max: 36)
#
# ####################
# Run: 70, exploration: 0.008, score: 14 | Scores: (min: 8, avg: 11.242857142857142, max: 36)
#
# Run: 71, exploration: 0.008, score: 14 | Scores: (min: 8, avg: 11.28169014084507, max: 36)
#
# Run: 72, exploration: 0.008, score: 14 | Scores: (min: 8, avg: 11.319444444444445, max: 36)
#
# Run: 73, exploration: 0.008, score: 14 | Scores: (min: 8, avg: 11.356164383561644, max: 36)
#
# Run: 74, exploration: 0.008, score: 12 | Scores: (min: 8, avg: 11.364864864864865, max: 36)
#
# Run: 75, exploration: 0.008, score: 20 | Scores: (min: 8, avg: 11.48, max: 36)
#
# Run: 76, exploration: 0.008, score: 18 | Scores: (min: 8, avg: 11.56578947368421, max: 36)
#
# Run: 77, exploration: 0.008, score: 13 | Scores: (min: 8, avg: 11.584415584415584, max: 36)
#
# Run: 78, exploration: 0.008, score: 21 | Scores: (min: 8, avg: 11.705128205128204, max: 36)
#
# Run: 79, exploration: 0.008, score: 15 | Scores: (min: 8, avg: 11.746835443037975, max: 36)
#
# ####################
# Run: 80, exploration: 0.008, score: 22 | Scores: (min: 8, avg: 11.875, max: 36)
# Run: 81, exploration: 0.008, score: 17 | Scores: (min: 8, avg: 11.938271604938272, max: 36)
#
# Run: 82, exploration: 0.008, score: 17 | Scores: (min: 8, avg: 12, max: 36)
#
# Run: 83, exploration: 0.008, score: 25 | Scores: (min: 8, avg: 12.156626506024097, max: 36)
#
# Run: 84, exploration: 0.008, score: 29 | Scores: (min: 8, avg: 12.357142857142858, max: 36)
#
# Run: 85, exploration: 0.008, score: 31 | Scores: (min: 8, avg: 12.576470588235294, max: 36)
#
# Run: 86, exploration: 0.008, score: 29 | Scores: (min: 8, avg: 12.767441860465116, max: 36)
#
# Run: 87, exploration: 0.008, score: 41 | Scores: (min: 8, avg: 13.091954022988507, max: 41)
#
# Run: 88, exploration: 0.008, score: 37 | Scores: (min: 8, avg: 13.363636363636363, max: 41)
#
# Run: 89, exploration: 0.008, score: 50 | Scores: (min: 8, avg: 13.775280898876405, max: 50)
#
# ####################
# Run: 90, exploration: 0.008, score: 53 | Scores: (min: 8, avg: 14.21111111111111, max: 53)
#
# Run: 91, exploration: 0.008, score: 68 | Scores: (min: 8, avg: 14.802197802197803, max: 68)
#
# Run: 92, exploration: 0.008, score: 94 | Scores: (min: 8, avg: 15.66304347826087, max: 94)
#
# Run: 93, exploration: 0.008, score: 63 | Scores: (min: 8, avg: 16.172043010752688, max: 94)
#
# Run: 94, exploration: 0.008, score: 38 | Scores: (min: 8, avg: 16.404255319148938, max: 94)
#
# Run: 95, exploration: 0.008, score: 27 | Scores: (min: 8, avg: 16.51578947368421, max: 94)
#
# Run: 96, exploration: 0.008, score: 21 | Scores: (min: 8, avg: 16.5625, max: 94)
#
# Run: 97, exploration: 0.008, score: 37 | Scores: (min: 8, avg: 16.77319587628866, max: 94)
#
# Run: 98, exploration: 0.008, score: 19 | Scores: (min: 8, avg: 16.79591836734694, max: 94)
#
# Run: 99, exploration: 0.008, score: 18 | Scores: (min: 8, avg: 16.80808080808081, max: 94)
#
# ####################
# Run: 100, exploration: 0.008, score: 30 | Scores: (min: 8, avg: 16.94, max: 94)
#
# Run: 101, exploration: 0.008, score: 21 | Scores: (min: 8, avg: 16.81, max: 94)
#
# Run: 102, exploration: 0.008, score: 38 | Scores: (min: 8, avg: 16.83, max: 94)
#
# Run: 103, exploration: 0.008, score: 33 | Scores: (min: 8, avg: 17.07, max: 94)
#
# Run: 104, exploration: 0.008, score: 19 | Scores: (min: 8, avg: 17.17, max: 94)
#
# Run: 105, exploration: 0.008, score: 25 | Scores: (min: 8, avg: 17.33, max: 94)
#
# Run: 106, exploration: 0.008, score: 23 | Scores: (min: 8, avg: 17.35, max: 94)
#
# Run: 107, exploration: 0.008, score: 27 | Scores: (min: 8, avg: 17.45, max: 94)
#
# Run: 108, exploration: 0.008, score: 25 | Scores: (min: 8, avg: 17.6, max: 94)
#
# Run: 109, exploration: 0.008, score: 25 | Scores: (min: 8, avg: 17.73, max: 94)
#
# ####################
# Run: 110, exploration: 0.008, score: 17 | Scores: (min: 8, avg: 17.78, max: 94)
#
# Run: 111, exploration: 0.008, score: 28 | Scores: (min: 8, avg: 17.94, max: 94)
#
# Run: 112, exploration: 0.008, score: 45 | Scores: (min: 8, avg: 18.29, max: 94)
#
# Run: 113, exploration: 0.008, score: 65 | Scores: (min: 8, avg: 18.81, max: 94)
#
# Run: 114, exploration: 0.008, score: 30 | Scores: (min: 8, avg: 18.99, max: 94)
#
# Run: 115, exploration: 0.008, score: 35 | Scores: (min: 8, avg: 19.25, max: 94)
#
# Run: 116, exploration: 0.008, score: 44 | Scores: (min: 8, avg: 19.59, max: 94)
#
# Run: 117, exploration: 0.008, score: 40 | Scores: (min: 8, avg: 19.88, max: 94)
#
# Run: 118, exploration: 0.008, score: 23 | Scores: (min: 8, avg: 19.99, max: 94)
#
# Run: 119, exploration: 0.008, score: 56 | Scores: (min: 8, avg: 20.44, max: 94)
#
# ####################
# Run: 120, exploration: 0.008, score: 41 | Scores: (min: 8, avg: 20.73, max: 94)
#
# Run: 121, exploration: 0.008, score: 50 | Scores: (min: 8, avg: 21.12, max: 94)
#
# Run: 122, exploration: 0.008, score: 86 | Scores: (min: 8, avg: 21.87, max: 94)
#
# Run: 123, exploration: 0.008, score: 86 | Scores: (min: 8, avg: 22.63, max: 94)
#
# Run: 124, exploration: 0.008, score: 80 | Scores: (min: 8, avg: 23.33, max: 94)
#
# Run: 125, exploration: 0.008, score: 120 | Scores: (min: 8, avg: 24.43, max: 120)
#
# Run: 126, exploration: 0.008, score: 118 | Scores: (min: 8, avg: 25.5, max: 120)
#
# Run: 127, exploration: 0.008, score: 100 | Scores: (min: 8, avg: 26.39, max: 120)
#
# Run: 128, exploration: 0.008, score: 116 | Scores: (min: 8, avg: 27.44, max: 120)
#
# Run: 129, exploration: 0.008, score: 195 | Scores: (min: 8, avg: 29.3, max: 195)
#
# ####################
# Run: 130, exploration: 0.008, score: 225 | Scores: (min: 8, avg: 31.46, max: 225)
#
# Run: 131, exploration: 0.008, score: 136 | Scores: (min: 8, avg: 32.71, max: 225)
#
# Run: 132, exploration: 0.008, score: 210 | Scores: (min: 8, avg: 34.71, max: 225)
#
# Run: 133, exploration: 0.008, score: 129 | Scores: (min: 8, avg: 35.9, max: 225)
#
# Run: 134, exploration: 0.008, score: 149 | Scores: (min: 8, avg: 37.27, max: 225)
#
# Run: 135, exploration: 0.008, score: 134 | Scores: (min: 8, avg: 38.52, max: 225)
#
# Run: 136, exploration: 0.008, score: 188 | Scores: (min: 8, avg: 40.32, max: 225)
#
# Run: 137, exploration: 0.008, score: 159 | Scores: (min: 8, avg: 41.82, max: 225)
#
# Run: 138, exploration: 0.008, score: 165 | Scores: (min: 8, avg: 43.37, max: 225)
#
# Run: 139, exploration: 0.008, score: 163 | Scores: (min: 8, avg: 44.92, max: 225)
#
# ####################
# Run: 140, exploration: 0.008, score: 190 | Scores: (min: 8, avg: 46.74, max: 225)
#
# Run: 141, exploration: 0.008, score: 156 | Scores: (min: 8, avg: 48.2, max: 225)
#
# Run: 142, exploration: 0.008, score: 168 | Scores: (min: 8, avg: 49.79, max: 225)
#
# Run: 143, exploration: 0.008, score: 151 | Scores: (min: 8, avg: 51.21, max: 225)
#
# Run: 144, exploration: 0.008, score: 143 | Scores: (min: 9, avg: 52.56, max: 225)
#
# Run: 145, exploration: 0.008, score: 149 | Scores: (min: 9, avg: 53.96, max: 225)
#
# Run: 146, exploration: 0.008, score: 151 | Scores: (min: 9, avg: 55.38, max: 225)
#
# Run: 147, exploration: 0.008, score: 158 | Scores: (min: 9, avg: 56.86, max: 225)
#
# Run: 148, exploration: 0.008, score: 159 | Scores: (min: 9, avg: 58.36, max: 225)
#
# Run: 149, exploration: 0.008, score: 162 | Scores: (min: 9, avg: 59.89, max: 225)
#
# ####################
# Run: 150, exploration: 0.008, score: 141 | Scores: (min: 9, avg: 61.2, max: 225)
#
# Run: 151, exploration: 0.008, score: 152 | Scores: (min: 9, avg: 62.61, max: 225)
#
# Run: 152, exploration: 0.008, score: 150 | Scores: (min: 9, avg: 63.99, max: 225)
#
# Run: 153, exploration: 0.008, score: 180 | Scores: (min: 9, avg: 65.68, max: 225)
#
# Run: 154, exploration: 0.008, score: 164 | Scores: (min: 9, avg: 67.22, max: 225)
#
# Run: 155, exploration: 0.008, score: 158 | Scores: (min: 9, avg: 68.71, max: 225)
#
# Run: 156, exploration: 0.008, score: 158 | Scores: (min: 9, avg: 70.2, max: 225)
#
# Run: 157, exploration: 0.008, score: 162 | Scores: (min: 9, avg: 71.72, max: 225)
#
# Run: 158, exploration: 0.008, score: 176 | Scores: (min: 9, avg: 73.38, max: 225)
#
# Run: 159, exploration: 0.008, score: 145 | Scores: (min: 9, avg: 74.74, max: 225)
#
# ####################
# Run: 160, exploration: 0.008, score: 174 | Scores: (min: 9, avg: 76.38, max: 225)
#
# Run: 161, exploration: 0.008, score: 141 | Scores: (min: 9, avg: 77.67, max: 225)
#
# Run: 162, exploration: 0.008, score: 143 | Scores: (min: 9, avg: 78.99, max: 225)
#
# Run: 163, exploration: 0.008, score: 177 | Scores: (min: 9, avg: 80.65, max: 225)
#
# Run: 164, exploration: 0.008, score: 184 | Scores: (min: 9, avg: 82.37, max: 225)
#
# Run: 165, exploration: 0.008, score: 175 | Scores: (min: 10, avg: 84.03, max: 225)
#
# Run: 166, exploration: 0.008, score: 153 | Scores: (min: 10, avg: 85.44, max: 225)
#
# Run: 167, exploration: 0.008, score: 184 | Scores: (min: 10, avg: 87.17, max: 225)
#
# Run: 168, exploration: 0.008, score: 407 | Scores: (min: 12, avg: 91.14, max: 407)
#
# Run: 169, exploration: 0.008, score: 208 | Scores: (min: 12, avg: 93.09, max: 407)
#
# ####################
# Run: 170, exploration: 0.008, score: 319 | Scores: (min: 12, avg: 96.14, max: 407)
#
# Run: 171, exploration: 0.008, score: 269 | Scores: (min: 12, avg: 98.69, max: 407)
#
# Run: 172, exploration: 0.008, score: 102 | Scores: (min: 12, avg: 99.57, max: 407)
#
# Run: 173, exploration: 0.008, score: 111 | Scores: (min: 12, avg: 100.54, max: 407)
#
# Run: 174, exploration: 0.008, score: 195 | Scores: (min: 13, avg: 102.37, max: 407)
#
# Run: 175, exploration: 0.008, score: 156 | Scores: (min: 13, avg: 103.73, max: 407)
#
# Run: 176, exploration: 0.008, score: 219 | Scores: (min: 13, avg: 105.74, max: 407)
# Run: 177, exploration: 0.008, score: 213 | Scores: (min: 15, avg: 107.74, max: 407)
#
# Run: 178, exploration: 0.008, score: 253 | Scores: (min: 15, avg: 110.06, max: 407)
#
# Run: 179, exploration: 0.008, score: 251 | Scores: (min: 17, avg: 112.42, max: 407)
#
# ####################
# Run: 180, exploration: 0.008, score: 258 | Scores: (min: 17, avg: 114.78, max: 407)
#
# Run: 181, exploration: 0.008, score: 199 | Scores: (min: 17, avg: 116.6, max: 407)
#
# Run: 182, exploration: 0.008, score: 355 | Scores: (min: 17, avg: 119.98, max: 407)
#
# Run: 183, exploration: 0.008, score: 259 | Scores: (min: 17, avg: 122.32, max: 407)
#
# Run: 184, exploration: 0.008, score: 182 | Scores: (min: 17, avg: 123.85, max: 407)
#
# Run: 185, exploration: 0.008, score: 186 | Scores: (min: 17, avg: 125.4, max: 407)
#
# Run: 186, exploration: 0.008, score: 37 | Scores: (min: 17, avg: 125.48, max: 407)
#
# Run: 187, exploration: 0.008, score: 147 | Scores: (min: 17, avg: 126.54, max: 407)
#
# Run: 188, exploration: 0.008, score: 223 | Scores: (min: 17, avg: 128.4, max: 407)
#
# Run: 189, exploration: 0.008, score: 200 | Scores: (min: 17, avg: 129.9, max: 407)
#
# ####################
# Run: 190, exploration: 0.008, score: 311 | Scores: (min: 17, avg: 132.48, max: 407)
#
# Run: 191, exploration: 0.008, score: 288 | Scores: (min: 17, avg: 134.68, max: 407)
#
# Run: 192, exploration: 0.008, score: 288 | Scores: (min: 17, avg: 136.62, max: 407)
#
# Run: 193, exploration: 0.008, score: 149 | Scores: (min: 17, avg: 137.48, max: 407)
#
# Run: 194, exploration: 0.008, score: 175 | Scores: (min: 17, avg: 138.85, max: 407)
#
# Run: 195, exploration: 0.008, score: 333 | Scores: (min: 17, avg: 141.91, max: 407)
#
# Run: 196, exploration: 0.008, score: 272 | Scores: (min: 17, avg: 144.42, max: 407)
#
# Run: 197, exploration: 0.008, score: 116 | Scores: (min: 17, avg: 145.21, max: 407)
#
# Run: 198, exploration: 0.008, score: 290 | Scores: (min: 17, avg: 147.92, max: 407)
#
# Run: 199, exploration: 0.008, score: 292 | Scores: (min: 17, avg: 150.66, max: 407)
#
# ####################
# Run: 200, exploration: 0.008, score: 195 | Scores: (min: 17, avg: 152.31, max: 407)
#
# Run: 201, exploration: 0.008, score: 248 | Scores: (min: 17, avg: 154.58, max: 407)
#
# Run: 202, exploration: 0.008, score: 157 | Scores: (min: 17, avg: 155.77, max: 407)
#
# Run: 203, exploration: 0.008, score: 126 | Scores: (min: 17, avg: 156.7, max: 407)
#
# Run: 204, exploration: 0.008, score: 228 | Scores: (min: 17, avg: 158.79, max: 407)
#
# Run: 205, exploration: 0.008, score: 254 | Scores: (min: 17, avg: 161.08, max: 407)
#
# Run: 206, exploration: 0.008, score: 67 | Scores: (min: 17, avg: 161.52, max: 407)
#
# Run: 207, exploration: 0.008, score: 302 | Scores: (min: 17, avg: 164.27, max: 407)
#
# Run: 208, exploration: 0.008, score: 156 | Scores: (min: 17, avg: 165.58, max: 407)
#
# Run: 209, exploration: 0.008, score: 187 | Scores: (min: 17, avg: 167.2, max: 407)
#
# ####################
# Run: 210, exploration: 0.008, score: 121 | Scores: (min: 23, avg: 168.24, max: 407)
#
# Run: 211, exploration: 0.008, score: 195 | Scores: (min: 23, avg: 169.91, max: 407)
#
# Run: 212, exploration: 0.008, score: 162 | Scores: (min: 23, avg: 171.08, max: 407)
#
# Run: 213, exploration: 0.008, score: 213 | Scores: (min: 23, avg: 172.56, max: 407)
#
# Run: 214, exploration: 0.008, score: 113 | Scores: (min: 23, avg: 173.39, max: 407)
#
# Run: 215, exploration: 0.008, score: 134 | Scores: (min: 23, avg: 174.38, max: 407)
#
# Run: 216, exploration: 0.008, score: 89 | Scores: (min: 23, avg: 174.83, max: 407)
#
# Run: 217, exploration: 0.008, score: 140 | Scores: (min: 23, avg: 175.83, max: 407)
#
# Run: 218, exploration: 0.008, score: 182 | Scores: (min: 37, avg: 177.42, max: 407)
#
# Run: 219, exploration: 0.008, score: 271 | Scores: (min: 37, avg: 179.57, max: 407)
#
# ####################
# Run: 220, exploration: 0.008, score: 86 | Scores: (min: 37, avg: 180.02, max: 407)
#
# Run: 221, exploration: 0.008, score: 167 | Scores: (min: 37, avg: 181.19, max: 407)
#
# Run: 222, exploration: 0.008, score: 160 | Scores: (min: 37, avg: 181.93, max: 407)
#
# Run: 223, exploration: 0.008, score: 348 | Scores: (min: 37, avg: 184.55, max: 407)
#
# Run: 224, exploration: 0.008, score: 249 | Scores: (min: 37, avg: 186.24, max: 407)
#
# Run: 225, exploration: 0.008, score: 127 | Scores: (min: 37, avg: 186.31, max: 407)
#
# Run: 226, exploration: 0.008, score: 198 | Scores: (min: 37, avg: 187.11, max: 407)
#
# Run: 227, exploration: 0.008, score: 235 | Scores: (min: 37, avg: 188.46, max: 407)
#
# Run: 228, exploration: 0.008, score: 113 | Scores: (min: 37, avg: 188.43, max: 407)
#
# Run: 229, exploration: 0.008, score: 500 | Scores: (min: 37, avg: 191.48, max: 500)
#
# ####################
# Run: 230, exploration: 0.008, score: 215 | Scores: (min: 37, avg: 191.38, max: 500)
#
# Run: 231, exploration: 0.008, score: 127 | Scores: (min: 37, avg: 191.29, max: 500)
#
# Run: 232, exploration: 0.008, score: 403 | Scores: (min: 37, avg: 193.22, max: 500)
#
# Run: 233, exploration: 0.008, score: 207 | Scores: (min: 37, avg: 194, max: 500)
#
# Run: 234, exploration: 0.008, score: 115 | Scores: (min: 37, avg: 193.66, max: 500)
#
# Run: 235, exploration: 0.008, score: 269 | Scores: (min: 37, avg: 195.01, max: 500)
#
# Solved in 135 runs, 235 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-6ad569a07efe> in <module>
#       2 reset_to_baseline_settings()
#       3 EXPLORATION_DECAY = 0.993
# ----> 4 cartpole(250)
#
# <ipython-input-3-6270a8499d29> in cartpole(max_run)
#      26                     print("####################")
#      27                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step), end=' | ')
# ---> 28                 score_logger.add_score(step, run)
#      29                 break
#      30             dqn_solver.experience_replay()
#
# U:\Cartpole\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %% [markdown]
# # Thoughts about results:
#
# For each variable change, we had a sample size of one. This is largely due to constraints on computational power and access to the computer lab. As such, these results are not conclusive.
#
# We took 826 runs to solve the scenario with default values; at run #249, the average score was slightly above 100. When we adjusted gamma, we found that increasing it slightly resulted in an average score of 194 by run 249 and when we decreased it slightly we found that the provlem was solved in 158 runs. When we increased learning rate slightly, we solved in 175; when we decreased we solved in 121. When we increased exploration max, we solved in 147; when we decreased, we solved in 110. When we increased exploration min, the average score at run 249 was 77; when we decreased, the average was 88. Finally, when we increased exploration decay, we solved in 100 runs; When we decreased, we solved in 235.
#
# Overall, adjusting gamma in either direction resulted in improvements, with decreasing the value yeilding better performance. Adjusting learning rate in either direction resulted in an improvement, but decreasing it resulted in the best performance. When we modified exploration max in either direction, we improved our score, but decreasing it resulted in the best performance. When we changed exploration min, we universally harmed our performance. When we changed exploration decay, we improved our performance in either direction, but increasing it resulted in the quickest solve yet.
#
# It could be that the performance changes were a result of a low sample size, it could be that these values need to be in certain ratios relative to eachother, or it could be that we could produce a much quicker solve by combining what has worked so far:

# %%
# Note: the baseline average at run# 250 was 101.74
reset_to_baseline_settings()
GAMMA = 0.94
LEARNING_RATE = 0.0008  
EXPLORATION_MAX = .8
EXPLORATION_DECAY = 0.997 
cartpole(250)
# Out:
# Run: 1, exploration: 0.8, score: 11 | Scores: (min: 11, avg: 11, max: 11)
#
# Run: 2, exploration: 0.7857075689708344, score: 15 | Scores: (min: 11, avg: 13, max: 15)
#
# Run: 3, exploration: 0.7556105185200527, score: 14 | Scores: (min: 11, avg: 13.333333333333334, max: 15)
#
# Run: 4, exploration: 0.7244863565164134, score: 15 | Scores: (min: 11, avg: 13.75, max: 15)
#
# Run: 5, exploration: 0.7009337191955577, score: 12 | Scores: (min: 11, avg: 13.4, max: 15)
#
# Run: 6, exploration: 0.6740839873838664, score: 14 | Scores: (min: 11, avg: 13.5, max: 15)
#
# Run: 7, exploration: 0.6405185355881937, score: 18 | Scores: (min: 11, avg: 14.142857142857142, max: 18)
#
# Run: 8, exploration: 0.6104558150072419, score: 17 | Scores: (min: 11, avg: 14.5, max: 18)
#
# Run: 9, exploration: 0.509757628551752, score: 61 | Scores: (min: 11, avg: 19.666666666666668, max: 61)
#
# ####################
# Run: 10, exploration: 0.4742938935465297, score: 25 | Scores: (min: 11, avg: 20.2, max: 61)
#
# Run: 11, exploration: 0.4044742922376113, score: 54 | Scores: (min: 11, avg: 23.272727272727273, max: 61)
#
# Run: 12, exploration: 0.36300835674260845, score: 37 | Scores: (min: 11, avg: 24.416666666666668, max: 61)
#
# Run: 13, exploration: 0.33877024961294344, score: 24 | Scores: (min: 11, avg: 24.384615384615383, max: 61)
#
# Run: 14, exploration: 0.28890074025359924, score: 54 | Scores: (min: 11, avg: 26.5, max: 61)
#
# Run: 15, exploration: 0.2471137361114808, score: 53 | Scores: (min: 11, avg: 28.266666666666666, max: 61)
#
# Run: 16, exploration: 0.17863805622997883, score: 109 | Scores: (min: 11, avg: 33.3125, max: 109)
#
# Run: 17, exploration: 0.16571161209929774, score: 26 | Scores: (min: 11, avg: 32.88235294117647, max: 109)
#
# Run: 18, exploration: 0.13069845354029794, score: 80 | Scores: (min: 11, avg: 35.5, max: 109)
#
# Run: 19, exploration: 0.12270684038249202, score: 22 | Scores: (min: 11, avg: 34.78947368421053, max: 109)
#
# ####################
# Run: 20, exploration: 0.10154621659129047, score: 64 | Scores: (min: 11, avg: 36.25, max: 109)
#
# Run: 21, exploration: 0.09168517741352725, score: 35 | Scores: (min: 11, avg: 36.19047619047619, max: 109)
#
# Run: 22, exploration: 0.06489964713889011, score: 116 | Scores: (min: 11, avg: 39.81818181818182, max: 116)
#
# Run: 23, exploration: 0.051187019478642265, score: 80 | Scores: (min: 11, avg: 41.56521739130435, max: 116)
#
# Run: 24, exploration: 0.033712180805062074, score: 140 | Scores: (min: 11, avg: 45.666666666666664, max: 140)
#
# Run: 25, exploration: 0.019221242227494, score: 188 | Scores: (min: 11, avg: 51.36, max: 188)
#
# Run: 26, exploration: 0.010571045832268559, score: 200 | Scores: (min: 11, avg: 57.07692307692308, max: 200)
#
# Run: 27, exploration: 0.01, score: 247 | Scores: (min: 11, avg: 64.11111111111111, max: 247)
#
# Run: 28, exploration: 0.01, score: 235 | Scores: (min: 11, avg: 70.21428571428571, max: 247)
#
# Run: 29, exploration: 0.01, score: 184 | Scores: (min: 11, avg: 74.13793103448276, max: 247)
#
# ####################
# Run: 30, exploration: 0.01, score: 197 | Scores: (min: 11, avg: 78.23333333333333, max: 247)
#
# Run: 31, exploration: 0.01, score: 258 | Scores: (min: 11, avg: 84.03225806451613, max: 258)
#
# Run: 32, exploration: 0.01, score: 166 | Scores: (min: 11, avg: 86.59375, max: 258)
#
# Run: 33, exploration: 0.01, score: 185 | Scores: (min: 11, avg: 89.57575757575758, max: 258)
#
# Run: 34, exploration: 0.01, score: 186 | Scores: (min: 11, avg: 92.41176470588235, max: 258)
#
# Run: 35, exploration: 0.01, score: 180 | Scores: (min: 11, avg: 94.91428571428571, max: 258)
#
# Run: 36, exploration: 0.01, score: 158 | Scores: (min: 11, avg: 96.66666666666667, max: 258)
#
# Run: 37, exploration: 0.01, score: 177 | Scores: (min: 11, avg: 98.83783783783784, max: 258)
#
# Run: 38, exploration: 0.01, score: 193 | Scores: (min: 11, avg: 101.3157894736842, max: 258)
#
# Run: 39, exploration: 0.01, score: 204 | Scores: (min: 11, avg: 103.94871794871794, max: 258)
#
# ####################
# Run: 40, exploration: 0.01, score: 176 | Scores: (min: 11, avg: 105.75, max: 258)
#
# Run: 41, exploration: 0.01, score: 210 | Scores: (min: 11, avg: 108.29268292682927, max: 258)
#
# Run: 42, exploration: 0.01, score: 170 | Scores: (min: 11, avg: 109.76190476190476, max: 258)
#
# Run: 43, exploration: 0.01, score: 185 | Scores: (min: 11, avg: 111.51162790697674, max: 258)
#
# Run: 44, exploration: 0.01, score: 162 | Scores: (min: 11, avg: 112.6590909090909, max: 258)
#
# Run: 45, exploration: 0.01, score: 192 | Scores: (min: 11, avg: 114.42222222222222, max: 258)
#
# Run: 46, exploration: 0.01, score: 230 | Scores: (min: 11, avg: 116.93478260869566, max: 258)
#
# Run: 47, exploration: 0.01, score: 200 | Scores: (min: 11, avg: 118.70212765957447, max: 258)
#
# Run: 48, exploration: 0.01, score: 320 | Scores: (min: 11, avg: 122.89583333333333, max: 320)
#
# Run: 49, exploration: 0.01, score: 140 | Scores: (min: 11, avg: 123.24489795918367, max: 320)
#
# ####################
# Run: 50, exploration: 0.01, score: 246 | Scores: (min: 11, avg: 125.7, max: 320)
#
# Run: 51, exploration: 0.01, score: 218 | Scores: (min: 11, avg: 127.50980392156863, max: 320)
#
# Run: 52, exploration: 0.01, score: 156 | Scores: (min: 11, avg: 128.05769230769232, max: 320)
#
# Run: 53, exploration: 0.01, score: 182 | Scores: (min: 11, avg: 129.0754716981132, max: 320)
#
# Run: 54, exploration: 0.01, score: 333 | Scores: (min: 11, avg: 132.85185185185185, max: 333)
#
# Run: 55, exploration: 0.01, score: 198 | Scores: (min: 11, avg: 134.03636363636363, max: 333)
#
# Run: 56, exploration: 0.01, score: 224 | Scores: (min: 11, avg: 135.64285714285714, max: 333)
#
# Run: 57, exploration: 0.01, score: 296 | Scores: (min: 11, avg: 138.4561403508772, max: 333)
#
# Run: 58, exploration: 0.01, score: 168 | Scores: (min: 11, avg: 138.9655172413793, max: 333)
#
# Run: 59, exploration: 0.01, score: 144 | Scores: (min: 11, avg: 139.05084745762713, max: 333)
#
# ####################
# Run: 60, exploration: 0.01, score: 63 | Scores: (min: 11, avg: 137.78333333333333, max: 333)
#
# Run: 61, exploration: 0.01, score: 138 | Scores: (min: 11, avg: 137.78688524590163, max: 333)
#
# Run: 62, exploration: 0.01, score: 141 | Scores: (min: 11, avg: 137.83870967741936, max: 333)
#
# Run: 63, exploration: 0.01, score: 85 | Scores: (min: 11, avg: 137, max: 333)
#
# Run: 64, exploration: 0.01, score: 237 | Scores: (min: 11, avg: 138.5625, max: 333)
#
# Run: 65, exploration: 0.01, score: 166 | Scores: (min: 11, avg: 138.98461538461538, max: 333)
#
# Run: 66, exploration: 0.01, score: 166 | Scores: (min: 11, avg: 139.3939393939394, max: 333)
#
# Run: 67, exploration: 0.01, score: 170 | Scores: (min: 11, avg: 139.8507462686567, max: 333)
#
# Run: 68, exploration: 0.01, score: 195 | Scores: (min: 11, avg: 140.66176470588235, max: 333)
#
# Run: 69, exploration: 0.01, score: 170 | Scores: (min: 11, avg: 141.08695652173913, max: 333)
#
# ####################
# Run: 70, exploration: 0.01, score: 132 | Scores: (min: 11, avg: 140.95714285714286, max: 333)
#
# Run: 71, exploration: 0.01, score: 188 | Scores: (min: 11, avg: 141.61971830985917, max: 333)
#
# Run: 72, exploration: 0.01, score: 189 | Scores: (min: 11, avg: 142.27777777777777, max: 333)
#
# Run: 73, exploration: 0.01, score: 309 | Scores: (min: 11, avg: 144.56164383561645, max: 333)
#
# Run: 74, exploration: 0.01, score: 221 | Scores: (min: 11, avg: 145.59459459459458, max: 333)
#
# Run: 75, exploration: 0.01, score: 295 | Scores: (min: 11, avg: 147.58666666666667, max: 333)
#
# Run: 76, exploration: 0.01, score: 154 | Scores: (min: 11, avg: 147.67105263157896, max: 333)
#
# Run: 77, exploration: 0.01, score: 197 | Scores: (min: 11, avg: 148.3116883116883, max: 333)
#
# Run: 78, exploration: 0.01, score: 170 | Scores: (min: 11, avg: 148.5897435897436, max: 333)
#
# Run: 79, exploration: 0.01, score: 214 | Scores: (min: 11, avg: 149.41772151898735, max: 333)
#
# ####################
# Run: 80, exploration: 0.01, score: 261 | Scores: (min: 11, avg: 150.8125, max: 333)
#
# Run: 81, exploration: 0.01, score: 211 | Scores: (min: 11, avg: 151.55555555555554, max: 333)
#
# Run: 82, exploration: 0.01, score: 167 | Scores: (min: 11, avg: 151.7439024390244, max: 333)
#
# Run: 83, exploration: 0.01, score: 171 | Scores: (min: 11, avg: 151.97590361445782, max: 333)
#
# Run: 84, exploration: 0.01, score: 239 | Scores: (min: 11, avg: 153.01190476190476, max: 333)
# Run: 85, exploration: 0.01, score: 231 | Scores: (min: 11, avg: 153.9294117647059, max: 333)
#
# Run: 86, exploration: 0.01, score: 293 | Scores: (min: 11, avg: 155.54651162790697, max: 333)
#
# Run: 87, exploration: 0.01, score: 204 | Scores: (min: 11, avg: 156.10344827586206, max: 333)
#
# Run: 88, exploration: 0.01, score: 186 | Scores: (min: 11, avg: 156.4431818181818, max: 333)
#
# Run: 89, exploration: 0.01, score: 165 | Scores: (min: 11, avg: 156.53932584269663, max: 333)
#
# ####################
# Run: 90, exploration: 0.01, score: 177 | Scores: (min: 11, avg: 156.76666666666668, max: 333)
#
# Run: 91, exploration: 0.01, score: 147 | Scores: (min: 11, avg: 156.65934065934067, max: 333)
#
# Run: 92, exploration: 0.01, score: 131 | Scores: (min: 11, avg: 156.3804347826087, max: 333)
#
# Run: 93, exploration: 0.01, score: 149 | Scores: (min: 11, avg: 156.30107526881721, max: 333)
#
# Run: 94, exploration: 0.01, score: 229 | Scores: (min: 11, avg: 157.0744680851064, max: 333)
#
# Run: 95, exploration: 0.01, score: 272 | Scores: (min: 11, avg: 158.2842105263158, max: 333)
#
# Run: 96, exploration: 0.01, score: 134 | Scores: (min: 11, avg: 158.03125, max: 333)
#
# Run: 97, exploration: 0.01, score: 146 | Scores: (min: 11, avg: 157.90721649484536, max: 333)
#
# Run: 98, exploration: 0.01, score: 217 | Scores: (min: 11, avg: 158.51020408163265, max: 333)
#
# Run: 99, exploration: 0.01, score: 226 | Scores: (min: 11, avg: 159.1919191919192, max: 333)
#
# ####################
# Run: 100, exploration: 0.01, score: 221 | Scores: (min: 11, avg: 159.81, max: 333)
#
# Run: 101, exploration: 0.01, score: 159 | Scores: (min: 12, avg: 161.29, max: 333)
#
# Run: 102, exploration: 0.01, score: 202 | Scores: (min: 12, avg: 163.16, max: 333)
#
# Run: 103, exploration: 0.01, score: 220 | Scores: (min: 12, avg: 165.22, max: 333)
#
# Run: 104, exploration: 0.01, score: 178 | Scores: (min: 12, avg: 166.85, max: 333)
#
# Run: 105, exploration: 0.01, score: 139 | Scores: (min: 14, avg: 168.12, max: 333)
#
# Run: 106, exploration: 0.01, score: 197 | Scores: (min: 17, avg: 169.95, max: 333)
#
# Run: 107, exploration: 0.01, score: 116 | Scores: (min: 17, avg: 170.93, max: 333)
#
# Run: 108, exploration: 0.01, score: 136 | Scores: (min: 22, avg: 172.12, max: 333)
#
# Run: 109, exploration: 0.01, score: 194 | Scores: (min: 22, avg: 173.45, max: 333)
#
# ####################
# Run: 110, exploration: 0.01, score: 127 | Scores: (min: 22, avg: 174.47, max: 333)
#
# Run: 111, exploration: 0.01, score: 154 | Scores: (min: 22, avg: 175.47, max: 333)
#
# Run: 112, exploration: 0.01, score: 262 | Scores: (min: 22, avg: 177.72, max: 333)
#
# Run: 113, exploration: 0.01, score: 233 | Scores: (min: 22, avg: 179.81, max: 333)
#
# Run: 114, exploration: 0.01, score: 370 | Scores: (min: 22, avg: 182.97, max: 370)
#
# Run: 115, exploration: 0.01, score: 66 | Scores: (min: 22, avg: 183.1, max: 370)
#
# Run: 116, exploration: 0.01, score: 162 | Scores: (min: 22, avg: 183.63, max: 370)
#
# Run: 117, exploration: 0.01, score: 213 | Scores: (min: 22, avg: 185.5, max: 370)
#
# Run: 118, exploration: 0.01, score: 250 | Scores: (min: 22, avg: 187.2, max: 370)
#
# Run: 119, exploration: 0.01, score: 174 | Scores: (min: 35, avg: 188.72, max: 370)
#
# ####################
# Run: 120, exploration: 0.01, score: 150 | Scores: (min: 35, avg: 189.58, max: 370)
#
# Run: 121, exploration: 0.01, score: 172 | Scores: (min: 63, avg: 190.95, max: 370)
#
# Run: 122, exploration: 0.01, score: 118 | Scores: (min: 63, avg: 190.97, max: 370)
#
# Run: 123, exploration: 0.01, score: 187 | Scores: (min: 63, avg: 192.04, max: 370)
#
# Run: 124, exploration: 0.01, score: 95 | Scores: (min: 63, avg: 191.59, max: 370)
#
# Run: 125, exploration: 0.01, score: 217 | Scores: (min: 63, avg: 191.88, max: 370)
#
# Run: 126, exploration: 0.01, score: 157 | Scores: (min: 63, avg: 191.45, max: 370)
#
# Run: 127, exploration: 0.01, score: 296 | Scores: (min: 63, avg: 191.94, max: 370)
#
# Run: 128, exploration: 0.01, score: 297 | Scores: (min: 63, avg: 192.56, max: 370)
#
# Run: 129, exploration: 0.01, score: 129 | Scores: (min: 63, avg: 192.01, max: 370)
#
# ####################
# Run: 130, exploration: 0.01, score: 118 | Scores: (min: 63, avg: 191.22, max: 370)
#
# Run: 131, exploration: 0.01, score: 120 | Scores: (min: 63, avg: 189.84, max: 370)
#
# Run: 132, exploration: 0.01, score: 245 | Scores: (min: 63, avg: 190.63, max: 370)
#
# Run: 133, exploration: 0.01, score: 117 | Scores: (min: 63, avg: 189.95, max: 370)
#
# Run: 134, exploration: 0.01, score: 150 | Scores: (min: 63, avg: 189.59, max: 370)
#
# Run: 135, exploration: 0.01, score: 148 | Scores: (min: 63, avg: 189.27, max: 370)
#
# Run: 136, exploration: 0.01, score: 290 | Scores: (min: 63, avg: 190.59, max: 370)
#
# Run: 137, exploration: 0.01, score: 164 | Scores: (min: 63, avg: 190.46, max: 370)
#
# Run: 138, exploration: 0.01, score: 114 | Scores: (min: 63, avg: 189.67, max: 370)
#
# Run: 139, exploration: 0.01, score: 14 | Scores: (min: 14, avg: 187.77, max: 370)
#
# ####################
# Run: 140, exploration: 0.01, score: 106 | Scores: (min: 14, avg: 187.07, max: 370)
#
# Run: 141, exploration: 0.01, score: 250 | Scores: (min: 14, avg: 187.47, max: 370)
#
# Run: 142, exploration: 0.01, score: 140 | Scores: (min: 14, avg: 187.17, max: 370)
#
# Run: 143, exploration: 0.01, score: 166 | Scores: (min: 14, avg: 186.98, max: 370)
#
# Run: 144, exploration: 0.01, score: 325 | Scores: (min: 14, avg: 188.61, max: 370)
#
# Run: 145, exploration: 0.01, score: 173 | Scores: (min: 14, avg: 188.42, max: 370)
#
# Run: 146, exploration: 0.01, score: 215 | Scores: (min: 14, avg: 188.27, max: 370)
#
# Run: 147, exploration: 0.01, score: 449 | Scores: (min: 14, avg: 190.76, max: 449)
#
# Run: 148, exploration: 0.01, score: 171 | Scores: (min: 14, avg: 189.27, max: 449)
#
# Run: 149, exploration: 0.01, score: 156 | Scores: (min: 14, avg: 189.43, max: 449)
#
# ####################
# Run: 150, exploration: 0.01, score: 208 | Scores: (min: 14, avg: 189.05, max: 449)
#
# Run: 151, exploration: 0.01, score: 14 | Scores: (min: 14, avg: 187.01, max: 449)
#
# Run: 152, exploration: 0.01, score: 126 | Scores: (min: 14, avg: 186.71, max: 449)
#
# Run: 153, exploration: 0.01, score: 165 | Scores: (min: 14, avg: 186.54, max: 449)
#
# Run: 154, exploration: 0.01, score: 236 | Scores: (min: 14, avg: 185.57, max: 449)
#
# Run: 155, exploration: 0.01, score: 241 | Scores: (min: 14, avg: 186, max: 449)
#
# Run: 156, exploration: 0.01, score: 273 | Scores: (min: 14, avg: 186.49, max: 449)
#
# Run: 157, exploration: 0.01, score: 308 | Scores: (min: 14, avg: 186.61, max: 449)
#
# Run: 158, exploration: 0.01, score: 322 | Scores: (min: 14, avg: 188.15, max: 449)
#
# Run: 159, exploration: 0.01, score: 317 | Scores: (min: 14, avg: 189.88, max: 449)
#
# ####################
# Run: 160, exploration: 0.01, score: 151 | Scores: (min: 14, avg: 190.76, max: 449)
#
# Run: 161, exploration: 0.01, score: 142 | Scores: (min: 14, avg: 190.8, max: 449)
#
# Run: 162, exploration: 0.01, score: 177 | Scores: (min: 14, avg: 191.16, max: 449)
#
# Run: 163, exploration: 0.01, score: 140 | Scores: (min: 14, avg: 191.71, max: 449)
#
# Run: 164, exploration: 0.01, score: 118 | Scores: (min: 14, avg: 190.52, max: 449)
#
# Run: 165, exploration: 0.01, score: 295 | Scores: (min: 14, avg: 191.81, max: 449)
#
# Run: 166, exploration: 0.01, score: 62 | Scores: (min: 14, avg: 190.77, max: 449)
#
# Run: 167, exploration: 0.01, score: 134 | Scores: (min: 14, avg: 190.41, max: 449)
#
# Run: 168, exploration: 0.01, score: 157 | Scores: (min: 14, avg: 190.03, max: 449)
#
# Run: 169, exploration: 0.01, score: 159 | Scores: (min: 14, avg: 189.92, max: 449)
#
# ####################
# Run: 170, exploration: 0.01, score: 191 | Scores: (min: 14, avg: 190.51, max: 449)
#
# Run: 171, exploration: 0.01, score: 129 | Scores: (min: 14, avg: 189.92, max: 449)
#
# Run: 172, exploration: 0.01, score: 119 | Scores: (min: 14, avg: 189.22, max: 449)
#
# Run: 173, exploration: 0.01, score: 172 | Scores: (min: 14, avg: 187.85, max: 449)
#
# Run: 174, exploration: 0.01, score: 144 | Scores: (min: 14, avg: 187.08, max: 449)
#
# Run: 175, exploration: 0.01, score: 235 | Scores: (min: 14, avg: 186.48, max: 449)
#
# Run: 176, exploration: 0.01, score: 360 | Scores: (min: 14, avg: 188.54, max: 449)
#
# Run: 177, exploration: 0.01, score: 276 | Scores: (min: 14, avg: 189.33, max: 449)
#
# Run: 178, exploration: 0.01, score: 160 | Scores: (min: 14, avg: 189.23, max: 449)
# Run: 179, exploration: 0.01, score: 144 | Scores: (min: 14, avg: 188.53, max: 449)
#
# ####################
# Run: 180, exploration: 0.01, score: 166 | Scores: (min: 14, avg: 187.58, max: 449)
#
# Run: 181, exploration: 0.01, score: 185 | Scores: (min: 14, avg: 187.32, max: 449)
#
# Run: 182, exploration: 0.01, score: 267 | Scores: (min: 14, avg: 188.32, max: 449)
#
# Run: 183, exploration: 0.01, score: 151 | Scores: (min: 14, avg: 188.12, max: 449)
#
# Run: 184, exploration: 0.01, score: 194 | Scores: (min: 14, avg: 187.67, max: 449)

# %% [markdown]
# # Final thoughts about modifying the values

# %% [markdown]
# The goal of the agent is to balance a pole on a cart (Surma, 2019). The pole is subject to simulated gravity and is attached to the cart at a point which can be rotated. Another way to describe this setup is an inverted pendulum. The goal is for the cart to balance the pole upright without it falling over. In some versions of the scenario, the goal is to keep the pole within a certain range of angles. The cart will need to move in order to counter-act the simulated gravity. The simulated environment in this scenario was created by OpenAI. The pole can have a position relative to the cart at various angles. The cart can have a displacement along a line. In some versions of the problem, the cart is constrained to a finite x movement. The cart can move left or right. Moving the cart will modify the angle of the pole.
#
#
# In our scenario, the agent is a neural network which learns from experience by making attempts, determining which strategies were successful, and continuing successful behaviors (Surma, 2019). In this case, the agent is trained by reinforcement learning. Specifically, we are using a Markov chain. A score is calculated by analyzing how favorable a state is. In this case, we process the score through a "GAMMA" value, which influences how large or small the reward is; we will discuss the "GAMMA" value later. The agent is then updated with the corresponding reward, then the agent incorporates this data. The agent will try to select the actions which it predicts will result in the state which maximizes the reward. If the pole falls down, the run is determined to be terminal. Information is printed out about the run, then the process is repeated.
#
#
# Q-learning refers to a model-free, value-based algorithm to find the best series of actions (Awan, 2022). The “Q” in q-learning stands for quality, which is a measure for how much a specific action will maximize future reward. In our scenario, we remember each state which our agent has experienced (Surma, 2019). A Q-table is formed, which is a collection of the state-action pairs and associated Q values (Luu, 2024). After an action, we perform an experience replay, which updates the Q table with the maximum predicted reward for an action in a specific state. It is important to note that we will progressively discount future predicted rewards.
#
#
# In our scenario, we are not using Q-learning, but rather, deep Q-learning, which replaces the Q table with a neural network. The neural network is used to predict Q values of actions based on a given state. Instead of recording state-action pairs and associated Q values, the neural network attempts to minimize the difference between its predicted Q-value for a given state and the observed outcome (Luu, 2024).
#
#
# The reason why we want to discount future rewards is so that we weight the more immediate rewards so that we do note take an especially risky action because we anticipate a high payoff (Chanda, 2024). This discounting factor is one of the variables which we can fine-tune in order to prevent overly-cautious behavior while also preventing destructively risky behavior.
#
#
# In our scenario, we are using deep Q-learning, which applies Q-learning principles onto a neural network. Like with other neural networks, we have an input layer which inputs the values that we can observe from the current state, we have processing layers, and we have an output layer which corresponds to which actions we can take (In this case, two: left or right) (Halthor, 2023). Whenever we apply an experience replay, we are adjusting the various values of the neural network and identifying which values correspond to better Q values.
#
#
# One of the issues with standard Q learning is that it becomes challenging with large numbers of possible states (Luu, 2024). In this scenario, this problem is not quite as pronounced because we have a closed set of potential states; the pole can only have a finite number of simulated angles and the cart has only a finite set of potential positions. One consequence of this approach is that the neural network does not always record the most accurate action for a given scenario, which could negatively affect the performance of the deep Q-learning algorithm. Training time for standard Q-learning and deep Q-learning would depend on the number of possible states. For standard Q-learning to be effective, you would need to ensure a high level of coverage for all potential scenarios. Deep Q-learning may be able to be trained effectively with a subset of potential scenarios, however because of the aforementioned accuracy problems the overall training time may be higher due to the need to refine the accuracy.
#
#
# In our tests, we observed that the starting values produced a very low performance, in contradiction with the performance reported by the documentation. While the documentation claimed to solve the problem with an average of 131 runs, we observed the agent was sufficiently trained after 826 runs. This indicates that there is a high level of variability across potential outcomes, and that a larger sample size is needed in order to determine changes in performance. We observed this variability because nearly all of our modified runs resulted in better performance. For this reason, even though we observed that there was a relatively decreased performance whenever we increased the learning rate as compared to whenever we decreased the learning rate, I do not believe that we can draw any firm conclusions.
#
#
# My current hypothesis is that there exists multiple potential values and strategies for solving this problem quickly. While one might tend to be more mathematically reliable. I was unable to reproduce the working environment on my local machine, so I am unable to increase the computational power or bypass the time constraints imposed by the virtual lab environment.

# %% [markdown]
# # Works Cited:
# Awan, A. A. (2022, October 27). An introduction to Q-learning: A tutorial for Beginners. DataCamp. https://www.datacamp.com/tutorial/introduction-q-learning-beginner-tutorial
#
#
# Chanda, K. (2024, August 26). Q-learning. GeeksforGeeks. https://www.geeksforgeeks.org/q-learning-in-python/
#
#
# Halthor, A. (2023, November 28). Deep Q-Networks Explained!. YouTube. https://www.youtube.com/watch?v=x83WmvbRa2I
#
#
# Luu, W. by: Q. T. (2024, March 18). Q-learning vs. deep Q-learning vs. Deep Q-Network. Baeldung on Computer Science. https://www.baeldung.com/cs/q-learning-vs-deep-q-learning-vs-deep-q-network
#
#
# Surma, G. (2019, November 10). Cartpole - introduction to reinforcement learning (DQN - deep Q-learning). Medium. https://gsurma.medium.com/cartpole-introduction-to-reinforcement-learning-ed0eb5b58288#f94f
